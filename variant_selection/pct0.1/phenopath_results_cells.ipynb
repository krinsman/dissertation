# %%
library("phenopath")
library("reticulate")
np <- import("numpy")

# %% [markdown]
# I am not sure whether the CAVI optimization from phenopath is completely deterministic, so I'm not sure whether the following cell would have actually been necessary for complete reproducibility. Nevertheless, I should have included this in the original notebooks.

# %%
set.seed(42)

# %%
phenopath_defaults <- function(observations, covariates, ...) {
    # suppressWarnings because I am well aware that it hasn't converged
    return(suppressWarnings(phenopath(observations, covariates, model_mu=TRUE, 
                                      maxiter=50, thin=10, verbose=FALSE, ...)))
}

# %% [markdown]
# The gLV models have intercepts $\mu$, and it makes more sense conceptually that a model has them (so they can represent 'intrinsic growth rates'), so `model_mu` is being used even though it is not a default setting. Plus very preliminary investigation seemed to suggest it is likely to get better results, and one would expect that theoretically as well not just for the reasons above but also because the default `model_mu=FALSE` is actually a special case where $\mu = 0$ is assumed, so allowing extra possible values for that parameter in general can only increase the fit. (Of course one can then argue about overfitting, but that seems unlikely since this model is clearly heavily mis-specified anyway, and again the extra parameter would not only increase fit but also be amenable to biological interpretation in this context.)
#
# Regarding small number of iterations, they seem to give decent enough results in practice, all the more so given that in this context one is more interested in qualitative fit, especially correct signs and sparsity, than precise numerical values. In other words any resulting quantitative accuracy will hopefully not also correspond to substantially decreased qualitative accuracy, especially given that 50 iterations is still a decent amount. Plus from a practical perspective, in order to provide estimates for so many estimations, there needs to be a reasonably enough upper bound on the runtime for each, and that is only possible by providing a relatively small of maximum possible iterations. In practice the experimenter, who only needs to analyze the results of a single experiment, should probably not used such a low number of maximum iterations.

# %%
spearman <- function(x,y){return(cor(x,y,method='spearman'))}

# %%
size = 11
seed = 42
number_droplets = 100000
number_batches = 5
results_dirname = 'results'

base_filename = paste(results_dirname, '/', size, '_strains.seed_', 
                      seed, '.', format(number_droplets, scientific=FALSE), '_droplets.iteration_',
                      '#', '.npz', sep='')

# %%
get_results <- function(phenopath_results, true_times) {
    uncensored_results <- interaction_effects(phenopath_results)
    censored_results <- significant_interactions(phenopath_results) * uncensored_results
    pearson <- abs(cor(true_times, trajectory(phenopath_results))) # same level of support if pseudotimes are flipped
    spearman <- abs(spearman(true_times, trajectory(phenopath_results)))
    
    results <- list("uncensored_results" = uncensored_results, 
                   "censored_results" = censored_results,
                   "pearson" = pearson,
                   "spearman" = spearman)
    return(results)
}

# %%
get_results_filename <- function(base_dir, scaling, iteration_number) {
    iteration_filename = paste('iteration_', iteration_number, '.npz', sep='')
    results_dir = file.path(paste(base_dir, '/', scaling, sep=''))
    results_filename = file.path(paste(results_dir, '/', iteration_filename, sep=''))
    return(results_filename)
}

save_results <- function(results_filename, results) {
    np$savez_compressed(results_filename,
    uncensored_results = results$uncensored_results,
    censored_results = results$censored_results,
    pearson = results$pearson,
    spearman = results$spearman)
}

# %% [markdown]
# The questions that I seek to answer are at a broad level: 'How can phenopath best be applied to this problem?' and 'What settings will allow phenopath to work best?'. Admittedly though not all possible choices of settings are being considered (e.g. alternative choices of `z_init`, like the true time values or the exponentials thereof, nor centering but not scaling the data, etc.) but the idea behind that was because in practice the experimenter is only likely to be willing (or in some cases only able) to use settings which do not deviate too much from the default values, plus it is reasonable to think that default choices of e.g. `z_init` were well thought out by the developers and are likely to be useful in practice, even if not the most useful theoretically possible for this context (which would be impossible to find, at least without a lot of probably intractable theory, due to e.g. the infinite state space of options for many settings).
#
# So the specific questions reduce to: (1) does it make sense to scale the data in this context (even though the data is PCR-bias adjusted and so roughly absolute counts), (2) what makes the most sense to use as the covariates for the model, and (3) do censoring values considered "insignificant" by the phenopath model lead to increased fit (i.e. by reducing false positives)? As an additional fun question, it is also asked: does the correlation (Pearson and/or Spearman) of the computed pseudotimes with the true times of the batches have any predictive value for the performance? E.g. do the true time values have any "importance" in that sense?
#
# As for always using the log-transformed data as the values, well that is both what is recommended in the phenopath paper and in its documentation, and moreover what makes the (generative) model for phenopath most closely resemble the (integral version of) the gLV equations.
#
# create directories to store results in

# %%
all_results_dir = 'phenopath_results_cells'
if (!dir.exists(all_results_dir)) {dir.create(all_results_dir)}

binary_results_dir = file.path(paste(all_results_dir, '/', 'binary_covariates', sep=''))
if (!dir.exists(binary_results_dir)) {dir.create(binary_results_dir)}

counts_cov_results_dir = file.path(paste(all_results_dir, '/', 'count_covariates', sep=''))
if (!dir.exists(counts_cov_results_dir)) {dir.create(counts_cov_results_dir)}

for (subdirectory in list.files(path=all_results_dir, full.names=T)) {
    scaled_results_dir = file.path(paste(subdirectory, '/', 'scaled', sep=''))
    if (!dir.exists(scaled_results_dir)) {dir.create(scaled_results_dir)}
    
    unscaled_results_dir = file.path(paste(subdirectory, '/', 'unscaled', sep=''))
    if (!dir.exists(unscaled_results_dir)) {dir.create(unscaled_results_dir)}
}

# %% [markdown]
# loop through the iterations of stored results

# %%
# very bad naughty code that uses lots of global variables
# this is a self-contained notebook however and not a software library.
# I don't want to rewrite the function and the function calls to unnecessarily be
# much longer when scope rules automatically do the right thing.
lapply_input <- function(iteration_number){
    
    filename = gsub("#", iteration_number, base_filename)
    npzfile = np$load(filename)

    cell_log_counts = npzfile[["cell_log_counts"]]
    cell_init_vectors = npzfile[["cell_init_vectors"]]
    cell_counts = exp(cell_log_counts)*(cell_log_counts != 0)    
    
    merged_droplets_per_batch <- dim(cell_log_counts)[1]/number_batches
    true_times = c()
    for (i in 1:number_batches) {true_times <- append(true_times, rep(i, merged_droplets_per_batch))}
    
    start_time <- proc.time()
    binary_scaled <- phenopath_defaults(cell_log_counts, cell_init_vectors, scale_y=TRUE)
    results <- get_results(binary_scaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    binary_unscaled <- phenopath_defaults(cell_log_counts, cell_init_vectors, scale_y=FALSE)
    results <- get_results(binary_unscaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_scaled <- phenopath_defaults(cell_log_counts, cell_counts, scale_y=TRUE)
    results <- get_results(counts_scaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_unscaled <- phenopath_defaults(cell_log_counts, cell_counts, scale_y=FALSE)
    results <- get_results(counts_unscaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    # this is supposed to be an embarrassingly parallel for loop, so memory usage should not change with number of iterations
    # but system monitor shows memory usage continually increasing. Hadley Wickham seems to have said that calling `gc`
    # manually for garbage collection should never be necessary, but honestly at this point I don't trust R so...
    gc()
    
    # controversial stylistically but consistent with Python style and since most programming is done
    # in Python, from a practical perspective it's better for me to use stylistic conventions that also work in Python.
    return(NULL)
}

# %%
lapply(1:100, lapply_input)
# Out:
#    user  system elapsed
# 776.545  46.557 817.004
#    user  system elapsed
# 766.536  54.705 818.269
#    user  system elapsed
# 763.570  49.729 808.549
#    user  system elapsed
# 759.364  51.678 806.836
#    user  system elapsed
# 765.181  49.101 808.858
#    user  system elapsed
# 793.905  57.641 856.971
#    user  system elapsed
# 829.197  60.133 904.091
#    user  system elapsed
# 822.219  56.915 887.736
#    user  system elapsed
# 848.471  59.168 920.752
#    user  system elapsed
# 835.595  63.688 914.577
#    user  system elapsed
# 846.336  62.308 931.972
#    user  system elapsed
# 842.014  59.987 921.746
#    user  system elapsed
# 840.950  62.896 922.605
#    user  system elapsed
# 836.667  63.325 918.015
#    user  system elapsed
# 844.553  60.859 921.356
#    user  system elapsed
# 837.487  66.485 922.602
#    user  system elapsed
# 778.924  58.797 835.792
#    user  system elapsed
# 774.997  56.080 828.545
#    user  system elapsed
# 769.942  52.512 819.224
#    user  system elapsed
# 768.120  52.279 818.275
#    user  system elapsed
# 778.371  51.610 826.424
#    user  system elapsed
# 775.746  54.739 827.697
#    user  system elapsed
# 781.743  52.813 837.269
#    user  system elapsed
# 801.390  59.540 884.298
#    user  system elapsed
# 860.781  66.717 948.026
#    user  system elapsed
# 837.843  68.803 924.817
#    user  system elapsed
# 834.432  63.957 912.816
#    user  system elapsed
# 839.880  64.575 918.802
#    user  system elapsed
# 845.042  61.098 919.866
#    user  system elapsed
# 841.540  65.619 922.858
#    user  system elapsed
# 830.564  64.487 909.247
#    user  system elapsed
# 834.922  65.685 916.391
#    user  system elapsed
# 841.759  62.530 921.733
#    user  system elapsed
# 827.815  67.035 912.616
#    user  system elapsed
# 830.204  63.866 910.797
#     user   system  elapsed
#  857.275   80.206 1015.559
#    user  system elapsed
# 855.602  77.637 970.923
#    user  system elapsed
# 838.800  74.044 941.700
#    user  system elapsed
# 838.638  70.497 932.863
#    user  system elapsed
# 841.188  73.409 942.830
#    user  system elapsed
# 851.877  74.494 953.653
#    user  system elapsed
# 850.468  73.714 958.652
#    user  system elapsed
# 862.518  78.628 982.946
#    user  system elapsed
# 861.730  77.294 981.939
#    user  system elapsed
# 867.220  78.998 988.732
#    user  system elapsed
# 797.511  64.117 869.630
#    user  system elapsed
# 766.823  49.918 814.667
#    user  system elapsed
# 766.834  49.605 811.564
#    user  system elapsed
# 777.256  49.946 825.339
#    user  system elapsed
# 768.744  53.335 817.900
#    user  system elapsed
# 762.876  49.122 808.233
#    user  system elapsed
# 759.851  52.631 809.714
#    user  system elapsed
# 771.178  50.248 816.503
#    user  system elapsed
# 765.643  49.597 811.340
#    user  system elapsed
# 761.483  48.513 805.378
#    user  system elapsed
# 762.636  48.794 806.519
#    user  system elapsed
# 764.517  48.290 807.820
#    user  system elapsed
# 762.276  51.192 809.240
#    user  system elapsed
# 760.112  49.140 804.092
#    user  system elapsed
# 760.756  51.758 808.238
#    user  system elapsed
# 774.294  51.850 822.639
#    user  system elapsed
# 766.372  49.802 811.263
#    user  system elapsed
# 765.412  49.366 809.632
#    user  system elapsed
# 765.389  49.365 809.273
#    user  system elapsed
# 763.956  49.017 808.000
#    user  system elapsed
# 767.914  49.759 813.169
#    user  system elapsed
# 766.832  49.094 810.347
#    user  system elapsed
# 757.282  49.890 802.165
#    user  system elapsed
# 773.548  50.450 818.561
#    user  system elapsed
# 768.512  51.349 816.047
#    user  system elapsed
# 759.704  48.209 803.399
#    user  system elapsed
# 766.093  51.315 812.976
#    user  system elapsed
# 767.279  49.254 812.344
#    user  system elapsed
# 764.691  50.440 811.308
#    user  system elapsed
# 765.956  48.402 810.102
#    user  system elapsed
# 764.148  50.009 809.850
#    user  system elapsed
# 765.296  49.659 809.835
#    user  system elapsed
# 763.233  51.609 810.613
#    user  system elapsed
# 760.163  48.102 804.021
#    user  system elapsed
# 762.775  50.454 810.193
#    user  system elapsed
# 772.549  51.974 821.206
#    user  system elapsed
# 762.366  50.205 808.315
#    user  system elapsed
# 764.341  48.516 808.536
#    user  system elapsed
# 757.260  49.548 802.584
#    user  system elapsed
# 788.293  57.301 854.786
#    user  system elapsed
# 791.714  60.381 859.699
#    user  system elapsed
# 796.555  60.560 867.402
#    user  system elapsed
# 809.798  69.788 898.535
#    user  system elapsed
# 772.492  51.894 822.435
#    user  system elapsed
# 779.346  56.537 845.256
#    user  system elapsed
# 776.372  57.844 841.839
#    user  system elapsed
# 786.008  62.283 858.314
#    user  system elapsed
# 790.218  57.104 850.090
#    user  system elapsed
# 828.160  70.320 937.366
#    user  system elapsed
# 868.136  80.927 991.009
#    user  system elapsed
# 791.546  59.713 855.869
#    user  system elapsed
# 801.834  61.685 869.533
#    user  system elapsed
# 794.063  57.574 856.273
#    user  system elapsed
# 810.579  59.227 874.911
#    user  system elapsed
# 793.699  53.912 849.213
#    user  system elapsed
# 764.203  49.196 808.393
#    user  system elapsed
# 765.129  52.596 814.538
#    user  system elapsed
# 765.566  48.746 810.343
#    user  system elapsed
# 762.722  51.150 810.390
#    user  system elapsed
# 772.273  48.984 816.164
#    user  system elapsed
# 765.343  49.847 811.717
#    user  system elapsed
# 804.170  56.980 860.503
#    user  system elapsed
# 800.101  63.384 873.315
#    user  system elapsed
# 797.561  57.651 854.887
#    user  system elapsed
# 799.242  56.167 856.064
#    user  system elapsed
# 789.365  52.653 840.561
#    user  system elapsed
# 774.710  55.650 834.318
#    user  system elapsed
# 791.001  56.024 850.544
#    user  system elapsed
# 792.127  58.077 854.371
#    user  system elapsed
# 804.291  58.162 865.764
#    user  system elapsed
# 795.130  57.670 858.735
#    user  system elapsed
# 797.939  58.249 858.095
#    user  system elapsed
# 801.474  58.878 864.757
#    user  system elapsed
# 781.843  56.224 842.737
#    user  system elapsed
# 776.609  51.402 823.663
#    user  system elapsed
# 818.355  60.854 893.690
#    user  system elapsed
# 783.221  56.135 841.174
#    user  system elapsed
# 775.688  55.738 828.431
#    user  system elapsed
# 766.491  53.019 816.990
#    user  system elapsed
# 773.169  51.832 820.751
#    user  system elapsed
# 776.570  53.298 825.912
#    user  system elapsed
# 785.959  53.868 841.145
#    user  system elapsed
# 806.179  63.971 884.680
#    user  system elapsed
# 819.811  65.610 894.921
#    user  system elapsed
# 792.387  63.206 866.364
#    user  system elapsed
# 772.588  52.630 821.435
#    user  system elapsed
# 764.825  52.171 814.195
#    user  system elapsed
# 773.120  50.912 819.592
#    user  system elapsed
# 791.696  59.566 857.371
#    user  system elapsed
# 778.259  50.521 825.814
#    user  system elapsed
# 777.500  53.408 827.908
#    user  system elapsed
# 778.154  54.213 830.120
#    user  system elapsed
# 770.194  52.675 819.950
#    user  system elapsed
# 788.775  57.183 851.514
#    user  system elapsed
# 782.802  54.768 838.606
#    user  system elapsed
# 803.614  53.973 859.824
#    user  system elapsed
# 769.029  51.900 816.419
#    user  system elapsed
# 765.425  48.770 809.327
#    user  system elapsed
# 762.966  49.264 807.253
#    user  system elapsed
# 769.983  50.199 815.733
#    user  system elapsed
# 770.308  53.153 819.981
#    user  system elapsed
# 763.017  49.036 807.024
#    user  system elapsed
# 765.939  50.186 811.903
#    user  system elapsed
# 769.749  50.115 814.793
#    user  system elapsed
# 773.200  52.013 820.383
#    user  system elapsed
# 766.936  49.529 811.434
#    user  system elapsed
# 760.942  50.177 806.183
#    user  system elapsed
# 771.745  50.581 817.700
#    user  system elapsed
# 766.748  50.872 813.833
#    user  system elapsed
# 763.414  48.759 806.998
#    user  system elapsed
# 760.433  49.854 805.138
#    user  system elapsed
# 774.811  49.298 818.914
#    user  system elapsed
# 777.473  49.899 823.619
#    user  system elapsed
# 776.554  49.858 822.037
#    user  system elapsed
# 766.036  52.200 814.376
#    user  system elapsed
# 765.367  48.037 808.172
#    user  system elapsed
# 764.966  50.441 810.884
#    user  system elapsed
# 765.909  48.926 809.954
#    user  system elapsed
# 762.217  51.597 809.519
#    user  system elapsed
# 776.748  49.907 821.851
#    user  system elapsed
# 780.179  51.033 827.560
#    user  system elapsed
# 762.277  49.532 807.603
#    user  system elapsed
# 764.574  50.728 810.447
#    user  system elapsed
# 777.154  49.101 820.705
#    user  system elapsed
# 765.515  49.567 810.061
#    user  system elapsed
# 767.090  48.602 810.210
#    user  system elapsed
# 759.203  49.452 803.637
#    user  system elapsed
# 767.663  50.322 812.850
#    user  system elapsed
# 771.293  50.570 817.975
#    user  system elapsed
# 769.963  48.907 813.537
#    user  system elapsed
# 760.725  49.372 806.045
#    user  system elapsed
# 769.556  50.679 815.763
#    user  system elapsed
# 761.484  52.191 809.438
#    user  system elapsed
# 763.451  48.130 806.437
#    user  system elapsed
# 773.094  54.594 836.657
#    user  system elapsed
# 847.253  63.826 915.735
#    user  system elapsed
# 853.665  70.883 935.700
#    user  system elapsed
# 868.901  60.998 933.020
#    user  system elapsed
# 867.363  60.875 929.523
#    user  system elapsed
# 867.040  55.321 921.858
#    user  system elapsed
# 840.629  60.593 909.258
#    user  system elapsed
# 854.958  78.226 977.795
#    user  system elapsed
# 850.601  82.880 986.343
#    user  system elapsed
# 860.375  85.865 981.076
#     user   system  elapsed
#  892.545   97.090 1052.855
#    user  system elapsed
# 851.237  87.498 970.040
#    user  system elapsed
# 778.205  64.316 844.934
#    user  system elapsed
# 772.954  58.606 830.859
#    user  system elapsed
# 836.960  77.071 952.801
#     user   system  elapsed
#  848.665   99.709 1005.389
#    user  system elapsed
# 803.559  74.012 900.462
#    user  system elapsed
# 813.084  71.416 900.764
#    user  system elapsed
# 809.843  72.272 896.436
#    user  system elapsed
# 816.328  72.795 906.886
#    user  system elapsed
# 832.203  80.032 958.396
#    user  system elapsed
# 833.303  76.065 954.868
#    user  system elapsed
# 875.770  75.420 967.616
#    user  system elapsed
# 884.142  72.022 959.846
#    user  system elapsed
# 836.134  80.097 969.774
#    user  system elapsed
# 834.276  78.011 969.319
#    user  system elapsed
# 850.831  77.886 955.361
#    user  system elapsed
# 897.368  79.379 991.835
#    user  system elapsed
# 877.928  84.225 987.562
#    user  system elapsed
# 880.776  75.491 965.948
#    user  system elapsed
# 872.627  73.289 955.945
#    user  system elapsed
# 885.958  78.155 977.243
#    user  system elapsed
# 873.019  78.020 973.980
#    user  system elapsed
# 825.099  73.740 925.717
#    user  system elapsed
# 833.194  76.857 948.909
#     user   system  elapsed
#  855.113   84.321 1015.908
#    user  system elapsed
# 824.915  73.269 954.767
#    user  system elapsed
# 869.821  67.176 942.977
#    user  system elapsed
# 879.547  70.094 956.045
#    user  system elapsed
# 885.450  72.592 968.608
#    user  system elapsed
# 874.721  71.362 958.941
#    user  system elapsed
# 884.111  73.038 977.502
#     user   system  elapsed
#  902.590   80.680 1111.629
#    user  system elapsed
# 833.254  72.810 953.202
#     user   system  elapsed
#  867.280   77.273 1022.211
#     user   system  elapsed
#  887.495   78.230 1060.166
#     user   system  elapsed
#  933.933  171.051 1351.966
#     user   system  elapsed
#  864.134   90.491 1004.490
#    user  system elapsed
# 835.612  67.333 929.571
#    user  system elapsed
# 821.882  66.893 919.002
#    user  system elapsed
# 817.469  66.707 909.997
#     user   system  elapsed
#  864.584   70.487 1010.820
#    user  system elapsed
# 837.197  70.597 933.851
#    user  system elapsed
# 866.455  65.107 932.434
#    user  system elapsed
# 872.333  60.829 933.261
#    user  system elapsed
# 860.317  57.592 918.363
#    user  system elapsed
# 860.625  57.103 917.520
#    user  system elapsed
# 867.185  59.279 925.909
#    user  system elapsed
# 861.734  60.630 923.448
#    user  system elapsed
# 856.874  54.584 910.083
#    user  system elapsed
# 852.599  53.325 904.507
#    user  system elapsed
# 851.360  52.838 903.054
#    user  system elapsed
# 843.699  52.773 895.575
#    user  system elapsed
# 791.127  51.350 840.576
#    user  system elapsed
# 759.922  50.760 806.526
#    user  system elapsed
# 805.081  51.378 852.580
#    user  system elapsed
# 795.450  51.291 844.378
#    user  system elapsed
# 763.455  49.727 809.043
#    user  system elapsed
# 771.713  52.537 821.234
#    user  system elapsed
# 822.866  53.374 874.230
#    user  system elapsed
# 772.923  52.333 821.031
#    user  system elapsed
# 770.631  50.783 816.824
#    user  system elapsed
# 824.463  53.828 874.758
#    user  system elapsed
# 775.366  50.866 821.303
#    user  system elapsed
# 768.020  50.841 814.064
#    user  system elapsed
# 768.207  49.285 812.546
#    user  system elapsed
# 767.468  49.932 812.267
#    user  system elapsed
# 769.208  49.929 814.629
#    user  system elapsed
# 767.992  51.252 814.473
#    user  system elapsed
# 761.279  49.279 805.619
#    user  system elapsed
# 756.184  49.964 801.063
#    user  system elapsed
# 823.227  51.107 869.766
#    user  system elapsed
# 782.099  50.417 830.298
#    user  system elapsed
# 760.199  49.400 805.334
#    user  system elapsed
# 767.375  50.652 813.433
#    user  system elapsed
# 770.970  49.821 816.132
#    user  system elapsed
# 767.656  51.438 814.616
#    user  system elapsed
# 767.541  49.852 813.363
#    user  system elapsed
# 759.607  51.007 806.066
#    user  system elapsed
# 784.204  51.238 830.608
#    user  system elapsed
# 820.968  50.985 869.650
#    user  system elapsed
# 769.130  49.258 813.170
#    user  system elapsed
# 758.305  49.377 802.957
#    user  system elapsed
# 772.768  49.691 817.289
#    user  system elapsed
# 768.853  50.748 814.942
#    user  system elapsed
# 764.489  49.023 808.709
#    user  system elapsed
# 755.036  51.015 801.568
#    user  system elapsed
# 764.517  50.466 810.025
#    user  system elapsed
# 773.053  53.988 826.533
#    user  system elapsed
# 840.147  81.585 958.106
#     user   system  elapsed
#  891.209   95.888 1045.016
#     user   system  elapsed
#  900.117   92.345 1055.551
#    user  system elapsed
# 857.337  81.893 977.100
#     user   system  elapsed
#  881.122   87.601 1001.181
#     user   system  elapsed
#  981.748  160.812 1409.436
#    user  system elapsed
# 862.078  87.714 990.942
#    user  system elapsed
# 849.475  69.260 952.876
#    user  system elapsed
# 814.415  55.606 877.780
#    user  system elapsed
# 803.802  52.753 854.208
#    user  system elapsed
# 778.699  52.652 827.491
#    user  system elapsed
# 797.090  51.893 844.543
#    user  system elapsed
# 825.605  65.060 902.606
#    user  system elapsed
# 846.030  71.484 974.310
#    user  system elapsed
# 817.443  65.630 906.640
#    user  system elapsed
# 847.920  61.168 909.785
#    user  system elapsed
# 785.608  58.524 867.891
#    user  system elapsed
# 792.823  65.743 879.776
#    user  system elapsed
# 790.567  60.020 857.473
#    user  system elapsed
# 799.057  60.975 867.091
#    user  system elapsed
# 784.333  53.807 835.323
#    user  system elapsed
# 817.408  56.289 874.065
#    user  system elapsed
# 776.110  53.552 825.571
#    user  system elapsed
# 769.231  53.434 819.033
#    user  system elapsed
# 772.651  51.559 820.441
#    user  system elapsed
# 768.650  53.945 819.085
#    user  system elapsed
# 873.518  61.259 933.318
#    user  system elapsed
# 773.920  56.029 828.811
#    user  system elapsed
# 771.487  52.352 819.951
#    user  system elapsed
# 764.267  53.298 814.729
#    user  system elapsed
# 772.737  53.649 822.891
#    user  system elapsed
# 820.749  54.103 871.584
#    user  system elapsed
# 789.247  51.176 838.646
#    user  system elapsed
# 768.700  51.935 816.545
#    user  system elapsed
# 774.946  51.746 823.028
#    user  system elapsed
# 769.202  52.891 818.431
#    user  system elapsed
# 769.429  52.671 818.766
#    user  system elapsed
# 764.958  52.711 814.592
#    user  system elapsed
# 770.036  52.713 819.120
#    user  system elapsed
# 784.082  55.090 835.715
#    user  system elapsed
# 816.113  52.245 867.459
#    user  system elapsed
# 778.034  54.301 829.349
#    user  system elapsed
# 774.713  52.736 823.115
#    user  system elapsed
# 767.925  53.113 817.645
#    user  system elapsed
# 774.868  52.290 822.792
#    user  system elapsed
# 765.414  52.591 814.891
#     user   system  elapsed
#  875.292   99.055 1032.587
#    user  system elapsed
# 811.492  68.910 896.349
#    user  system elapsed
# 813.737  64.192 901.834
#    user  system elapsed
# 799.982  62.172 881.351
#    user  system elapsed
# 804.432  57.308 864.947
#    user  system elapsed
# 791.376  58.840 853.850
#    user  system elapsed
# 824.251  66.901 924.339
#    user  system elapsed
# 807.691  61.674 889.263
#    user  system elapsed
# 821.886  65.280 918.078
#    user  system elapsed
# 819.558  66.085 916.790
#    user  system elapsed
# 833.310  69.860 938.894
#    user  system elapsed
# 816.265  72.023 926.222
#    user  system elapsed
# 838.580  73.417 962.499
#    user  system elapsed
# 801.868  59.643 870.541
#    user  system elapsed
# 842.619  76.196 974.186
#    user  system elapsed
# 789.316  60.324 855.073
#    user  system elapsed
# 780.252  54.047 829.822
#    user  system elapsed
# 775.140  52.262 822.951
#    user  system elapsed
# 773.049  48.458 815.850
#    user  system elapsed
# 771.205  50.094 816.151
#    user  system elapsed
# 779.127  49.982 823.944
#    user  system elapsed
# 769.956  51.113 816.396
#    user  system elapsed
# 767.890  49.519 811.686
#    user  system elapsed
# 762.827  51.312 809.977
#    user  system elapsed
# 767.846  50.447 813.426
#    user  system elapsed
# 765.490  49.405 810.827
#    user  system elapsed
# 764.181  49.098 807.372
#    user  system elapsed
# 762.725  49.905 806.227
#    user  system elapsed
# 771.134  48.938 813.966
#    user  system elapsed
# 783.728  50.830 829.060
#    user  system elapsed
# 777.608  50.550 822.575
#    user  system elapsed
# 767.175  50.248 812.011
#    user  system elapsed
# 774.947  50.304 820.021
#    user  system elapsed
# 772.630  51.546 819.270
#    user  system elapsed
# 770.216  49.533 814.063
#    user  system elapsed
# 768.896  49.669 812.564
#    user  system elapsed
# 771.168  49.636 815.003
#    user  system elapsed
# 776.432  50.657 821.675
#    user  system elapsed
# 769.866  49.873 814.342
#    user  system elapsed
# 764.615  50.729 809.750
#    user  system elapsed
# 780.574  51.179 826.558
#    user  system elapsed
# 783.088  51.220 829.960
#    user  system elapsed
# 771.804  48.881 814.970
#    user  system elapsed
# 764.760  49.543 808.143
#    user  system elapsed
# 767.831  49.410 812.030
#    user  system elapsed
# 766.426  50.231 811.248
#    user  system elapsed
# 778.020  49.906 821.948
#    user  system elapsed
# 767.675  50.675 812.385
#    user  system elapsed
# 773.378  49.776 817.611
#    user  system elapsed
# 766.149  49.356 809.930
#    user  system elapsed
# 784.850  57.785 867.158
#    user  system elapsed
# 850.768  73.948 969.052
#    user  system elapsed
# 826.861  60.627 890.341
#    user  system elapsed
# 834.362  71.808 942.199
#    user  system elapsed
# 828.868  58.414 889.949
#    user  system elapsed
# 816.635  58.185 888.734
#    user  system elapsed
# 814.402  66.927 897.108
#    user  system elapsed
# 805.402  63.121 882.699
#    user  system elapsed
# 799.238  57.676 865.678
#    user  system elapsed
# 770.020  50.896 816.608
#    user  system elapsed
# 775.438  53.164 825.955
#    user  system elapsed
# 816.329  61.957 900.963
#    user  system elapsed
# 778.621  52.043 828.713
#    user  system elapsed
# 770.857  52.056 818.548
#    user  system elapsed
# 773.797  51.431 820.868
#    user  system elapsed
# 774.298  50.998 822.054
#    user  system elapsed
# 775.228  49.802 820.256
#    user  system elapsed
# 770.814  51.788 819.943
#    user  system elapsed
# 790.262  57.615 867.447
#     user   system  elapsed
#  879.254   83.457 1055.281
#    user  system elapsed
# 838.727  66.134 922.110
#    user  system elapsed
# 846.623  74.623 997.340
#    user  system elapsed
# 850.625  78.878 979.485
#    user  system elapsed
# 865.640  76.261 995.367
#     user   system  elapsed
#  869.593   79.133 1019.285
#     user   system  elapsed
#  869.391   84.224 1033.130
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL
#
# [[6]]
# NULL
#
# [[7]]
# NULL
#
# [[8]]
# NULL
#
# [[9]]
# NULL
#
# [[10]]
# NULL
#
# [[11]]
# NULL
#
# [[12]]
# NULL
#
# [[13]]
# NULL
#
# [[14]]
# NULL
#
# [[15]]
# NULL
#
# [[16]]
# NULL
#
# [[17]]
# NULL
#
# [[18]]
# NULL
#
# [[19]]
# NULL
#
# [[20]]
# NULL
#
# [[21]]
# NULL
#
# [[22]]
# NULL
#
# [[23]]
# NULL
#
# [[24]]
# NULL
#
# [[25]]
# NULL
#
# [[26]]
# NULL
#
# [[27]]
# NULL
#
# [[28]]
# NULL
#
# [[29]]
# NULL
#
# [[30]]
# NULL
#
# [[31]]
# NULL
#
# [[32]]
# NULL
#
# [[33]]
# NULL
#
# [[34]]
# NULL
#
# [[35]]
# NULL
#
# [[36]]
# NULL
#
# [[37]]
# NULL
#
# [[38]]
# NULL
#
# [[39]]
# NULL
#
# [[40]]
# NULL
#
# [[41]]
# NULL
#
# [[42]]
# NULL
#
# [[43]]
# NULL
#
# [[44]]
# NULL
#
# [[45]]
# NULL
#
# [[46]]
# NULL
#
# [[47]]
# NULL
#
# [[48]]
# NULL
#
# [[49]]
# NULL
#
# [[50]]
# NULL
#
# [[51]]
# NULL
#
# [[52]]
# NULL
#
# [[53]]
# NULL
#
# [[54]]
# NULL
#
# [[55]]
# NULL
#
# [[56]]
# NULL
#
# [[57]]
# NULL
#
# [[58]]
# NULL
#
# [[59]]
# NULL
#
# [[60]]
# NULL
#
# [[61]]
# NULL
#
# [[62]]
# NULL
#
# [[63]]
# NULL
#
# [[64]]
# NULL
#
# [[65]]
# NULL
#
# [[66]]
# NULL
#
# [[67]]
# NULL
#
# [[68]]
# NULL
#
# [[69]]
# NULL
#
# [[70]]
# NULL
#
# [[71]]
# NULL
#
# [[72]]
# NULL
#
# [[73]]
# NULL
#
# [[74]]
# NULL
#
# [[75]]
# NULL
#
# [[76]]
# NULL
#
# [[77]]
# NULL
#
# [[78]]
# NULL
#
# [[79]]
# NULL
#
# [[80]]
# NULL
#
# [[81]]
# NULL
#
# [[82]]
# NULL
#
# [[83]]
# NULL
#
# [[84]]
# NULL
#
# [[85]]
# NULL
#
# [[86]]
# NULL
#
# [[87]]
# NULL
#
# [[88]]
# NULL
#
# [[89]]
# NULL
#
# [[90]]
# NULL
#
# [[91]]
# NULL
#
# [[92]]
# NULL
#
# [[93]]
# NULL
#
# [[94]]
# NULL
#
# [[95]]
# NULL
#
# [[96]]
# NULL
#
# [[97]]
# NULL
#
# [[98]]
# NULL
#
# [[99]]
# NULL
#
# [[100]]
# NULL
