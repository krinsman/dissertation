# %%
library("phenopath")
library("reticulate")
np <- import("numpy")

# %% [markdown]
# I am not sure whether the CAVI optimization from phenopath is completely deterministic, so I'm not sure whether the following cell would have actually been necessary for complete reproducibility. Nevertheless, I should have included this in the original notebooks.

# %%
set.seed(42)

# %%
phenopath_defaults <- function(observations, covariates, ...) {
    # suppressWarnings because I am well aware that it hasn't converged
    return(suppressWarnings(phenopath(observations, covariates, model_mu=TRUE, 
                                      maxiter=50, thin=10, verbose=FALSE, ...)))
}

# %% [markdown]
# The gLV models have intercepts $\mu$, and it makes more sense conceptually that a model has them (so they can represent 'intrinsic growth rates'), so `model_mu` is being used even though it is not a default setting. Plus very preliminary investigation seemed to suggest it is likely to get better results, and one would expect that theoretically as well not just for the reasons above but also because the default `model_mu=FALSE` is actually a special case where $\mu = 0$ is assumed, so allowing extra possible values for that parameter in general can only increase the fit. (Of course one can then argue about overfitting, but that seems unlikely since this model is clearly heavily mis-specified anyway, and again the extra parameter would not only increase fit but also be amenable to biological interpretation in this context.)
#
# Regarding small number of iterations, they seem to give decent enough results in practice, all the more so given that in this context one is more interested in qualitative fit, especially correct signs and sparsity, than precise numerical values. In other words any resulting quantitative accuracy will hopefully not also correspond to substantially decreased qualitative accuracy, especially given that 50 iterations is still a decent amount. Plus from a practical perspective, in order to provide estimates for so many estimations, there needs to be a reasonably enough upper bound on the runtime for each, and that is only possible by providing a relatively small of maximum possible iterations. In practice the experimenter, who only needs to analyze the results of a single experiment, should probably not used such a low number of maximum iterations.

# %%
spearman <- function(x,y){return(cor(x,y,method='spearman'))}

# %%
size = 11
seed = 42
number_droplets = 100000
number_batches = 5
results_dirname = 'results'

base_filename = paste(results_dirname, '/', size, '_strains.seed_', 
                      seed, '.', format(number_droplets, scientific=FALSE), '_droplets.iteration_',
                      '#', '.npz', sep='')

# %%
get_results <- function(phenopath_results, true_times) {
    uncensored_results <- interaction_effects(phenopath_results)
    censored_results <- significant_interactions(phenopath_results) * uncensored_results
    pearson <- abs(cor(true_times, trajectory(phenopath_results))) # same level of support if pseudotimes are flipped
    spearman <- abs(spearman(true_times, trajectory(phenopath_results)))
    
    results <- list("uncensored_results" = uncensored_results, 
                   "censored_results" = censored_results,
                   "pearson" = pearson,
                   "spearman" = spearman)
    return(results)
}

# %%
get_results_filename <- function(base_dir, scaling, iteration_number) {
    iteration_filename = paste('iteration_', iteration_number, '.npz', sep='')
    results_dir = file.path(paste(base_dir, '/', scaling, sep=''))
    results_filename = file.path(paste(results_dir, '/', iteration_filename, sep=''))
    return(results_filename)
}

save_results <- function(results_filename, results) {
    np$savez_compressed(results_filename,
    uncensored_results = results$uncensored_results,
    censored_results = results$censored_results,
    pearson = results$pearson,
    spearman = results$spearman)
}

# %% [markdown]
# The questions that I seek to answer are at a broad level: 'How can phenopath best be applied to this problem?' and 'What settings will allow phenopath to work best?'. Admittedly though not all possible choices of settings are being considered (e.g. alternative choices of `z_init`, like the true time values or the exponentials thereof, nor centering but not scaling the data, etc.) but the idea behind that was because in practice the experimenter is only likely to be willing (or in some cases only able) to use settings which do not deviate too much from the default values, plus it is reasonable to think that default choices of e.g. `z_init` were well thought out by the developers and are likely to be useful in practice, even if not the most useful theoretically possible for this context (which would be impossible to find, at least without a lot of probably intractable theory, due to e.g. the infinite state space of options for many settings).
#
# So the specific questions reduce to: (1) does it make sense to scale the data in this context (even though the data is PCR-bias adjusted and so roughly absolute counts), (2) what makes the most sense to use as the covariates for the model, and (3) do censoring values considered "insignificant" by the phenopath model lead to increased fit (i.e. by reducing false positives)? As an additional fun question, it is also asked: does the correlation (Pearson and/or Spearman) of the computed pseudotimes with the true times of the batches have any predictive value for the performance? E.g. do the true time values have any "importance" in that sense?
#
# As for always using the log-transformed data as the values, well that is both what is recommended in the phenopath paper and in its documentation, and moreover what makes the (generative) model for phenopath most closely resemble the (integral version of) the gLV equations.
#
# create directories to store results in

# %%
all_results_dir = 'phenopath_results_cells'
if (!dir.exists(all_results_dir)) {dir.create(all_results_dir)}

binary_results_dir = file.path(paste(all_results_dir, '/', 'binary_covariates', sep=''))
if (!dir.exists(binary_results_dir)) {dir.create(binary_results_dir)}

counts_cov_results_dir = file.path(paste(all_results_dir, '/', 'count_covariates', sep=''))
if (!dir.exists(counts_cov_results_dir)) {dir.create(counts_cov_results_dir)}

for (subdirectory in list.files(path=all_results_dir, full.names=T)) {
    scaled_results_dir = file.path(paste(subdirectory, '/', 'scaled', sep=''))
    if (!dir.exists(scaled_results_dir)) {dir.create(scaled_results_dir)}
    
    unscaled_results_dir = file.path(paste(subdirectory, '/', 'unscaled', sep=''))
    if (!dir.exists(unscaled_results_dir)) {dir.create(unscaled_results_dir)}
}

# %% [markdown]
# loop through the iterations of stored results

# %%
# very bad naughty code that uses lots of global variables
# this is a self-contained notebook however and not a software library.
# I don't want to rewrite the function and the function calls to unnecessarily be
# much longer when scope rules automatically do the right thing.
lapply_input <- function(iteration_number){
    
    filename = gsub("#", iteration_number, base_filename)
    npzfile = np$load(filename)

    cell_log_counts = npzfile[["cell_log_counts"]]
    cell_init_vectors = npzfile[["cell_init_vectors"]]
    cell_counts = exp(cell_log_counts)*(cell_log_counts != 0)    
    
    merged_droplets_per_batch <- dim(cell_log_counts)[1]/number_batches
    true_times = c()
    for (i in 1:number_batches) {true_times <- append(true_times, rep(i, merged_droplets_per_batch))}
    
    start_time <- proc.time()
    binary_scaled <- phenopath_defaults(cell_log_counts, cell_init_vectors, scale_y=TRUE)
    results <- get_results(binary_scaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    binary_unscaled <- phenopath_defaults(cell_log_counts, cell_init_vectors, scale_y=FALSE)
    results <- get_results(binary_unscaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_scaled <- phenopath_defaults(cell_log_counts, cell_counts, scale_y=TRUE)
    results <- get_results(counts_scaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_unscaled <- phenopath_defaults(cell_log_counts, cell_counts, scale_y=FALSE)
    results <- get_results(counts_unscaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    # this is supposed to be an embarrassingly parallel for loop, so memory usage should not change with number of iterations
    # but system monitor shows memory usage continually increasing. Hadley Wickham seems to have said that calling `gc`
    # manually for garbage collection should never be necessary, but honestly at this point I don't trust R so...
    gc()
    
    # controversial stylistically but consistent with Python style and since most programming is done
    # in Python, from a practical perspective it's better for me to use stylistic conventions that also work in Python.
    return(NULL)
}

# %%
lapply(1:100, lapply_input)
# Out:
#     user   system  elapsed
#  875.746   76.055 1002.279
#     user   system  elapsed
#  866.709   84.356 1027.816
#     user   system  elapsed
#  857.074   86.008 1014.348
#    user  system elapsed
# 840.247  73.922 934.367
#    user  system elapsed
# 818.942  71.009 908.738
#    user  system elapsed
# 814.842  64.673 892.068
#    user  system elapsed
# 823.542  56.112 888.847
#    user  system elapsed
# 809.005  63.288 881.143
#    user  system elapsed
# 812.428  62.606 883.741
#    user  system elapsed
# 810.575  60.155 882.959
#    user  system elapsed
# 818.849  57.358 875.875
#    user  system elapsed
# 813.867  58.569 871.632
#    user  system elapsed
# 821.471  64.871 901.121
#    user  system elapsed
# 827.797  71.471 921.495
#     user   system  elapsed
#  856.468   97.522 1001.774
#     user   system  elapsed
#  897.819  115.879 1091.770
#     user   system  elapsed
#  880.973   99.140 1035.496
#     user   system  elapsed
#  873.555   82.628 1010.908
#    user  system elapsed
# 839.819  67.524 918.231
#    user  system elapsed
# 815.583  64.516 883.227
#    user  system elapsed
# 841.407  82.260 960.138
#    user  system elapsed
# 815.247  69.701 900.522
#    user  system elapsed
# 842.787  72.259 932.121
#    user  system elapsed
# 827.898  77.205 928.289
#    user  system elapsed
# 819.766  74.998 909.256
#    user  system elapsed
# 818.318  74.144 905.584
#    user  system elapsed
# 815.943  72.834 898.925
#    user  system elapsed
# 821.620  73.361 909.918
#    user  system elapsed
# 825.130  73.505 909.425
#     user   system  elapsed
#  885.908   83.891 1052.100
#     user   system  elapsed
#  892.347   85.970 1069.442
#     user   system  elapsed
#  898.548   88.497 1082.466
#     user   system  elapsed
#  919.397   89.640 1127.888
#     user   system  elapsed
#  913.112   97.270 1151.786
#    user  system elapsed
# 856.265  81.342 976.284
#    user  system elapsed
# 860.962  70.781 934.452
#    user  system elapsed
# 793.926  61.524 853.705
#    user  system elapsed
# 789.516  58.144 844.482
#    user  system elapsed
# 848.386  56.419 901.875
#    user  system elapsed
# 775.076  53.891 826.383
#    user  system elapsed
# 792.022  52.077 840.043
#    user  system elapsed
# 814.004  56.712 867.670
#    user  system elapsed
# 808.556  55.937 863.453
#    user  system elapsed
# 777.851  54.036 827.833
#    user  system elapsed
# 823.080  54.417 873.675
#    user  system elapsed
# 804.685  56.284 860.147
#    user  system elapsed
# 786.580  52.821 836.048
#    user  system elapsed
# 780.439  53.539 829.968
#    user  system elapsed
# 780.032  52.424 828.894
#    user  system elapsed
# 784.828  54.186 835.598
#    user  system elapsed
# 780.151  51.601 827.504
#    user  system elapsed
# 780.403  53.321 829.573
#    user  system elapsed
# 788.317  53.264 837.712
#    user  system elapsed
# 855.635  59.770 914.203
#    user  system elapsed
# 781.354  51.954 829.644
#    user  system elapsed
# 786.370  56.161 839.587
#    user  system elapsed
# 784.334  51.494 831.545
#    user  system elapsed
# 777.170  54.530 828.644
#    user  system elapsed
# 783.746  53.836 833.601
#    user  system elapsed
# 778.462  54.004 831.061
#    user  system elapsed
# 786.386  54.246 836.944
#    user  system elapsed
# 812.627  57.688 868.145
#    user  system elapsed
# 810.998  53.235 862.796
#    user  system elapsed
# 776.841  54.272 826.998
#    user  system elapsed
# 783.561  54.314 835.034
#    user  system elapsed
# 807.812  66.925 881.323
#    user  system elapsed
# 796.274  55.420 849.065
#    user  system elapsed
# 770.693  54.811 823.368
#    user  system elapsed
# 780.083  63.351 843.798
#    user  system elapsed
# 788.969  61.168 851.041
#    user  system elapsed
# 804.633  59.498 864.452
#    user  system elapsed
# 796.416  57.976 853.852
#    user  system elapsed
# 807.999  61.045 870.599
#    user  system elapsed
# 796.327  62.766 860.415
#    user  system elapsed
# 796.570  57.756 861.219
#    user  system elapsed
# 816.717  76.151 921.713
#    user  system elapsed
# 850.087  64.380 915.618
#    user  system elapsed
# 790.691  60.162 863.870
#    user  system elapsed
# 802.436  56.385 861.900
#    user  system elapsed
# 815.164  58.697 871.681
#    user  system elapsed
# 850.079  61.448 912.631
#    user  system elapsed
# 794.282  59.041 852.095
#    user  system elapsed
# 790.328  58.967 851.464
#    user  system elapsed
# 824.406  62.528 897.170
#    user  system elapsed
# 831.498  62.431 905.304
#    user  system elapsed
# 811.433  63.391 882.399
#    user  system elapsed
# 809.036  60.252 874.872
#    user  system elapsed
# 795.884  65.009 863.555
#    user  system elapsed
# 825.770  77.042 947.149
#    user  system elapsed
# 849.609  69.320 922.319
#    user  system elapsed
# 826.055  72.542 939.566
#    user  system elapsed
# 784.795  62.012 847.376
#    user  system elapsed
# 789.208  61.311 850.835
#    user  system elapsed
# 813.277  66.568 904.542
#    user  system elapsed
# 887.630  72.316 979.314
#    user  system elapsed
# 817.956  67.757 892.880
#    user  system elapsed
# 807.219  64.647 879.255
#    user  system elapsed
# 801.212  68.978 877.871
#    user  system elapsed
# 801.697  65.156 870.919
#    user  system elapsed
# 817.508  74.198 921.894
#    user  system elapsed
# 820.208  72.120 910.956
#    user  system elapsed
# 828.561  72.682 915.515
#    user  system elapsed
# 847.271  82.668 961.558
#    user  system elapsed
# 838.738  79.762 938.633
#    user  system elapsed
# 855.103  75.500 956.766
#    user  system elapsed
# 851.796  82.883 982.203
#    user  system elapsed
# 865.315  75.234 966.136
#    user  system elapsed
# 846.440  69.558 931.135
#    user  system elapsed
# 834.717  69.185 912.168
#    user  system elapsed
# 857.355  69.098 934.223
#    user  system elapsed
# 848.601  75.627 935.708
#     user   system  elapsed
#  872.926  107.555 1035.916
#    user  system elapsed
# 828.607  61.248 893.248
#    user  system elapsed
# 838.671  67.510 912.801
#    user  system elapsed
# 842.024  75.564 938.069
#    user  system elapsed
# 842.224  74.124 933.931
#    user  system elapsed
# 854.926  75.994 962.805
#    user  system elapsed
# 840.529  74.286 936.115
#    user  system elapsed
# 863.826  74.774 954.042
#    user  system elapsed
# 854.417  81.861 972.384
#    user  system elapsed
# 827.108  77.035 928.686
#    user  system elapsed
# 840.008  75.804 954.776
#    user  system elapsed
# 834.828  73.598 934.714
#    user  system elapsed
# 841.125  78.553 959.190
#     user   system  elapsed
#  858.485   87.707 1018.785
#    user  system elapsed
# 841.743  79.900 972.217
#    user  system elapsed
# 840.749  79.696 963.596
#    user  system elapsed
# 822.357  78.853 923.110
#    user  system elapsed
# 845.082  79.549 954.372
#    user  system elapsed
# 847.907  76.649 952.850
#    user  system elapsed
# 834.184  80.957 943.345
#    user  system elapsed
# 781.627  58.283 836.879
#    user  system elapsed
# 801.923  57.044 855.475
#    user  system elapsed
# 788.465  54.662 840.479
#    user  system elapsed
# 779.900  50.780 825.853
#    user  system elapsed
# 778.603  50.580 824.126
#    user  system elapsed
# 786.713  52.822 838.378
#    user  system elapsed
# 775.791  51.038 822.743
#    user  system elapsed
# 789.394  51.415 836.094
#    user  system elapsed
# 779.998  54.411 832.023
#    user  system elapsed
# 778.186  51.541 825.303
#    user  system elapsed
# 783.371  52.717 831.055
#    user  system elapsed
# 784.692  51.529 831.057
#    user  system elapsed
# 781.355  51.542 828.373
#    user  system elapsed
# 797.604  51.564 844.328
#    user  system elapsed
# 787.793  51.228 833.994
#    user  system elapsed
# 778.046  51.227 826.928
#    user  system elapsed
# 768.461  52.209 815.782
#    user  system elapsed
# 788.558  51.403 835.204
#    user  system elapsed
# 773.761  51.327 820.480
#    user  system elapsed
# 777.289  51.598 825.073
#    user  system elapsed
# 769.597  51.357 816.202
#    user  system elapsed
# 780.570  51.204 826.710
#    user  system elapsed
# 777.656  51.111 823.407
#    user  system elapsed
# 789.553  51.015 836.458
#    user  system elapsed
# 778.319  52.735 826.461
#    user  system elapsed
# 773.992  51.024 819.953
#    user  system elapsed
# 775.234  52.748 823.980
#    user  system elapsed
# 781.032  52.838 830.404
#    user  system elapsed
# 771.674  50.600 817.650
#    user  system elapsed
# 783.036  50.582 828.531
#    user  system elapsed
# 775.793  51.066 821.427
#    user  system elapsed
# 776.991  49.954 821.125
#    user  system elapsed
# 825.652  72.049 948.281
#    user  system elapsed
# 813.998  69.895 893.054
#    user  system elapsed
# 814.250  68.083 891.534
#    user  system elapsed
# 808.959  68.068 886.543
#    user  system elapsed
# 824.023  76.430 917.470
#    user  system elapsed
# 856.033  65.341 926.597
#    user  system elapsed
# 782.460  64.309 846.852
#    user  system elapsed
# 786.251  58.082 842.286
#    user  system elapsed
# 835.136  72.144 932.507
#    user  system elapsed
# 851.160  64.580 921.506
#    user  system elapsed
# 793.382  60.421 853.792
#    user  system elapsed
# 795.562  62.465 859.202
#    user  system elapsed
# 816.235  69.619 894.211
#    user  system elapsed
# 810.615  67.104 880.467
#    user  system elapsed
# 805.376  67.348 876.546
#    user  system elapsed
# 782.821  62.751 845.008
#    user  system elapsed
# 793.831  68.879 867.266
#    user  system elapsed
# 803.395  68.819 880.574
#    user  system elapsed
# 803.001  69.066 883.198
#    user  system elapsed
# 799.717  65.456 869.530
#    user  system elapsed
# 827.128  75.534 922.332
#    user  system elapsed
# 816.822  65.920 889.299
#    user  system elapsed
# 829.541  70.949 917.382
#    user  system elapsed
# 826.863  65.411 905.159
#    user  system elapsed
# 838.136  74.862 940.863
#    user  system elapsed
# 830.565  67.732 905.989
#    user  system elapsed
# 866.465  67.563 942.936
#    user  system elapsed
# 821.117  72.043 908.817
#    user  system elapsed
# 817.945  74.149 903.024
#    user  system elapsed
# 832.253  69.885 914.353
#    user  system elapsed
# 860.774  61.685 922.850
#    user  system elapsed
# 791.737  60.751 854.861
#    user  system elapsed
# 823.464  72.415 915.307
#    user  system elapsed
# 872.404  73.414 964.378
#    user  system elapsed
# 832.035  70.863 919.825
#    user  system elapsed
# 833.907  74.452 929.980
#    user  system elapsed
# 848.450  77.004 953.356
#    user  system elapsed
# 837.267  71.972 927.552
#    user  system elapsed
# 832.545  64.331 896.306
#    user  system elapsed
# 812.962  61.003 873.511
#    user  system elapsed
# 813.545  70.907 899.696
#    user  system elapsed
# 819.460  71.602 900.294
#    user  system elapsed
# 824.713  67.069 896.528
#    user  system elapsed
# 815.798  64.214 885.937
#    user  system elapsed
# 820.393  72.640 903.221
#     user   system  elapsed
#  922.852  150.207 1171.056
#    user  system elapsed
# 833.407  74.183 917.752
#    user  system elapsed
# 785.584  56.288 838.711
#    user  system elapsed
# 823.670  64.860 890.462
#    user  system elapsed
# 818.757  62.199 885.115
#    user  system elapsed
# 797.526  59.983 855.522
#    user  system elapsed
# 836.945  60.155 897.772
#    user  system elapsed
# 782.190  59.603 842.400
#    user  system elapsed
# 818.704  66.744 896.058
#    user  system elapsed
# 812.798  63.326 880.464
#    user  system elapsed
# 803.076  59.345 869.872
#    user  system elapsed
# 827.488  70.450 911.691
#    user  system elapsed
# 819.788  62.903 896.463
#    user  system elapsed
# 828.959  74.102 945.567
#    user  system elapsed
# 801.574  64.534 875.501
#    user  system elapsed
# 783.858  53.443 833.564
#    user  system elapsed
# 796.539  53.547 846.310
#    user  system elapsed
# 782.723  51.033 828.931
#    user  system elapsed
# 771.116  49.628 815.532
#    user  system elapsed
# 780.534  53.498 829.286
#    user  system elapsed
# 785.028  52.385 832.519
#    user  system elapsed
# 774.378  51.847 821.019
#    user  system elapsed
# 775.749  49.327 819.822
#    user  system elapsed
# 772.522  51.950 819.245
#    user  system elapsed
# 774.766  50.241 820.126
#    user  system elapsed
# 772.303  51.324 818.879
#    user  system elapsed
# 776.204  50.070 820.152
#    user  system elapsed
# 770.831  53.337 819.301
#    user  system elapsed
# 776.113  51.401 822.380
#    user  system elapsed
# 772.155  50.637 818.137
#    user  system elapsed
# 774.773  49.463 819.100
#    user  system elapsed
# 781.465  51.545 826.898
#    user  system elapsed
# 786.473  50.326 831.501
#    user  system elapsed
# 772.877  52.485 821.648
#    user  system elapsed
# 777.417  49.513 821.532
#    user  system elapsed
# 776.490  51.059 822.089
#    user  system elapsed
# 781.949  50.810 828.159
#    user  system elapsed
# 770.197  51.615 817.685
#    user  system elapsed
# 773.056  49.407 817.495
#    user  system elapsed
# 768.859  50.876 814.471
#    user  system elapsed
# 774.908  49.538 818.850
#    user  system elapsed
# 785.549  51.648 832.915
#    user  system elapsed
# 769.508  50.179 813.992
#    user  system elapsed
# 771.746  52.495 819.605
#    user  system elapsed
# 775.385  51.317 822.050
#    user  system elapsed
# 773.946  51.537 820.490
#    user  system elapsed
# 777.753  51.169 824.129
#    user  system elapsed
# 767.068  50.902 812.815
#    user  system elapsed
# 780.299  50.834 825.684
#    user  system elapsed
# 783.140  52.134 830.121
#    user  system elapsed
# 806.981  51.546 853.954
#    user  system elapsed
# 768.984  52.108 815.868
#    user  system elapsed
# 778.361  51.632 824.966
#    user  system elapsed
# 779.565  51.677 826.115
#    user  system elapsed
# 827.121  63.321 905.044
#    user  system elapsed
# 835.810  68.872 919.634
#    user  system elapsed
# 829.751  64.964 906.779
#    user  system elapsed
# 793.928  63.554 867.186
#    user  system elapsed
# 777.844  57.353 834.017
#    user  system elapsed
# 776.660  55.817 829.152
#    user  system elapsed
# 779.269  53.885 829.638
#    user  system elapsed
# 769.614  53.243 819.369
#    user  system elapsed
# 773.540  51.551 821.791
#    user  system elapsed
# 770.799  54.090 821.839
#    user  system elapsed
# 779.551  51.865 828.419
#    user  system elapsed
# 782.647  52.836 831.932
#    user  system elapsed
# 782.999  51.410 831.081
#    user  system elapsed
# 776.103  55.870 828.706
#    user  system elapsed
# 786.714  54.451 837.757
#    user  system elapsed
# 773.747  52.843 823.581
#    user  system elapsed
# 775.476  52.416 824.226
#    user  system elapsed
# 776.561  55.183 828.449
#    user  system elapsed
# 791.204  57.642 848.232
#    user  system elapsed
# 781.738  54.690 833.924
#    user  system elapsed
# 785.777  51.943 833.705
#    user  system elapsed
# 793.075  55.070 844.890
#    user  system elapsed
# 798.983  54.206 850.661
#    user  system elapsed
# 787.334  55.714 839.957
#    user  system elapsed
# 779.012  52.510 828.333
#    user  system elapsed
# 799.031  57.507 867.683
#    user  system elapsed
# 850.026  69.148 961.130
#    user  system elapsed
# 840.193  68.101 930.009
#    user  system elapsed
# 850.489  68.059 944.314
#    user  system elapsed
# 854.365  67.905 941.483
#    user  system elapsed
# 875.109  66.045 958.909
#     user   system  elapsed
# 1047.177   97.439 1303.983
#     user   system  elapsed
# 1001.116   86.770 1181.111
#    user  system elapsed
# 847.498  69.023 938.994
#    user  system elapsed
# 818.392  64.458 896.478
#    user  system elapsed
# 804.912  59.151 868.546
#    user  system elapsed
# 812.672  62.102 878.964
#    user  system elapsed
# 805.980  58.952 865.614
#    user  system elapsed
# 811.948  57.707 871.859
#    user  system elapsed
# 787.575  53.234 836.793
#    user  system elapsed
# 778.187  50.478 823.462
#    user  system elapsed
# 787.633  54.274 847.154
#    user  system elapsed
# 860.230  70.452 953.594
#    user  system elapsed
# 872.120  69.806 958.294
#    user  system elapsed
# 855.720  63.288 934.478
#    user  system elapsed
# 793.164  62.121 859.686
#    user  system elapsed
# 784.974  56.614 839.819
#    user  system elapsed
# 752.598  58.149 810.442
#    user  system elapsed
# 649.093  50.320 695.050
#    user  system elapsed
# 678.973  57.276 764.179
#     user   system  elapsed
#  785.600  118.284 1020.116
#    user  system elapsed
# 722.386  54.168 783.074
#    user  system elapsed
# 658.661  48.842 709.889
#    user  system elapsed
# 678.530  48.599 721.389
#    user  system elapsed
# 663.766  50.455 720.610
#    user  system elapsed
# 654.689  48.528 703.870
#    user  system elapsed
# 666.253  49.640 716.816
#    user  system elapsed
# 663.322  49.977 717.223
#    user  system elapsed
# 630.376  45.788 671.963
#    user  system elapsed
# 626.659  44.966 664.146
#    user  system elapsed
# 626.323  44.582 662.878
#    user  system elapsed
# 620.578  45.013 657.594
#    user  system elapsed
# 626.903  44.499 663.557
#    user  system elapsed
# 623.111  44.210 659.748
#    user  system elapsed
# 620.577  43.418 655.896
#    user  system elapsed
# 620.846  44.060 656.977
#    user  system elapsed
# 629.109  44.211 665.379
#    user  system elapsed
# 621.052  44.149 656.831
#    user  system elapsed
# 619.666  43.384 654.920
#    user  system elapsed
# 620.981  44.727 657.455
#    user  system elapsed
# 624.810  44.636 661.412
#    user  system elapsed
# 622.154  44.176 658.386
#    user  system elapsed
# 623.542  43.833 659.037
#    user  system elapsed
# 622.042  43.680 657.330
#    user  system elapsed
# 630.616  43.881 666.414
#    user  system elapsed
# 626.616  44.227 662.797
#    user  system elapsed
# 623.412  43.316 658.747
#    user  system elapsed
# 619.502  45.199 656.346
#    user  system elapsed
# 623.494  44.367 660.052
#    user  system elapsed
# 622.340  44.112 659.167
#    user  system elapsed
# 626.278  43.616 661.439
#    user  system elapsed
# 625.443  44.137 660.815
#    user  system elapsed
# 633.788  44.467 670.354
#    user  system elapsed
# 622.665  43.752 658.810
#    user  system elapsed
# 622.209  43.313 657.277
#    user  system elapsed
# 619.090  44.474 655.626
#    user  system elapsed
# 622.753  44.639 659.348
#    user  system elapsed
# 620.232  44.425 656.738
#    user  system elapsed
# 624.142  43.212 659.224
#    user  system elapsed
# 619.919  42.874 656.499
#    user  system elapsed
# 624.340  43.551 660.017
#    user  system elapsed
# 620.636  43.929 656.383
#    user  system elapsed
# 622.733  43.440 658.092
#    user  system elapsed
# 623.119  44.883 659.965
#    user  system elapsed
# 624.452  45.016 661.655
#    user  system elapsed
# 621.722  44.069 657.874
#    user  system elapsed
# 623.624  43.700 659.211
#    user  system elapsed
# 622.292  44.288 658.220
#    user  system elapsed
# 622.854  44.017 658.972
#    user  system elapsed
# 620.277  44.273 656.186
#    user  system elapsed
# 619.887  43.455 655.299
#    user  system elapsed
# 619.698  45.023 656.763
#    user  system elapsed
# 624.398  44.824 661.282
#    user  system elapsed
# 624.272  44.526 660.983
#    user  system elapsed
# 622.515  43.788 658.056
#    user  system elapsed
# 621.521  43.721 656.818
#    user  system elapsed
# 622.765  43.655 658.221
#    user  system elapsed
# 627.033  44.805 663.687
#    user  system elapsed
# 620.518  44.107 656.475
#    user  system elapsed
# 621.716  45.228 658.594
#    user  system elapsed
# 622.944  44.821 659.603
#    user  system elapsed
# 620.706  44.301 657.107
#    user  system elapsed
# 621.079  43.712 656.757
#    user  system elapsed
# 658.189  49.199 706.829
#    user  system elapsed
# 658.755  49.195 708.588
#    user  system elapsed
# 636.990  45.874 675.547
#    user  system elapsed
# 641.881  45.424 680.204
#    user  system elapsed
# 633.005  46.293 672.573
#    user  system elapsed
# 630.641  45.302 668.074
#    user  system elapsed
# 626.744  44.672 663.261
#    user  system elapsed
# 657.964  47.923 705.305
#    user  system elapsed
# 633.326  45.627 672.106
#    user  system elapsed
# 628.590  44.636 665.348
#    user  system elapsed
# 635.284  45.919 673.501
#    user  system elapsed
# 653.997  46.736 695.951
#    user  system elapsed
# 635.819  47.705 676.727
#    user  system elapsed
# 628.971  45.175 666.243
#    user  system elapsed
# 625.188  44.676 662.046
#    user  system elapsed
# 624.354  44.232 660.534
#    user  system elapsed
# 624.692  44.099 660.560
#    user  system elapsed
# 647.372  45.369 688.027
#    user  system elapsed
# 627.470  44.657 664.269
#    user  system elapsed
# 635.732  44.478 673.088
#    user  system elapsed
# 624.972  44.859 663.820
#    user  system elapsed
# 628.686  44.965 666.038
#    user  system elapsed
# 636.824  45.927 675.231
#    user  system elapsed
# 626.693  43.864 663.374
#    user  system elapsed
# 613.878  44.404 651.518
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL
#
# [[6]]
# NULL
#
# [[7]]
# NULL
#
# [[8]]
# NULL
#
# [[9]]
# NULL
#
# [[10]]
# NULL
#
# [[11]]
# NULL
#
# [[12]]
# NULL
#
# [[13]]
# NULL
#
# [[14]]
# NULL
#
# [[15]]
# NULL
#
# [[16]]
# NULL
#
# [[17]]
# NULL
#
# [[18]]
# NULL
#
# [[19]]
# NULL
#
# [[20]]
# NULL
#
# [[21]]
# NULL
#
# [[22]]
# NULL
#
# [[23]]
# NULL
#
# [[24]]
# NULL
#
# [[25]]
# NULL
#
# [[26]]
# NULL
#
# [[27]]
# NULL
#
# [[28]]
# NULL
#
# [[29]]
# NULL
#
# [[30]]
# NULL
#
# [[31]]
# NULL
#
# [[32]]
# NULL
#
# [[33]]
# NULL
#
# [[34]]
# NULL
#
# [[35]]
# NULL
#
# [[36]]
# NULL
#
# [[37]]
# NULL
#
# [[38]]
# NULL
#
# [[39]]
# NULL
#
# [[40]]
# NULL
#
# [[41]]
# NULL
#
# [[42]]
# NULL
#
# [[43]]
# NULL
#
# [[44]]
# NULL
#
# [[45]]
# NULL
#
# [[46]]
# NULL
#
# [[47]]
# NULL
#
# [[48]]
# NULL
#
# [[49]]
# NULL
#
# [[50]]
# NULL
#
# [[51]]
# NULL
#
# [[52]]
# NULL
#
# [[53]]
# NULL
#
# [[54]]
# NULL
#
# [[55]]
# NULL
#
# [[56]]
# NULL
#
# [[57]]
# NULL
#
# [[58]]
# NULL
#
# [[59]]
# NULL
#
# [[60]]
# NULL
#
# [[61]]
# NULL
#
# [[62]]
# NULL
#
# [[63]]
# NULL
#
# [[64]]
# NULL
#
# [[65]]
# NULL
#
# [[66]]
# NULL
#
# [[67]]
# NULL
#
# [[68]]
# NULL
#
# [[69]]
# NULL
#
# [[70]]
# NULL
#
# [[71]]
# NULL
#
# [[72]]
# NULL
#
# [[73]]
# NULL
#
# [[74]]
# NULL
#
# [[75]]
# NULL
#
# [[76]]
# NULL
#
# [[77]]
# NULL
#
# [[78]]
# NULL
#
# [[79]]
# NULL
#
# [[80]]
# NULL
#
# [[81]]
# NULL
#
# [[82]]
# NULL
#
# [[83]]
# NULL
#
# [[84]]
# NULL
#
# [[85]]
# NULL
#
# [[86]]
# NULL
#
# [[87]]
# NULL
#
# [[88]]
# NULL
#
# [[89]]
# NULL
#
# [[90]]
# NULL
#
# [[91]]
# NULL
#
# [[92]]
# NULL
#
# [[93]]
# NULL
#
# [[94]]
# NULL
#
# [[95]]
# NULL
#
# [[96]]
# NULL
#
# [[97]]
# NULL
#
# [[98]]
# NULL
#
# [[99]]
# NULL
#
# [[100]]
# NULL
