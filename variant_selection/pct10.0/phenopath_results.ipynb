# %%
library("phenopath")
library("reticulate")
np <- import("numpy")

# %%
phenopath_defaults <- function(observations, covariates, ...) {
    return(suppressWarnings(phenopath(observations, covariates, model_mu=TRUE, 
                                      maxiter=50, thin=10, verbose=FALSE, ...)))
}

# %% [markdown]
# The gLV models have intercepts $\mu$, and it makes more sense conceptually that a model has them (so they can represent 'intrinsic growth rates'), so `model_mu` is being used even though it is not a default setting. Plus very preliminary investigation seemed to suggest it is likely to get better results, and one would expect that theoretically as well not just for the reasons above but also because the default `model_mu=FALSE` is actually a special case where $\mu = 0$ is assumed, so allowing extra possible values for that parameter in general can only increase the fit. (Of course one can then argue about overfitting, but that seems unlikely since this model is clearly heavily mis-specified anyway, and again the extra parameter would not only increase fit but also be amenable to biological interpretation in this context.)
#
# Regarding small number of iterations, they seem to give decent enough results in practice, all the more so given that in this context one is more interested in qualitative fit, especially correct signs and sparsity, than precise numerical values. In other words any resulting quantitative accuracy will hopefully not also correspond to substantially decreased qualitative accuracy, especially given that 50 iterations is still a decent amount. Plus from a practical perspective, in order to provide estimates for so many estimations, there needs to be a reasonably enough upper bound on the runtime for each, and that is only possible by providing a relatively small of maximum possible iterations. In practice the experimenter, who only needs to analyze the results of a single experiment, should probably not used such a low number of maximum iterations.

# %%
spearman <- function(x,y){return(cor(x,y,method='spearman'))}

# %%
size = 11
seed = 42
number_droplets = 100000
number_batches = 5
results_dirname = 'results'

base_filename = paste(results_dirname, '/', size, '_strains.seed_', 
                      seed, '.', format(number_droplets, scientific=FALSE), '_droplets.iteration_',
                      '#', '.npz', sep='')

# %%
get_results <- function(phenopath_results, true_times) {
    uncensored_results <- interaction_effects(phenopath_results)
    censored_results <- significant_interactions(phenopath_results) * uncensored_results
    pearson <- abs(cor(true_times, trajectory(phenopath_results))) # same level of support if pseudotimes are flipped
    spearman <- abs(spearman(true_times, trajectory(phenopath_results)))
    
    results <- list("uncensored_results" = uncensored_results, 
                   "censored_results" = censored_results,
                   "pearson" = pearson,
                   "spearman" = spearman)
    return(results)
}

# %%
get_results_filename <- function(base_dir, scaling, iteration_number) {
    iteration_filename = paste('iteration_', iteration_number, '.npz', sep='')
    results_dir = file.path(paste(base_dir, '/', scaling, sep=''))
    results_filename = file.path(paste(results_dir, '/', iteration_filename, sep=''))
    return(results_filename)
}

save_results <- function(results_filename, results) {
    np$savez_compressed(results_filename,
    uncensored_results = results$uncensored_results,
    censored_results = results$censored_results,
    pearson = results$pearson,
    spearman = results$spearman)
}

# %% [markdown]
# The questions that I seek to answer are at a broad level: 'How can phenopath best be applied to this problem?' and 'What settings will allow phenopath to work best?'. Admittedly though not all possible choices of settings are being considered (e.g. alternative choices of `z_init`, like the true time values or the exponentials thereof, nor centering but not scaling the data, etc.) but the idea behind that was because in practice the experimenter is only likely to be willing (or in some cases only able) to use settings which do not deviate too much from the default values, plus it is reasonable to think that default choices of e.g. `z_init` were well thought out by the developers and are likely to be useful in practice, even if not the most useful theoretically possible for this context (which would be impossible to find, at least without a lot of probably intractable theory, due to e.g. the infinite state space of options for many settings).
#
# So the specific questions reduce to: (1) does it make sense to scale the data in this context (even though the data is PCR-bias adjusted and so roughly absolute counts), (2) what makes the most sense to use as the covariates for the model, and (3) do censoring values considered "insignificant" by the phenopath model lead to increased fit (i.e. by reducing false positives)? As an additional fun question, it is also asked: does the correlation (Pearson and/or Spearman) of the computed pseudotimes with the true times of the batches have any predictive value for the performance? E.g. do the true time values have any "importance" in that sense?
#
# As for always using the log-transformed data as the values, well that is both what is recommended in the phenopath paper and in its documentation, and moreover what makes the (generative) model for phenopath most closely resemble the (integral version of) the gLV equations.
#
# create directories to store results in

# %%
all_results_dir = 'phenopath_results'
if (!dir.exists(all_results_dir)) {dir.create(all_results_dir)}

binary_results_dir = file.path(paste(all_results_dir, '/', 'binary_covariates', sep=''))
if (!dir.exists(binary_results_dir)) {dir.create(binary_results_dir)}

counts_cov_results_dir = file.path(paste(all_results_dir, '/', 'count_covariates', sep=''))
if (!dir.exists(counts_cov_results_dir)) {dir.create(counts_cov_results_dir)}

for (subdirectory in list.files(path='phenopath_results', full.names=T)) {
    scaled_results_dir = file.path(paste(subdirectory, '/', 'scaled', sep=''))
    if (!dir.exists(scaled_results_dir)) {dir.create(scaled_results_dir)}
    
    unscaled_results_dir = file.path(paste(subdirectory, '/', 'unscaled', sep=''))
    if (!dir.exists(unscaled_results_dir)) {dir.create(unscaled_results_dir)}
}

# %% [markdown]
# loop through the iterations of stored results

# %%
for (iteration_number in 1:100) {
    
    filename = gsub("#", iteration_number, base_filename)
    npzfile = np$load(filename)

    read_log_counts = npzfile[["read_log_counts"]]
    # b/c 11th species has 0% frequency for 10%
    stopifnot(sum(read_log_counts[,11])==0)
    read_log_counts <- read_log_counts[,1:10]
    
    read_init_vectors = npzfile[["read_init_vectors"]]
    # again same reason as above
    stopifnot(sum(read_init_vectors[,11])==0)
    read_init_vectors <- read_init_vectors[,1:10]
    
    # will have right dimensions b/c read_log_counts does now
    read_counts = exp(read_log_counts)*(read_log_counts != 0)    
    
    merged_droplets_per_batch <- dim(read_log_counts)[1]/number_batches
    true_times = c()
    for (i in 1:number_batches) {true_times <- append(true_times, rep(i, merged_droplets_per_batch))}
    
    start_time <- proc.time()
    binary_scaled <- phenopath_defaults(read_log_counts, read_init_vectors, scale_y=TRUE)
    results <- get_results(binary_scaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    binary_unscaled <- phenopath_defaults(read_log_counts, read_init_vectors, scale_y=FALSE)
    results <- get_results(binary_unscaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_scaled <- phenopath_defaults(read_log_counts, read_counts, scale_y=TRUE)
    results <- get_results(counts_scaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_unscaled <- phenopath_defaults(read_log_counts, read_counts, scale_y=FALSE)
    results <- get_results(counts_unscaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)

    # this is supposed to be an embarrassingly parallel for loop, so memory usage should not change with number of iterations
    # but system monitor shows memory usage continually increasing. Hadley Wickham seems to have said that calling `gc`
    # manually for garbage collection should never be necessary, but honestly at this point I don't trust R so...
    gc()    
}
# Out:
#    user  system elapsed
# 525.892  48.102 576.386
#    user  system elapsed
# 475.360  43.500 514.455
#    user  system elapsed
# 468.167  39.386 501.612
#    user  system elapsed
# 466.390  38.288 498.095
#    user  system elapsed
# 470.267  37.418 500.746
#    user  system elapsed
# 470.583  39.921 503.885
#    user  system elapsed
# 468.605  38.081 500.597
#    user  system elapsed
# 464.796  37.902 496.330
#    user  system elapsed
# 468.100  36.477 498.616
#    user  system elapsed
# 469.273  38.088 500.895
#    user  system elapsed
# 471.081  39.535 505.675
#    user  system elapsed
# 466.770  38.924 500.902
#    user  system elapsed
# 469.723  38.107 501.598
#    user  system elapsed
# 465.549  37.681 496.914
#    user  system elapsed
# 467.238  36.318 496.189
#    user  system elapsed
# 469.301  38.189 500.493
#    user  system elapsed
# 470.078  37.169 500.904
#    user  system elapsed
# 463.879  37.394 494.810
#    user  system elapsed
# 466.070  37.331 496.479
#    user  system elapsed
# 467.522  37.539 498.363
#    user  system elapsed
# 470.068  36.746 499.996
#    user  system elapsed
# 466.952  37.647 497.368
#    user  system elapsed
# 463.973  37.135 494.578
#    user  system elapsed
# 460.466  37.303 490.970
#    user  system elapsed
# 466.239  37.082 496.531
#    user  system elapsed
# 468.950  37.674 499.651
#    user  system elapsed
# 467.390  36.453 497.149
#    user  system elapsed
# 464.770  38.139 496.499
#    user  system elapsed
# 465.834  37.183 497.600
#    user  system elapsed
# 464.317  37.809 495.427
#    user  system elapsed
# 463.752  37.113 494.410
#    user  system elapsed
# 464.057  37.608 495.453
#    user  system elapsed
# 469.489  37.382 499.996
#    user  system elapsed
# 465.062  36.428 494.812
#    user  system elapsed
# 467.416  36.861 497.563
#    user  system elapsed
# 464.837  37.531 495.119
#    user  system elapsed
# 467.756  36.709 498.383
#    user  system elapsed
# 463.130  37.231 493.486
#    user  system elapsed
# 463.009  36.307 492.448
#    user  system elapsed
# 463.671  37.456 494.750
#    user  system elapsed
# 466.897  36.261 496.081
#    user  system elapsed
# 467.305  37.375 498.832
#    user  system elapsed
# 467.417  36.347 497.137
#    user  system elapsed
# 465.024  37.697 496.095
#    user  system elapsed
# 464.301  36.323 493.937
#    user  system elapsed
# 465.911  37.745 496.738
#    user  system elapsed
# 466.021  36.528 495.203
#    user  system elapsed
# 464.440  37.859 496.004
#    user  system elapsed
# 467.456  36.503 497.238
#    user  system elapsed
# 465.220  37.958 496.694
#    user  system elapsed
# 464.927  35.910 493.207
#    user  system elapsed
# 465.141  37.587 495.598
#    user  system elapsed
# 464.993  36.124 494.536
#    user  system elapsed
# 463.162  37.785 493.919
#    user  system elapsed
# 463.650  36.503 493.609
#    user  system elapsed
# 472.530  39.300 505.936
#    user  system elapsed
# 470.787  36.902 501.124
#    user  system elapsed
# 492.468  45.452 538.302
#    user  system elapsed
# 471.865  38.568 505.434
#    user  system elapsed
# 465.889  38.415 498.599
#    user  system elapsed
# 487.661  39.591 523.085
#    user  system elapsed
# 472.411  38.690 504.906
#    user  system elapsed
# 488.223  40.384 526.073
#    user  system elapsed
# 493.193  44.403 536.709
#    user  system elapsed
# 474.154  38.840 508.234
#    user  system elapsed
# 482.220  41.010 518.721
#    user  system elapsed
# 487.744  39.187 521.822
#    user  system elapsed
# 484.156  40.043 519.861
#    user  system elapsed
# 487.321  38.744 522.272
#    user  system elapsed
# 496.635  41.986 535.290
#    user  system elapsed
# 490.210  41.792 529.833
#    user  system elapsed
# 499.041  43.143 540.535
#    user  system elapsed
# 495.458  40.816 532.974
#    user  system elapsed
# 499.643  46.960 554.549
#    user  system elapsed
# 493.667  43.430 536.334
#    user  system elapsed
# 474.941  40.001 508.910
#    user  system elapsed
# 474.685  38.241 507.364
#    user  system elapsed
# 473.415  40.497 508.365
#    user  system elapsed
# 474.875  38.678 508.615
#    user  system elapsed
# 487.421  43.035 528.883
#    user  system elapsed
# 495.278  42.907 541.682
#    user  system elapsed
# 486.230  41.598 526.048
#    user  system elapsed
# 490.773  42.306 536.121
#    user  system elapsed
# 492.995  43.742 539.662
#    user  system elapsed
# 501.243  44.449 551.031
#    user  system elapsed
# 497.305  44.916 545.291
#    user  system elapsed
# 485.745  39.511 520.463
#    user  system elapsed
# 496.509  43.124 541.712
#    user  system elapsed
# 497.452  42.892 540.097
#    user  system elapsed
# 502.557  45.082 552.005
#    user  system elapsed
# 504.880  45.898 554.015
#    user  system elapsed
# 493.707  45.097 538.303
#    user  system elapsed
# 504.980  43.727 550.023
#    user  system elapsed
# 494.284  42.761 535.638
#    user  system elapsed
# 497.526  42.560 543.097
#    user  system elapsed
# 483.645  40.443 521.884
#    user  system elapsed
# 480.364  38.764 512.640
#    user  system elapsed
# 477.421  39.780 511.743
#    user  system elapsed
# 487.485  40.474 524.166
#    user  system elapsed
# 507.140  44.884 556.111
#    user  system elapsed
# 533.429  46.806 594.477
#    user  system elapsed
# 516.958  47.431 567.872
#    user  system elapsed
# 507.832  46.115 562.101
#    user  system elapsed
# 484.024  42.462 523.505
#    user  system elapsed
# 486.122  42.344 529.922
#    user  system elapsed
# 469.847  39.536 503.484
#    user  system elapsed
# 468.457  37.848 499.741
#    user  system elapsed
# 471.079  39.455 504.348
#    user  system elapsed
# 469.515  36.788 499.773
#    user  system elapsed
# 468.174  37.666 499.676
#    user  system elapsed
# 469.480  38.095 501.009
#    user  system elapsed
# 470.349  39.059 503.750
#    user  system elapsed
# 474.693  39.221 508.160
#    user  system elapsed
# 472.120  39.665 505.666
#    user  system elapsed
# 472.252  37.995 503.663
#    user  system elapsed
# 477.095  39.625 510.671
#    user  system elapsed
# 497.268  39.885 534.076
#    user  system elapsed
# 505.437  45.911 555.109
#    user  system elapsed
# 534.616  48.657 594.425
#    user  system elapsed
# 527.740  48.877 586.278
#    user  system elapsed
# 528.667  45.904 585.282
#    user  system elapsed
# 517.901  45.315 570.028
#    user  system elapsed
# 477.016  38.483 509.211
#    user  system elapsed
# 478.180  39.657 512.555
#    user  system elapsed
# 480.593  37.932 513.713
#    user  system elapsed
# 507.377  46.034 552.795
#    user  system elapsed
# 474.144  39.067 508.724
#    user  system elapsed
# 470.979  38.606 503.615
#    user  system elapsed
# 479.914  38.914 512.790
#    user  system elapsed
# 530.804  55.321 589.707
#    user  system elapsed
# 528.862  50.322 589.540
#    user  system elapsed
# 483.993  40.818 524.773
#    user  system elapsed
# 473.722  37.344 503.983
#    user  system elapsed
# 488.684  42.447 534.621
#    user  system elapsed
# 478.598  39.215 511.754
#    user  system elapsed
# 508.222  48.419 568.441
#    user  system elapsed
# 545.658  49.957 617.455
#    user  system elapsed
# 555.099  56.336 638.186
#    user  system elapsed
# 532.420  49.256 598.904
#    user  system elapsed
# 503.009  47.476 559.795
#    user  system elapsed
# 508.676  46.255 559.035
#    user  system elapsed
# 510.639  46.339 567.326
#    user  system elapsed
# 505.353  49.651 561.872
#    user  system elapsed
# 494.124  41.915 532.116
#    user  system elapsed
# 494.014  40.700 531.278
#    user  system elapsed
# 494.975  41.233 533.375
#    user  system elapsed
# 492.532  42.467 533.335
#    user  system elapsed
# 493.894  46.138 544.281
#    user  system elapsed
# 506.596  46.181 560.651
#    user  system elapsed
# 509.275  48.491 570.813
#    user  system elapsed
# 508.039  43.640 557.250
#    user  system elapsed
# 513.691  45.631 567.688
#    user  system elapsed
# 515.477  44.041 569.664
#    user  system elapsed
# 498.643  44.493 547.301
#    user  system elapsed
# 466.440  38.897 498.944
#    user  system elapsed
# 460.951  37.345 495.249
#    user  system elapsed
# 465.119  37.007 495.647
#    user  system elapsed
# 463.634  38.193 495.587
#    user  system elapsed
# 466.134  36.528 495.381
#    user  system elapsed
# 464.433  37.754 495.397
#    user  system elapsed
# 465.584  35.921 494.392
#    user  system elapsed
# 461.522  37.058 491.947
#    user  system elapsed
# 460.912  35.972 489.667
#    user  system elapsed
# 469.091  38.427 501.303
#    user  system elapsed
# 465.403  36.580 495.506
#    user  system elapsed
# 462.035  37.510 492.940
#    user  system elapsed
# 459.257  36.472 488.629
#    user  system elapsed
# 463.307  37.511 493.911
#    user  system elapsed
# 464.875  35.967 493.791
#    user  system elapsed
# 463.088  37.227 493.486
#    user  system elapsed
# 460.170  36.104 488.990
#    user  system elapsed
# 457.351  37.478 488.490
#    user  system elapsed
# 462.531  36.563 491.819
#    user  system elapsed
# 463.293  37.796 494.283
#    user  system elapsed
# 461.766  36.418 491.275
#    user  system elapsed
# 460.768  37.222 491.395
#    user  system elapsed
# 463.259  36.141 493.701
#    user  system elapsed
# 462.296  37.311 492.408
#    user  system elapsed
# 460.690  36.564 490.031
#    user  system elapsed
# 463.402  37.640 494.076
#    user  system elapsed
# 462.563  36.510 492.235
#    user  system elapsed
# 463.073  37.378 493.311
#    user  system elapsed
# 459.634  36.501 488.332
#    user  system elapsed
# 461.356  37.528 492.070
#    user  system elapsed
# 464.052  35.957 493.131
#    user  system elapsed
# 461.908  36.991 492.525
#    user  system elapsed
# 460.132  36.256 489.188
#    user  system elapsed
# 457.289  36.599 489.036
#    user  system elapsed
# 463.183  36.317 491.974
#    user  system elapsed
# 461.595  37.461 492.204
#    user  system elapsed
# 461.853  36.613 491.104
#    user  system elapsed
# 460.228  37.633 490.962
#    user  system elapsed
# 461.921  36.610 491.291
#    user  system elapsed
# 462.799  37.663 494.034
#    user  system elapsed
# 461.206  36.598 490.491
#    user  system elapsed
# 461.672  36.839 492.143
#    user  system elapsed
# 464.047  36.857 493.287
#    user  system elapsed
# 460.853  37.081 491.355
#    user  system elapsed
# 459.389  36.590 488.372
#    user  system elapsed
# 461.295  37.477 492.051
#    user  system elapsed
# 461.363  36.543 490.753
#    user  system elapsed
# 462.562  37.343 493.158
#    user  system elapsed
# 458.785  36.444 487.907
#    user  system elapsed
# 459.047  37.220 489.640
#    user  system elapsed
# 463.413  36.605 493.454
#    user  system elapsed
# 460.425  37.380 491.204
#    user  system elapsed
# 460.881  36.673 490.022
#    user  system elapsed
# 458.332  37.621 488.992
#    user  system elapsed
# 461.416  35.960 490.863
#    user  system elapsed
# 463.656  37.315 493.812
#    user  system elapsed
# 463.583  36.592 492.775
#    user  system elapsed
# 461.071  37.041 491.701
#    user  system elapsed
# 459.685  35.561 488.333
#    user  system elapsed
# 460.430  37.215 490.750
#    user  system elapsed
# 461.267  36.242 490.600
#    user  system elapsed
# 467.501  39.235 501.908
#    user  system elapsed
# 484.232  39.130 517.887
#    user  system elapsed
# 483.085  39.927 517.069
#    user  system elapsed
# 470.121  37.207 501.132
#    user  system elapsed
# 474.822  39.094 507.944
#    user  system elapsed
# 488.810  38.907 521.946
#    user  system elapsed
# 478.228  38.684 511.478
#    user  system elapsed
# 479.484  39.179 512.458
#    user  system elapsed
# 479.361  39.056 512.802
#    user  system elapsed
# 485.405  38.527 518.057
#    user  system elapsed
# 473.328  38.217 505.657
#    user  system elapsed
# 465.968  37.178 495.380
#    user  system elapsed
# 463.773  37.754 495.014
#    user  system elapsed
# 465.112  36.199 494.987
#    user  system elapsed
# 465.066  37.223 495.891
#    user  system elapsed
# 462.580  36.767 492.242
#    user  system elapsed
# 463.454  38.075 494.638
#    user  system elapsed
# 478.686  38.428 510.720
#    user  system elapsed
# 474.958  39.125 507.869
#    user  system elapsed
# 463.659  36.602 493.619
#    user  system elapsed
# 465.660  37.747 497.045
#    user  system elapsed
# 467.436  36.815 497.401
#    user  system elapsed
# 465.657  38.050 496.851
#    user  system elapsed
# 464.359  36.413 493.866
#    user  system elapsed
# 464.609  37.402 494.760
#    user  system elapsed
# 468.949  36.546 498.615
#    user  system elapsed
# 470.773  38.465 502.548
#    user  system elapsed
# 501.633  43.321 543.073
#    user  system elapsed
# 470.548  37.854 503.450
#    user  system elapsed
# 480.330  38.037 512.884
#    user  system elapsed
# 474.857  38.540 507.636
#    user  system elapsed
# 492.536  39.744 527.171
#    user  system elapsed
# 468.479  38.364 500.159
#    user  system elapsed
# 468.785  36.722 498.523
#    user  system elapsed
# 469.779  37.884 502.920
#    user  system elapsed
# 528.312  48.644 601.050
#    user  system elapsed
# 522.807  48.040 580.887
#    user  system elapsed
# 521.689  45.871 580.728
#    user  system elapsed
# 515.617  46.163 566.003
#    user  system elapsed
# 486.574  40.585 530.848
#    user  system elapsed
# 481.469  40.215 517.648
#    user  system elapsed
# 509.025  43.181 554.365
#    user  system elapsed
# 491.435  42.335 533.609
#    user  system elapsed
# 498.812  41.806 545.743
#    user  system elapsed
# 493.666  43.795 536.054
#    user  system elapsed
# 492.719  41.674 531.841
#    user  system elapsed
# 474.866  38.981 507.795
#    user  system elapsed
# 474.379  37.522 505.642
#    user  system elapsed
# 476.287  39.521 510.868
#    user  system elapsed
# 478.791  39.418 513.084
#    user  system elapsed
# 476.638  39.062 509.763
#    user  system elapsed
# 474.516  37.764 505.069
#    user  system elapsed
# 475.472  39.135 509.040
#    user  system elapsed
# 482.338  39.268 515.718
#    user  system elapsed
# 475.668  38.407 508.314
#    user  system elapsed
# 480.414  38.415 513.520
#    user  system elapsed
# 476.344  39.560 510.874
#    user  system elapsed
# 477.120  37.147 507.873
#    user  system elapsed
# 478.332  38.914 510.775
#    user  system elapsed
# 474.519  38.432 506.837
#    user  system elapsed
# 474.977  38.866 507.392
#    user  system elapsed
# 475.667  37.228 506.369
#    user  system elapsed
# 478.376  38.197 511.138
#    user  system elapsed
# 480.717  39.312 514.266
#    user  system elapsed
# 483.213  42.730 526.206
#    user  system elapsed
# 473.524  37.897 505.234
#    user  system elapsed
# 474.676  39.337 508.947
#    user  system elapsed
# 473.355  37.494 504.960
#    user  system elapsed
# 508.219  47.429 572.382
#    user  system elapsed
# 488.739  40.926 526.812
#    user  system elapsed
# 492.498  41.549 530.505
#    user  system elapsed
# 502.587  41.851 546.797
#    user  system elapsed
# 508.516  44.323 561.434
#    user  system elapsed
# 497.455  40.963 540.482
#    user  system elapsed
# 509.114  43.790 552.848
#    user  system elapsed
# 527.508  47.612 586.586
#    user  system elapsed
# 537.506  46.513 588.670
#    user  system elapsed
# 532.996  42.451 575.831
#    user  system elapsed
# 508.380  41.114 547.197
#    user  system elapsed
# 507.744  40.363 544.869
#    user  system elapsed
# 530.885  45.780 582.501
#    user  system elapsed
# 544.764  44.831 599.223
#    user  system elapsed
# 522.094  44.576 572.973
#    user  system elapsed
# 536.598  46.966 601.116
#    user  system elapsed
# 546.053  49.006 612.525
#    user  system elapsed
# 508.063  41.522 547.976
#    user  system elapsed
# 490.992  41.149 528.320
#    user  system elapsed
# 501.777  42.824 544.724
#    user  system elapsed
# 520.511  43.438 565.905
#    user  system elapsed
# 532.240  49.436 591.541
#    user  system elapsed
# 485.036  40.260 520.587
#    user  system elapsed
# 488.183  40.773 524.603
#    user  system elapsed
# 515.062  43.769 564.416
#    user  system elapsed
# 525.825  49.484 604.025
#    user  system elapsed
# 504.239  44.481 554.129
#    user  system elapsed
# 509.365  45.560 564.935
#    user  system elapsed
# 475.728  39.699 509.439
#    user  system elapsed
# 519.287  42.456 562.790
#    user  system elapsed
# 507.510  43.658 552.219
#    user  system elapsed
# 512.934  45.972 571.427
#    user  system elapsed
# 486.843  41.306 527.998
#    user  system elapsed
# 473.749  38.075 505.048
#    user  system elapsed
# 470.824  39.259 504.289
#    user  system elapsed
# 469.270  37.777 500.562
#    user  system elapsed
# 463.578  37.571 494.787
#    user  system elapsed
# 470.095  36.675 500.014
#    user  system elapsed
# 469.057  38.243 500.418
#    user  system elapsed
# 467.721  37.146 498.695
#    user  system elapsed
# 464.580  37.939 495.737
#    user  system elapsed
# 468.274  37.166 499.041
#    user  system elapsed
# 467.920  38.154 500.263
#    user  system elapsed
# 463.029  36.474 493.220
#    user  system elapsed
# 464.725  37.827 495.871
#    user  system elapsed
# 468.469  36.149 498.516
#    user  system elapsed
# 465.947  38.094 497.379
#    user  system elapsed
# 470.051  37.863 501.689
#    user  system elapsed
# 468.021  38.695 500.908
#    user  system elapsed
# 469.492  37.832 500.983
#    user  system elapsed
# 466.142  38.517 498.003
#    user  system elapsed
# 467.272  36.669 497.510
#    user  system elapsed
# 465.298  37.718 495.880
#    user  system elapsed
# 468.641  36.793 498.824
#    user  system elapsed
# 462.629  37.487 493.806
#    user  system elapsed
# 469.196  37.914 500.961
#    user  system elapsed
# 464.259  37.652 495.766
#    user  system elapsed
# 467.633  36.776 497.469
#    user  system elapsed
# 463.862  37.205 494.470
#    user  system elapsed
# 465.298  37.303 495.114
#    user  system elapsed
# 467.924  38.085 499.766
#    user  system elapsed
# 467.859  36.660 497.851
#    user  system elapsed
# 464.705  38.179 496.867
#    user  system elapsed
# 465.091  37.189 495.936
#    user  system elapsed
# 463.405  37.878 495.261
#    user  system elapsed
# 466.812  37.317 497.326
#    user  system elapsed
# 466.083  37.990 497.229
#    user  system elapsed
# 466.161  36.335 495.123
#    user  system elapsed
# 462.609  37.529 493.416
#    user  system elapsed
# 465.226  37.356 495.544
#    user  system elapsed
# 465.941  37.559 497.585
#    user  system elapsed
# 467.680  37.934 499.205
#    user  system elapsed
# 462.754  36.933 493.115
#    user  system elapsed
# 464.486  36.973 495.547
#    user  system elapsed
# 464.935  37.357 495.453
#    user  system elapsed
# 464.247  37.129 494.256
#    user  system elapsed
# 463.911  37.427 494.878
#    user  system elapsed
# 469.454  36.893 500.284
#    user  system elapsed
# 467.556  38.299 499.173
#    user  system elapsed
# 464.829  36.773 494.636
#    user  system elapsed
# 462.138  37.119 493.855
#    user  system elapsed
# 468.233  36.859 499.756
#    user  system elapsed
# 467.285  38.077 501.739
#    user  system elapsed
# 465.026  36.785 496.019
#    user  system elapsed
# 467.660  37.519 499.711
#    user  system elapsed
# 467.450  36.634 498.219
#    user  system elapsed
# 466.852  37.571 498.541
#    user  system elapsed
# 463.957  36.351 493.986
#    user  system elapsed
# 463.113  37.810 494.007
#    user  system elapsed
# 463.236  37.658 494.136
#    user  system elapsed
# 462.852  37.923 494.338
#    user  system elapsed
# 466.577  37.161 497.496
#    user  system elapsed
# 464.031  38.223 495.804
#    user  system elapsed
# 466.492  36.386 495.956
#    user  system elapsed
# 461.625  36.858 491.805
#    user  system elapsed
# 464.659  37.256 495.014
#    user  system elapsed
# 463.170  37.490 493.781
#    user  system elapsed
# 466.912  36.872 496.794
#    user  system elapsed
# 462.654  37.368 493.433
#    user  system elapsed
# 466.066  36.229 496.359
#    user  system elapsed
# 464.063  37.878 494.979
#    user  system elapsed
# 466.557  37.400 497.120
#    user  system elapsed
# 464.400  37.055 494.895
#    user  system elapsed
# 465.845  38.300 496.698
#    user  system elapsed
# 464.875  37.391 495.339
#    user  system elapsed
# 468.116  37.477 498.639
#    user  system elapsed
# 467.389  37.525 498.878
#    user  system elapsed
# 486.798  44.283 529.309
#    user  system elapsed
# 554.128  65.416 641.186
#    user  system elapsed
# 511.522  65.156 595.110
#    user  system elapsed
# 471.216  40.986 505.997
#    user  system elapsed
# 479.551  38.139 512.244
#    user  system elapsed
# 483.921  40.594 518.789
#    user  system elapsed
# 487.306  40.406 524.410
#    user  system elapsed
# 498.427  41.780 545.025
#    user  system elapsed
# 484.364  39.672 522.370
#    user  system elapsed
# 461.587  39.032 495.346
