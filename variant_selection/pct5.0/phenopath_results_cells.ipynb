# %%
library("phenopath")
library("reticulate")
np <- import("numpy")

# %% [markdown]
# I am not sure whether the CAVI optimization from phenopath is completely deterministic, so I'm not sure whether the following cell would have actually been necessary for complete reproducibility. Nevertheless, I should have included this in the original notebooks.

# %%
set.seed(42)

# %%
phenopath_defaults <- function(observations, covariates, ...) {
    # suppressWarnings because I am well aware that it hasn't converged
    return(suppressWarnings(phenopath(observations, covariates, model_mu=TRUE, 
                                      maxiter=50, thin=10, verbose=FALSE, ...)))
}

# %% [markdown]
# The gLV models have intercepts $\mu$, and it makes more sense conceptually that a model has them (so they can represent 'intrinsic growth rates'), so `model_mu` is being used even though it is not a default setting. Plus very preliminary investigation seemed to suggest it is likely to get better results, and one would expect that theoretically as well not just for the reasons above but also because the default `model_mu=FALSE` is actually a special case where $\mu = 0$ is assumed, so allowing extra possible values for that parameter in general can only increase the fit. (Of course one can then argue about overfitting, but that seems unlikely since this model is clearly heavily mis-specified anyway, and again the extra parameter would not only increase fit but also be amenable to biological interpretation in this context.)
#
# Regarding small number of iterations, they seem to give decent enough results in practice, all the more so given that in this context one is more interested in qualitative fit, especially correct signs and sparsity, than precise numerical values. In other words any resulting quantitative accuracy will hopefully not also correspond to substantially decreased qualitative accuracy, especially given that 50 iterations is still a decent amount. Plus from a practical perspective, in order to provide estimates for so many estimations, there needs to be a reasonably enough upper bound on the runtime for each, and that is only possible by providing a relatively small of maximum possible iterations. In practice the experimenter, who only needs to analyze the results of a single experiment, should probably not used such a low number of maximum iterations.

# %%
spearman <- function(x,y){return(cor(x,y,method='spearman'))}

# %%
size = 11
seed = 42
number_droplets = 100000
number_batches = 5
results_dirname = 'results'

base_filename = paste(results_dirname, '/', size, '_strains.seed_', 
                      seed, '.', format(number_droplets, scientific=FALSE), '_droplets.iteration_',
                      '#', '.npz', sep='')

# %%
get_results <- function(phenopath_results, true_times) {
    uncensored_results <- interaction_effects(phenopath_results)
    censored_results <- significant_interactions(phenopath_results) * uncensored_results
    pearson <- abs(cor(true_times, trajectory(phenopath_results))) # same level of support if pseudotimes are flipped
    spearman <- abs(spearman(true_times, trajectory(phenopath_results)))
    
    results <- list("uncensored_results" = uncensored_results, 
                   "censored_results" = censored_results,
                   "pearson" = pearson,
                   "spearman" = spearman)
    return(results)
}

# %%
get_results_filename <- function(base_dir, scaling, iteration_number) {
    iteration_filename = paste('iteration_', iteration_number, '.npz', sep='')
    results_dir = file.path(paste(base_dir, '/', scaling, sep=''))
    results_filename = file.path(paste(results_dir, '/', iteration_filename, sep=''))
    return(results_filename)
}

save_results <- function(results_filename, results) {
    np$savez_compressed(results_filename,
    uncensored_results = results$uncensored_results,
    censored_results = results$censored_results,
    pearson = results$pearson,
    spearman = results$spearman)
}

# %% [markdown]
# The questions that I seek to answer are at a broad level: 'How can phenopath best be applied to this problem?' and 'What settings will allow phenopath to work best?'. Admittedly though not all possible choices of settings are being considered (e.g. alternative choices of `z_init`, like the true time values or the exponentials thereof, nor centering but not scaling the data, etc.) but the idea behind that was because in practice the experimenter is only likely to be willing (or in some cases only able) to use settings which do not deviate too much from the default values, plus it is reasonable to think that default choices of e.g. `z_init` were well thought out by the developers and are likely to be useful in practice, even if not the most useful theoretically possible for this context (which would be impossible to find, at least without a lot of probably intractable theory, due to e.g. the infinite state space of options for many settings).
#
# So the specific questions reduce to: (1) does it make sense to scale the data in this context (even though the data is PCR-bias adjusted and so roughly absolute counts), (2) what makes the most sense to use as the covariates for the model, and (3) do censoring values considered "insignificant" by the phenopath model lead to increased fit (i.e. by reducing false positives)? As an additional fun question, it is also asked: does the correlation (Pearson and/or Spearman) of the computed pseudotimes with the true times of the batches have any predictive value for the performance? E.g. do the true time values have any "importance" in that sense?
#
# As for always using the log-transformed data as the values, well that is both what is recommended in the phenopath paper and in its documentation, and moreover what makes the (generative) model for phenopath most closely resemble the (integral version of) the gLV equations.
#
# create directories to store results in

# %%
all_results_dir = 'phenopath_results_cells'
if (!dir.exists(all_results_dir)) {dir.create(all_results_dir)}

binary_results_dir = file.path(paste(all_results_dir, '/', 'binary_covariates', sep=''))
if (!dir.exists(binary_results_dir)) {dir.create(binary_results_dir)}

counts_cov_results_dir = file.path(paste(all_results_dir, '/', 'count_covariates', sep=''))
if (!dir.exists(counts_cov_results_dir)) {dir.create(counts_cov_results_dir)}

for (subdirectory in list.files(path=all_results_dir, full.names=T)) {
    scaled_results_dir = file.path(paste(subdirectory, '/', 'scaled', sep=''))
    if (!dir.exists(scaled_results_dir)) {dir.create(scaled_results_dir)}
    
    unscaled_results_dir = file.path(paste(subdirectory, '/', 'unscaled', sep=''))
    if (!dir.exists(unscaled_results_dir)) {dir.create(unscaled_results_dir)}
}

# %% [markdown]
# loop through the iterations of stored results

# %%
# very bad naughty code that uses lots of global variables
# this is a self-contained notebook however and not a software library.
# I don't want to rewrite the function and the function calls to unnecessarily be
# much longer when scope rules automatically do the right thing.
lapply_input <- function(iteration_number){
    
    filename = gsub("#", iteration_number, base_filename)
    npzfile = np$load(filename)

    cell_log_counts = npzfile[["cell_log_counts"]]
    cell_init_vectors = npzfile[["cell_init_vectors"]]
    cell_counts = exp(cell_log_counts)*(cell_log_counts != 0)    
    
    merged_droplets_per_batch <- dim(cell_log_counts)[1]/number_batches
    true_times = c()
    for (i in 1:number_batches) {true_times <- append(true_times, rep(i, merged_droplets_per_batch))}
    
    start_time <- proc.time()
    binary_scaled <- phenopath_defaults(cell_log_counts, cell_init_vectors, scale_y=TRUE)
    results <- get_results(binary_scaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    binary_unscaled <- phenopath_defaults(cell_log_counts, cell_init_vectors, scale_y=FALSE)
    results <- get_results(binary_unscaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_scaled <- phenopath_defaults(cell_log_counts, cell_counts, scale_y=TRUE)
    results <- get_results(counts_scaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_unscaled <- phenopath_defaults(cell_log_counts, cell_counts, scale_y=FALSE)
    results <- get_results(counts_unscaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    # this is supposed to be an embarrassingly parallel for loop, so memory usage should not change with number of iterations
    # but system monitor shows memory usage continually increasing. Hadley Wickham seems to have said that calling `gc`
    # manually for garbage collection should never be necessary, but honestly at this point I don't trust R so...
    gc()
    
    # controversial stylistically but consistent with Python style and since most programming is done
    # in Python, from a practical perspective it's better for me to use stylistic conventions that also work in Python.
    return(NULL)
}

# %%
lapply(1:100, lapply_input)
# Out:
#     user   system  elapsed
#  882.207   77.753 1015.508
#     user   system  elapsed
#  866.751   84.815 1032.103
#     user   system  elapsed
#  851.679   85.313 1009.300
#    user  system elapsed
# 835.280  74.296 930.516
#    user  system elapsed
# 825.069  71.084 917.499
#    user  system elapsed
# 818.453  64.908 896.115
#    user  system elapsed
# 824.899  58.092 891.047
#    user  system elapsed
# 810.188  62.899 883.050
#    user  system elapsed
# 814.493  62.160 885.373
#    user  system elapsed
# 811.706  61.260 884.768
#    user  system elapsed
# 822.193  58.973 881.377
#    user  system elapsed
# 817.424  59.141 874.691
#    user  system elapsed
# 823.705  65.664 907.621
#    user  system elapsed
# 823.928  69.893 916.525
#     user   system  elapsed
#  866.211  102.535 1018.710
#     user   system  elapsed
#  895.484  116.199 1089.739
#     user   system  elapsed
#  890.860  102.194 1057.158
#     user   system  elapsed
#  873.064   83.071 1005.132
#    user  system elapsed
# 845.358  64.391 912.867
#    user  system elapsed
# 818.630  68.225 894.852
#    user  system elapsed
# 841.957  78.679 960.689
#    user  system elapsed
# 806.485  71.303 887.726
#    user  system elapsed
# 838.497  74.680 930.519
#    user  system elapsed
# 838.507  79.444 944.905
#    user  system elapsed
# 815.327  73.809 900.949
#    user  system elapsed
# 821.201  73.587 907.259
#    user  system elapsed
# 818.642  68.691 895.548
#    user  system elapsed
# 824.315  73.790 913.065
#    user  system elapsed
# 826.923  76.019 919.042
#     user   system  elapsed
#  886.508   84.042 1059.734
#     user   system  elapsed
#  893.672   85.477 1076.746
#     user   system  elapsed
#  905.102   88.968 1085.777
#     user   system  elapsed
#  917.200   90.178 1126.987
#     user   system  elapsed
#  917.504   97.730 1160.690
#    user  system elapsed
# 845.373  78.577 949.178
#    user  system elapsed
# 860.653  66.812 929.066
#    user  system elapsed
# 795.227  60.640 854.128
#    user  system elapsed
# 784.870  56.315 837.864
#    user  system elapsed
# 847.547  55.030 900.985
#    user  system elapsed
# 783.438  53.595 833.831
#    user  system elapsed
# 791.032  52.730 839.897
#    user  system elapsed
# 825.564  56.834 879.200
#    user  system elapsed
# 795.061  53.497 848.035
#    user  system elapsed
# 778.655  54.167 829.458
#    user  system elapsed
# 830.090  55.459 882.466
#    user  system elapsed
# 797.893  55.456 852.444
#    user  system elapsed
# 789.826  52.202 838.407
#    user  system elapsed
# 776.710  55.157 828.704
#    user  system elapsed
# 783.870  52.314 832.092
#    user  system elapsed
# 787.413  55.208 839.050
#    user  system elapsed
# 782.096  50.651 829.594
#    user  system elapsed
# 781.919  53.043 831.716
#    user  system elapsed
# 787.541  54.220 837.984
#    user  system elapsed
# 854.684  60.276 914.425
#    user  system elapsed
# 783.358  51.634 831.656
#    user  system elapsed
# 784.426  56.047 837.678
#    user  system elapsed
# 785.948  51.885 833.279
#    user  system elapsed
# 778.210  53.590 828.124
#    user  system elapsed
# 783.555  53.796 833.266
#    user  system elapsed
# 780.725  54.790 831.274
#    user  system elapsed
# 783.848  54.549 834.976
#    user  system elapsed
# 824.888  56.451 879.613
#    user  system elapsed
# 798.715  53.634 850.753
#    user  system elapsed
# 778.827  53.168 829.309
#    user  system elapsed
# 789.567  57.965 850.531
#    user  system elapsed
# 798.665  61.476 863.880
#    user  system elapsed
# 788.406  54.645 840.458
#    user  system elapsed
# 773.475  55.063 826.465
#    user  system elapsed
# 787.967  58.952 846.654
#    user  system elapsed
# 791.025  62.576 855.532
#    user  system elapsed
# 803.531  57.287 861.769
#    user  system elapsed
# 797.371  59.604 856.564
#    user  system elapsed
# 809.388  62.307 873.411
#    user  system elapsed
# 796.725  64.060 863.846
#    user  system elapsed
# 804.607  60.937 876.095
#    user  system elapsed
# 817.956  74.243 917.804
#    user  system elapsed
# 847.075  64.037 910.304
#    user  system elapsed
# 802.395  60.566 877.330
#    user  system elapsed
# 794.489  55.241 850.977
#    user  system elapsed
# 832.028  60.700 891.250
#    user  system elapsed
# 836.674  61.488 899.269
#    user  system elapsed
# 787.554  59.485 845.681
#    user  system elapsed
# 793.370  59.928 855.815
#    user  system elapsed
# 830.269  62.003 904.252
#    user  system elapsed
# 823.787  62.023 894.470
#    user  system elapsed
# 806.671  63.377 876.785
#    user  system elapsed
# 811.566  60.611 878.404
#    user  system elapsed
# 799.678  68.383 893.597
#    user  system elapsed
# 813.923  75.350 916.620
#    user  system elapsed
# 856.550  70.408 930.417
#    user  system elapsed
# 825.784  73.147 935.829
#    user  system elapsed
# 789.946  59.619 850.248
#    user  system elapsed
# 785.489  60.693 844.537
#    user  system elapsed
# 828.270  68.098 927.649
#    user  system elapsed
# 883.898  69.715 965.011
#    user  system elapsed
# 811.436  68.524 886.738
#    user  system elapsed
# 812.998  66.207 887.539
#    user  system elapsed
# 802.954  69.527 878.370
#    user  system elapsed
# 807.236  64.046 874.597
#    user  system elapsed
# 821.148  75.561 929.386
#    user  system elapsed
# 822.916  72.766 913.523
#    user  system elapsed
# 845.711  76.016 935.695
#    user  system elapsed
# 835.960  80.712 948.262
#    user  system elapsed
# 841.368  77.231 941.637
#    user  system elapsed
# 858.941  75.784 959.343
#    user  system elapsed
# 852.609  83.503 985.107
#    user  system elapsed
# 863.063  73.626 959.328
#    user  system elapsed
# 849.095  70.020 934.765
#    user  system elapsed
# 830.052  71.414 909.707
#    user  system elapsed
# 862.727  73.404 942.858
#    user  system elapsed
# 848.666  77.132 940.556
#     user   system  elapsed
#  863.791  103.294 1018.727
#    user  system elapsed
# 842.821  61.544 905.814
#    user  system elapsed
# 838.077  67.906 917.267
#    user  system elapsed
# 839.865  74.581 927.578
#    user  system elapsed
# 842.046  74.316 935.242
#    user  system elapsed
# 863.199  77.421 977.050
#    user  system elapsed
# 838.355  77.336 935.187
#    user  system elapsed
# 870.413  75.583 963.944
#    user  system elapsed
# 849.846  82.062 966.830
#    user  system elapsed
# 833.286  76.370 940.917
#    user  system elapsed
# 831.315  71.795 929.147
#    user  system elapsed
# 841.191  76.434 948.605
#    user  system elapsed
# 844.755  80.738 971.213
#     user   system  elapsed
#  854.472   88.355 1017.400
#    user  system elapsed
# 847.218  81.553 982.915
#    user  system elapsed
# 831.913  75.592 936.918
#    user  system elapsed
# 832.463  78.272 936.438
#    user  system elapsed
# 847.131  78.740 952.812
#    user  system elapsed
# 849.751  77.821 957.071
#    user  system elapsed
# 820.891  77.703 920.215
#    user  system elapsed
# 781.380  54.650 831.781
#    user  system elapsed
# 804.669  56.564 858.617
#    user  system elapsed
# 786.308  54.679 837.395
#    user  system elapsed
# 779.436  50.278 824.860
#    user  system elapsed
# 786.554  52.460 834.680
#    user  system elapsed
# 783.518  51.676 830.966
#    user  system elapsed
# 779.148  50.686 824.679
#    user  system elapsed
# 790.531  52.019 838.138
#    user  system elapsed
# 780.401  52.667 830.811
#    user  system elapsed
# 781.539  51.345 828.135
#    user  system elapsed
# 786.692  53.064 835.268
#    user  system elapsed
# 782.039  50.925 828.450
#    user  system elapsed
# 782.392  51.316 829.387
#    user  system elapsed
# 814.983  51.499 863.050
#    user  system elapsed
# 789.638  52.632 838.197
#    user  system elapsed
# 773.840  49.425 817.757
#    user  system elapsed
# 773.622  51.625 819.979
#    user  system elapsed
# 783.021  51.657 829.641
#    user  system elapsed
# 773.745  51.218 820.927
#    user  system elapsed
# 779.133  51.224 826.627
#    user  system elapsed
# 775.988  51.933 822.757
#    user  system elapsed
# 776.503  50.467 822.234
#    user  system elapsed
# 772.642  51.274 819.004
#    user  system elapsed
# 792.049  51.719 839.449
#    user  system elapsed
# 775.593  52.828 823.138
#    user  system elapsed
# 776.806  51.401 823.949
#    user  system elapsed
# 775.940  52.850 824.871
#    user  system elapsed
# 779.285  51.555 826.663
#    user  system elapsed
# 776.585  50.475 822.050
#    user  system elapsed
# 780.735  49.883 825.060
#    user  system elapsed
# 777.311  50.845 822.269
#    user  system elapsed
# 777.907  51.033 823.972
#    user  system elapsed
# 835.878  78.688 967.741
#    user  system elapsed
# 813.831  68.372 888.695
#    user  system elapsed
# 810.722  67.068 886.520
#    user  system elapsed
# 813.666  70.496 899.720
#    user  system elapsed
# 831.185  75.366 916.308
#    user  system elapsed
# 839.604  65.472 909.362
#    user  system elapsed
# 782.315  63.400 845.169
#    user  system elapsed
# 796.411  60.403 857.344
#    user  system elapsed
# 835.857  73.343 935.685
#    user  system elapsed
# 853.967  63.435 917.241
#    user  system elapsed
# 787.786  59.691 846.688
#    user  system elapsed
# 802.188  61.942 866.372
#    user  system elapsed
# 817.535  71.948 900.771
#    user  system elapsed
# 803.992  65.374 872.135
#    user  system elapsed
# 799.029  69.323 872.072
#    user  system elapsed
# 777.582  60.863 837.164
#    user  system elapsed
# 796.386  70.222 872.206
#    user  system elapsed
# 811.052  67.672 891.026
#    user  system elapsed
# 800.012  67.369 872.326
#    user  system elapsed
# 802.069  66.396 875.956
#    user  system elapsed
# 826.817  76.486 921.315
#    user  system elapsed
# 816.579  67.449 891.981
#    user  system elapsed
# 830.473  71.437 918.239
#    user  system elapsed
# 819.695  64.595 895.340
#    user  system elapsed
# 839.613  76.769 947.167
#    user  system elapsed
# 838.831  66.497 909.003
#    user  system elapsed
# 858.514  70.497 939.653
#    user  system elapsed
# 834.556  71.973 926.804
#    user  system elapsed
# 813.530  70.192 891.591
#    user  system elapsed
# 842.738  66.915 916.255
#    user  system elapsed
# 843.807  60.727 904.209
#    user  system elapsed
# 799.874  58.264 862.160
#    user  system elapsed
# 835.510  76.931 937.601
#    user  system elapsed
# 863.273  72.271 952.044
#    user  system elapsed
# 829.900  71.543 919.648
#    user  system elapsed
# 837.053  74.694 938.181
#    user  system elapsed
# 843.622  78.401 950.468
#    user  system elapsed
# 825.082  69.378 905.907
#    user  system elapsed
# 841.879  62.266 903.335
#    user  system elapsed
# 799.741  60.036 859.631
#    user  system elapsed
# 811.988  73.573 903.369
#    user  system elapsed
# 815.838  69.014 891.593
#    user  system elapsed
# 825.588  69.950 901.388
#    user  system elapsed
# 816.640  67.919 891.796
#    user  system elapsed
# 817.258  69.668 897.613
#     user   system  elapsed
#  921.425  153.980 1178.609
#    user  system elapsed
# 825.556  69.733 900.894
#    user  system elapsed
# 786.926  53.743 837.625
#    user  system elapsed
# 836.384  64.073 903.695
#    user  system elapsed
# 798.299  58.107 859.660
#    user  system elapsed
# 814.238  58.951 871.540
#    user  system elapsed
# 819.809  57.348 877.929
#    user  system elapsed
# 786.546  61.508 848.238
#    user  system elapsed
# 821.494  67.562 899.846
#    user  system elapsed
# 809.722  62.255 877.083
#    user  system elapsed
# 811.448  60.295 876.628
#    user  system elapsed
# 826.705  70.213 914.414
#    user  system elapsed
# 816.925  64.965 891.134
#    user  system elapsed
# 830.083  76.672 950.300
#    user  system elapsed
# 794.718  60.964 857.661
#    user  system elapsed
# 780.770  53.652 829.531
#    user  system elapsed
# 808.942  53.670 858.622
#    user  system elapsed
# 779.637  51.330 825.324
#    user  system elapsed
# 774.333  49.644 818.822
#    user  system elapsed
# 787.906  53.708 836.967
#    user  system elapsed
# 783.786  51.273 830.503
#    user  system elapsed
# 776.831  51.011 823.069
#    user  system elapsed
# 774.129  49.084 818.043
#    user  system elapsed
# 774.708  51.515 820.899
#    user  system elapsed
# 777.437  49.983 822.402
#    user  system elapsed
# 773.219  51.660 819.264
#    user  system elapsed
# 773.485  49.983 817.896
#    user  system elapsed
# 770.477  53.019 818.012
#    user  system elapsed
# 775.352  50.713 820.443
#    user  system elapsed
# 774.192  51.176 819.940
#    user  system elapsed
# 777.366  49.477 821.295
#    user  system elapsed
# 793.136  51.710 840.099
#    user  system elapsed
# 787.551  50.646 833.434
#    user  system elapsed
# 774.855  51.292 821.994
#    user  system elapsed
# 788.788  50.019 833.058
#    user  system elapsed
# 778.971  51.334 825.016
#    user  system elapsed
# 782.295  50.546 828.114
#    user  system elapsed
# 769.642  51.719 817.312
#    user  system elapsed
# 772.678  49.540 816.994
#    user  system elapsed
# 770.796  50.231 815.643
#    user  system elapsed
# 778.456  50.440 823.575
#    user  system elapsed
# 784.573  52.010 831.494
#    user  system elapsed
# 777.722  50.270 822.952
#    user  system elapsed
# 772.046  52.361 819.604
#    user  system elapsed
# 777.687  51.190 824.126
#    user  system elapsed
# 777.134  52.440 825.088
#    user  system elapsed
# 774.056  50.593 820.206
#    user  system elapsed
# 771.956  50.777 817.452
#    user  system elapsed
# 783.859  50.662 829.265
#    user  system elapsed
# 801.113  51.825 848.267
#    user  system elapsed
# 794.586  51.474 841.242
#    user  system elapsed
# 777.714  52.773 824.724
#    user  system elapsed
# 779.762  50.803 825.410
#    user  system elapsed
# 810.131  56.871 869.527
#    user  system elapsed
# 838.283  67.381 919.789
#    user  system elapsed
# 830.836  66.892 910.633
#    user  system elapsed
# 836.269  67.528 922.787
#    user  system elapsed
# 776.274  58.456 832.649
#    user  system elapsed
# 782.975  56.315 838.360
#    user  system elapsed
# 775.817  54.625 826.978
#    user  system elapsed
# 777.273  55.260 829.545
#    user  system elapsed
# 768.725  52.218 817.516
#    user  system elapsed
# 771.260  52.472 820.715
#    user  system elapsed
# 775.883  53.216 825.254
#    user  system elapsed
# 781.791  51.650 830.076
#    user  system elapsed
# 779.135  53.091 829.215
#    user  system elapsed
# 781.935  53.074 832.045
#    user  system elapsed
# 779.850  53.356 830.101
#    user  system elapsed
# 787.007  54.530 837.625
#    user  system elapsed
# 771.577  52.813 820.392
#    user  system elapsed
# 781.607  54.182 832.669
#    user  system elapsed
# 773.243  52.352 822.221
#    user  system elapsed
# 792.912  57.846 849.990
#    user  system elapsed
# 778.795  53.478 828.534
#    user  system elapsed
# 788.891  52.684 837.104
#    user  system elapsed
# 800.006  56.097 852.422
#    user  system elapsed
# 799.558  53.691 849.956
#    user  system elapsed
# 779.581  55.023 830.607
#    user  system elapsed
# 776.376  52.531 825.738
#    user  system elapsed
# 822.073  62.761 906.931
#    user  system elapsed
# 856.204  70.819 963.871
#    user  system elapsed
# 838.412  65.733 926.345
#    user  system elapsed
# 859.066  68.608 952.682
#    user  system elapsed
# 857.633  71.277 946.704
#     user   system  elapsed
#  922.768   75.345 1040.320
#     user   system  elapsed
# 1066.423   99.251 1335.264
#     user   system  elapsed
#  926.556   77.625 1056.035
#    user  system elapsed
# 837.331  67.852 924.902
#    user  system elapsed
# 810.996  59.106 884.369
#    user  system elapsed
# 808.314  61.615 872.972
#    user  system elapsed
# 805.143  58.513 867.253
#    user  system elapsed
# 818.265  59.853 883.667
#    user  system elapsed
# 833.607  56.893 887.791
#    user  system elapsed
# 785.973  53.150 834.263
#    user  system elapsed
# 775.617  49.622 820.331
#    user  system elapsed
# 829.614  64.198 910.201
#    user  system elapsed
# 855.182  66.207 938.371
#    user  system elapsed
# 859.722  66.726 943.297
#    user  system elapsed
# 839.723  63.874 916.696
#    user  system elapsed
# 785.927  59.051 842.751
#    user  system elapsed
# 784.355  57.233 839.018
#    user  system elapsed
# 701.438  54.429 755.776
#    user  system elapsed
# 644.347  47.088 687.117
#    user  system elapsed
# 726.182  70.626 840.559
#    user  system elapsed
# 768.106 108.126 984.228
#    user  system elapsed
# 701.516  50.036 753.702
#    user  system elapsed
# 644.264  47.525 689.552
#    user  system elapsed
# 687.076  49.547 736.002
#    user  system elapsed
# 660.020  50.933 715.392
#    user  system elapsed
# 655.378  48.818 703.936
#    user  system elapsed
# 674.891  49.171 728.299
#    user  system elapsed
# 654.256  48.680 701.960
#    user  system elapsed
# 628.558  44.917 665.401
#    user  system elapsed
# 623.355  45.425 660.831
#    user  system elapsed
# 623.968  43.875 660.118
#    user  system elapsed
# 622.314  45.207 659.289
#    user  system elapsed
# 625.425  44.125 661.702
#    user  system elapsed
# 623.425  44.309 659.906
#    user  system elapsed
# 619.380  43.451 654.546
#    user  system elapsed
# 625.413  44.292 661.778
#    user  system elapsed
# 626.832  43.274 662.061
#    user  system elapsed
# 621.548  44.176 657.432
#    user  system elapsed
# 621.661  43.307 656.760
#    user  system elapsed
# 619.813  44.521 656.231
#    user  system elapsed
# 625.876  44.502 662.060
#    user  system elapsed
# 624.982  43.998 661.085
#    user  system elapsed
# 623.093  42.929 657.667
#    user  system elapsed
# 622.502  43.612 657.246
#    user  system elapsed
# 628.994  43.205 664.147
#    user  system elapsed
# 628.140  43.951 663.917
#    user  system elapsed
# 621.286  43.278 656.521
#    user  system elapsed
# 621.643  44.612 657.981
#    user  system elapsed
# 622.976  44.397 659.172
#    user  system elapsed
# 624.727  43.774 660.585
#    user  system elapsed
# 625.710  43.010 660.544
#    user  system elapsed
# 624.726  43.486 660.281
#    user  system elapsed
# 633.511  44.142 669.289
#    user  system elapsed
# 624.542  44.119 660.171
#    user  system elapsed
# 619.945  43.449 655.250
#    user  system elapsed
# 621.309  44.864 657.915
#    user  system elapsed
# 622.578  44.221 658.823
#    user  system elapsed
# 621.939  44.221 658.288
#    user  system elapsed
# 621.781  43.315 657.188
#    user  system elapsed
# 623.174  43.291 658.098
#    user  system elapsed
# 622.194  43.541 657.761
#    user  system elapsed
# 621.741  44.074 657.541
#    user  system elapsed
# 621.453  43.383 656.780
#    user  system elapsed
# 625.140  44.787 661.824
#    user  system elapsed
# 624.060  44.581 660.631
#    user  system elapsed
# 622.741  44.389 658.996
#    user  system elapsed
# 622.760  43.586 658.466
#    user  system elapsed
# 623.377  44.279 659.083
#    user  system elapsed
# 622.430  43.882 658.221
#    user  system elapsed
# 620.129  44.474 656.280
#    user  system elapsed
# 622.608  43.776 658.468
#    user  system elapsed
# 619.066  44.500 655.457
#    user  system elapsed
# 626.562  45.024 663.431
#    user  system elapsed
# 621.800  44.290 658.043
#    user  system elapsed
# 621.388  43.515 656.703
#    user  system elapsed
# 624.031  43.796 659.459
#    user  system elapsed
# 626.143  43.852 661.739
#    user  system elapsed
# 622.144  44.284 658.248
#    user  system elapsed
# 622.946  44.224 658.952
#    user  system elapsed
# 621.059  45.073 657.486
#    user  system elapsed
# 621.021  44.693 657.346
#    user  system elapsed
# 621.001  44.574 657.288
#    user  system elapsed
# 621.078  43.867 656.622
#    user  system elapsed
# 677.482  52.634 735.538
#    user  system elapsed
# 644.999  46.094 684.972
#    user  system elapsed
# 647.298  46.671 687.371
#    user  system elapsed
# 634.893  44.626 672.127
#    user  system elapsed
# 631.546  45.697 670.337
#    user  system elapsed
# 630.551  44.871 667.308
#    user  system elapsed
# 621.881  44.665 658.095
#    user  system elapsed
# 664.339  49.362 714.367
#    user  system elapsed
# 630.783  45.174 667.612
#    user  system elapsed
# 630.085  44.701 667.550
#    user  system elapsed
# 645.331  46.377 684.776
#    user  system elapsed
# 649.833  46.491 692.553
#    user  system elapsed
# 626.219  45.817 665.111
#    user  system elapsed
# 627.074  45.165 664.460
#    user  system elapsed
# 625.428  44.915 662.477
#    user  system elapsed
# 623.779  43.588 659.324
#    user  system elapsed
# 643.066  45.073 680.536
#    user  system elapsed
# 631.633  45.190 669.627
#    user  system elapsed
# 626.999  45.019 664.313
#    user  system elapsed
# 637.084  44.678 674.151
#    user  system elapsed
# 624.703  45.657 662.554
#    user  system elapsed
# 630.174  44.702 666.836
#    user  system elapsed
# 637.846  45.660 676.373
#    user  system elapsed
# 630.892  44.854 669.079
#    user  system elapsed
# 551.651  37.896 581.983
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL
#
# [[6]]
# NULL
#
# [[7]]
# NULL
#
# [[8]]
# NULL
#
# [[9]]
# NULL
#
# [[10]]
# NULL
#
# [[11]]
# NULL
#
# [[12]]
# NULL
#
# [[13]]
# NULL
#
# [[14]]
# NULL
#
# [[15]]
# NULL
#
# [[16]]
# NULL
#
# [[17]]
# NULL
#
# [[18]]
# NULL
#
# [[19]]
# NULL
#
# [[20]]
# NULL
#
# [[21]]
# NULL
#
# [[22]]
# NULL
#
# [[23]]
# NULL
#
# [[24]]
# NULL
#
# [[25]]
# NULL
#
# [[26]]
# NULL
#
# [[27]]
# NULL
#
# [[28]]
# NULL
#
# [[29]]
# NULL
#
# [[30]]
# NULL
#
# [[31]]
# NULL
#
# [[32]]
# NULL
#
# [[33]]
# NULL
#
# [[34]]
# NULL
#
# [[35]]
# NULL
#
# [[36]]
# NULL
#
# [[37]]
# NULL
#
# [[38]]
# NULL
#
# [[39]]
# NULL
#
# [[40]]
# NULL
#
# [[41]]
# NULL
#
# [[42]]
# NULL
#
# [[43]]
# NULL
#
# [[44]]
# NULL
#
# [[45]]
# NULL
#
# [[46]]
# NULL
#
# [[47]]
# NULL
#
# [[48]]
# NULL
#
# [[49]]
# NULL
#
# [[50]]
# NULL
#
# [[51]]
# NULL
#
# [[52]]
# NULL
#
# [[53]]
# NULL
#
# [[54]]
# NULL
#
# [[55]]
# NULL
#
# [[56]]
# NULL
#
# [[57]]
# NULL
#
# [[58]]
# NULL
#
# [[59]]
# NULL
#
# [[60]]
# NULL
#
# [[61]]
# NULL
#
# [[62]]
# NULL
#
# [[63]]
# NULL
#
# [[64]]
# NULL
#
# [[65]]
# NULL
#
# [[66]]
# NULL
#
# [[67]]
# NULL
#
# [[68]]
# NULL
#
# [[69]]
# NULL
#
# [[70]]
# NULL
#
# [[71]]
# NULL
#
# [[72]]
# NULL
#
# [[73]]
# NULL
#
# [[74]]
# NULL
#
# [[75]]
# NULL
#
# [[76]]
# NULL
#
# [[77]]
# NULL
#
# [[78]]
# NULL
#
# [[79]]
# NULL
#
# [[80]]
# NULL
#
# [[81]]
# NULL
#
# [[82]]
# NULL
#
# [[83]]
# NULL
#
# [[84]]
# NULL
#
# [[85]]
# NULL
#
# [[86]]
# NULL
#
# [[87]]
# NULL
#
# [[88]]
# NULL
#
# [[89]]
# NULL
#
# [[90]]
# NULL
#
# [[91]]
# NULL
#
# [[92]]
# NULL
#
# [[93]]
# NULL
#
# [[94]]
# NULL
#
# [[95]]
# NULL
#
# [[96]]
# NULL
#
# [[97]]
# NULL
#
# [[98]]
# NULL
#
# [[99]]
# NULL
#
# [[100]]
# NULL
