# %%
library("phenopath")
library("reticulate")
np <- import("numpy")

# %%
set.seed(42)

# %%
phenopath_defaults <- function(observations, covariates, ...) {
    # suppressWarnings because I am well aware that it hasn't converged
    return(suppressWarnings(phenopath(observations, covariates, model_mu=TRUE, 
                                      maxiter=50, thin=10, verbose=FALSE, ...)))
}

# %%
spearman <- function(x,y){return(cor(x,y,method='spearman'))}

# %%
size = 11
seed = 42
number_droplets = 100000
number_batches = 5
results_dirname = 'results'

base_filename = paste(results_dirname, '/', size, '_strains.seed_', 
                      seed, '.', format(number_droplets, scientific=FALSE), '_droplets.iteration_',
                      '#', '.npz', sep='')

# %%
get_results <- function(phenopath_results, true_times) {
    uncensored_results <- interaction_effects(phenopath_results)
    censored_results <- significant_interactions(phenopath_results) * uncensored_results
    pearson <- abs(cor(true_times, trajectory(phenopath_results))) # same level of support if pseudotimes are flipped
    spearman <- abs(spearman(true_times, trajectory(phenopath_results)))
    
    results <- list("uncensored_results" = uncensored_results, 
                   "censored_results" = censored_results,
                   "pearson" = pearson,
                   "spearman" = spearman)
    return(results)
}

# %%
get_results_filename <- function(base_dir, scaling, iteration_number) {
    iteration_filename = paste('iteration_', iteration_number, '.npz', sep='')
    results_dir = file.path(paste(base_dir, '/', scaling, sep=''))
    results_filename = file.path(paste(results_dir, '/', iteration_filename, sep=''))
    return(results_filename)
}

save_results <- function(results_filename, results) {
    np$savez_compressed(results_filename,
    uncensored_results = results$uncensored_results,
    censored_results = results$censored_results,
    pearson = results$pearson,
    spearman = results$spearman)
}

# %%
all_results_dir = 'phenopath_results'
if (!dir.exists(all_results_dir)) {dir.create(all_results_dir)}

log_counts_cov_results_dir = file.path(paste(all_results_dir, '/', 'log_count_covariates', sep=''))
if (!dir.exists(log_counts_cov_results_dir)) {dir.create(log_counts_cov_results_dir)}

for (subdirectory in list.files(path=all_results_dir, full.names=T)) {
    scaled_results_dir = file.path(paste(subdirectory, '/', 'scaled', sep=''))
    if (!dir.exists(scaled_results_dir)) {dir.create(scaled_results_dir)}
    
    unscaled_results_dir = file.path(paste(subdirectory, '/', 'unscaled', sep=''))
    if (!dir.exists(unscaled_results_dir)) {dir.create(unscaled_results_dir)}
}

# %% [markdown]
# loop through the iterations of stored results

# %%
# very bad naughty code that uses lots of global variables
# this is a self-contained notebook however and not a software library.
# I don't want to rewrite the function and the function calls to unnecessarily be
# much longer when scope rules automatically do the right thing.
lapply_input <- function(iteration_number){
    
    filename = gsub("#", iteration_number, base_filename)
    npzfile = np$load(filename)

    read_log_counts = npzfile[["read_log_counts"]]
    
    merged_droplets_per_batch <- dim(read_log_counts)[1]/number_batches
    true_times = c()
    for (i in 1:number_batches) {true_times <- append(true_times, rep(i, merged_droplets_per_batch))}
    
    start_time <- proc.time()
    log_counts_scaled <- phenopath_defaults(read_log_counts, read_log_counts, scale_y=TRUE)
    results <- get_results(log_counts_scaled, true_times)
    save_results(get_results_filename(log_counts_cov_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    log_counts_unscaled <- phenopath_defaults(read_log_counts, read_log_counts, scale_y=FALSE)
    results <- get_results(log_counts_unscaled, true_times)
    save_results(get_results_filename(log_counts_cov_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    # this is supposed to be an embarrassingly parallel for loop, so memory usage should not change with number of iterations
    # but system monitor shows memory usage continually increasing. Hadley Wickham seems to have said that calling `gc`
    # manually for garbage collection should never be necessary, but honestly at this point I don't trust R so...
    gc()
    
    # controversial stylistically but consistent with Python style and since most programming is done
    # in Python, from a practical perspective it's better for me to use stylistic conventions that also work in Python.
    return(NULL)
}

# %%
lapply(1:100, lapply_input)
# Out:
#    user  system elapsed
# 648.438  41.657 691.755
#    user  system elapsed
# 763.944  53.226 833.414
#    user  system elapsed
# 766.061  55.068 832.888
#    user  system elapsed
# 753.824  58.095 825.449
#    user  system elapsed
# 775.606  55.125 844.695
#    user  system elapsed
# 742.735  52.936 800.238
#    user  system elapsed
# 737.006  47.785 782.154
#    user  system elapsed
# 739.991  44.558 778.873
#    user  system elapsed
# 744.656  45.381 784.744
#    user  system elapsed
# 736.969  46.475 778.099
#    user  system elapsed
# 741.282  44.802 780.078
#    user  system elapsed
# 740.834  44.736 780.426
#    user  system elapsed
# 766.621  52.811 826.449
#    user  system elapsed
# 832.850  81.069 964.183
#    user  system elapsed
# 824.505  83.208 947.315
#    user  system elapsed
# 799.496  74.932 901.730
#    user  system elapsed
# 786.107  66.899 868.519
#    user  system elapsed
# 776.826  70.070 862.801
#    user  system elapsed
# 760.444  55.999 819.655
#    user  system elapsed
# 774.792  66.357 854.451
#    user  system elapsed
# 790.325  61.875 872.625
#    user  system elapsed
# 771.375  53.090 832.733
#    user  system elapsed
# 780.600  60.381 862.098
#    user  system elapsed
# 840.495  69.796 951.754
#    user  system elapsed
# 820.822  70.729 925.215
#    user  system elapsed
# 789.725  69.222 886.507
#    user  system elapsed
# 787.579  61.131 863.447
#    user  system elapsed
# 768.003  58.197 845.016
#    user  system elapsed
# 781.699  59.711 846.551
#    user  system elapsed
# 785.091  65.364 892.896
#    user  system elapsed
# 808.144  63.403 883.926
#     user   system  elapsed
#  865.629  109.348 1084.729
#    user  system elapsed
# 800.113  64.982 898.450
#    user  system elapsed
# 752.477  54.631 807.848
#    user  system elapsed
# 816.561  52.675 866.566
#    user  system elapsed
# 738.614  49.049 782.642
#    user  system elapsed
# 765.913  57.316 831.465
#    user  system elapsed
# 772.808  56.196 831.990
#    user  system elapsed
# 800.121  51.005 860.682
#    user  system elapsed
# 777.720  59.428 843.301
#    user  system elapsed
# 794.418  53.338 857.095
#    user  system elapsed
# 810.767  63.892 932.716
#    user  system elapsed
# 755.667  50.697 811.070
#    user  system elapsed
# 742.758  53.397 792.075
#    user  system elapsed
# 755.774  49.892 800.246
#    user  system elapsed
# 749.406  50.778 795.481
#    user  system elapsed
# 742.896  48.019 784.778
#    user  system elapsed
# 738.412  49.310 782.676
#    user  system elapsed
# 743.848  46.541 785.249
#    user  system elapsed
#  742.87   48.24  785.25
#    user  system elapsed
# 745.392  45.691 785.477
#    user  system elapsed
# 744.156  45.426 783.274
#    user  system elapsed
# 748.717  48.547 792.089
#    user  system elapsed
# 742.148  49.529 786.504
#    user  system elapsed
# 761.545  48.452 804.387
#    user  system elapsed
# 747.752  48.086 790.446
#    user  system elapsed
# 740.772  49.852 786.097
#    user  system elapsed
# 742.647  46.482 783.875
#    user  system elapsed
# 755.246  48.255 798.182
#    user  system elapsed
# 747.054  51.123 793.576
#    user  system elapsed
# 744.115  47.756 786.477
#    user  system elapsed
# 733.883  47.782 776.194
#    user  system elapsed
# 740.653  46.260 781.095
#    user  system elapsed
# 732.576  49.047 776.013
#    user  system elapsed
# 741.215  50.321 786.808
#    user  system elapsed
# 742.580  52.163 789.932
#    user  system elapsed
# 741.268  48.295 783.932
#    user  system elapsed
# 736.395  46.793 777.516
#    user  system elapsed
# 750.191  43.697 788.694
#    user  system elapsed
# 743.887  48.106 786.530
#    user  system elapsed
# 736.020  48.922 779.756
#    user  system elapsed
# 730.870  52.104 780.518
#    user  system elapsed
# 738.864  49.356 783.196
#    user  system elapsed
# 739.184  50.323 784.665
#    user  system elapsed
# 734.918  45.049 774.843
#    user  system elapsed
# 742.052  43.379 779.653
#    user  system elapsed
# 739.610  49.205 783.100
#    user  system elapsed
# 732.705  50.595 778.049
#    user  system elapsed
# 738.304  49.352 783.070
#    user  system elapsed
# 742.358  52.174 789.400
#    user  system elapsed
# 749.206  47.869 792.168
#    user  system elapsed
# 744.779  43.344 782.560
#    user  system elapsed
# 753.347  45.427 793.385
#    user  system elapsed
# 744.354  49.178 788.126
#    user  system elapsed
# 743.008  47.928 785.972
#    user  system elapsed
# 735.830  52.722 784.559
#    user  system elapsed
# 742.310  47.344 785.080
#    user  system elapsed
# 760.048  55.238 817.450
#    user  system elapsed
# 779.081  56.410 842.184
#    user  system elapsed
# 792.741  56.291 869.362
#    user  system elapsed
# 789.536  53.358 847.674
#    user  system elapsed
# 759.071  53.017 813.123
#    user  system elapsed
# 821.803  92.803 968.030
#     user   system  elapsed
#  928.436  284.774 1525.020
#     user   system  elapsed
#  939.782  343.013 1663.432
#     user   system  elapsed
#  871.774   84.857 1010.453
#    user  system elapsed
# 750.542  50.504 798.292
#    user  system elapsed
# 765.198  60.188 832.647
#    user  system elapsed
# 770.972  55.672 824.536
#    user  system elapsed
# 769.323  59.423 827.669
#    user  system elapsed
# 766.395  52.025 815.102
#    user  system elapsed
# 763.849  55.064 825.043
#    user  system elapsed
# 760.958  51.218 810.453
#    user  system elapsed
# 756.918  53.866 810.634
#    user  system elapsed
# 797.159  47.528 847.037
#    user  system elapsed
# 819.259  60.161 902.003
#    user  system elapsed
# 802.004  50.023 852.791
#    user  system elapsed
# 751.744  53.270 805.530
#    user  system elapsed
# 771.168  48.280 817.362
#    user  system elapsed
# 763.393  49.555 810.997
#    user  system elapsed
# 762.275  53.536 816.683
#    user  system elapsed
# 786.270  50.857 839.394
#    user  system elapsed
# 768.608  49.746 817.189
#    user  system elapsed
# 768.741  53.955 823.559
#    user  system elapsed
# 767.503  53.568 822.755
#    user  system elapsed
# 761.389  62.425 830.205
#    user  system elapsed
# 768.517  51.418 821.171
#    user  system elapsed
# 790.816  56.716 851.628
#    user  system elapsed
# 796.029  60.930 867.206
#    user  system elapsed
# 752.820  47.835 796.128
#    user  system elapsed
# 760.071  56.546 823.584
#    user  system elapsed
# 743.721  54.855 795.885
#    user  system elapsed
# 745.419  53.158 795.656
#    user  system elapsed
# 741.951  47.975 784.800
#    user  system elapsed
# 749.355  51.144 797.972
#    user  system elapsed
# 748.789  51.290 796.748
#    user  system elapsed
# 752.802  51.488 801.229
#    user  system elapsed
# 743.853  49.551 789.567
#    user  system elapsed
# 753.068  47.792 795.944
#    user  system elapsed
# 768.430  59.454 844.579
#    user  system elapsed
# 749.987  54.298 805.046
#    user  system elapsed
# 743.654  51.856 792.991
#    user  system elapsed
# 750.010  49.802 795.945
#    user  system elapsed
# 747.929  54.121 798.409
#    user  system elapsed
# 751.446  48.923 796.079
#    user  system elapsed
# 746.335  52.941 795.873
#    user  system elapsed
# 743.362  49.332 787.866
#    user  system elapsed
# 742.192  51.400 790.224
#    user  system elapsed
# 745.857  47.028 787.805
#    user  system elapsed
# 816.900  69.747 936.975
#    user  system elapsed
# 804.801  67.440 916.976
#    user  system elapsed
# 738.449  50.962 785.226
#    user  system elapsed
# 739.021  50.577 785.433
#    user  system elapsed
# 742.297  54.445 793.072
#    user  system elapsed
# 742.634  50.778 789.823
#    user  system elapsed
# 753.220  46.754 796.597
#    user  system elapsed
# 750.741  46.819 793.096
#    user  system elapsed
# 747.926  48.855 792.413
#    user  system elapsed
# 742.357  50.583 788.051
#    user  system elapsed
# 744.425  52.030 793.122
#    user  system elapsed
# 761.012  45.604 801.625
#    user  system elapsed
# 745.084  45.744 785.159
#    user  system elapsed
# 747.887  48.717 792.245
#    user  system elapsed
# 737.700  49.094 781.753
#    user  system elapsed
# 741.642  49.350 787.464
#    user  system elapsed
# 612.066  49.128 656.618
#    user  system elapsed
# 646.036  48.765 690.754
#    user  system elapsed
# 736.029  51.586 784.039
#    user  system elapsed
# 739.107  48.465 782.859
#    user  system elapsed
# 730.566  48.015 774.173
#    user  system elapsed
# 730.734  47.850 772.859
#    user  system elapsed
# 730.192  52.170 777.414
#    user  system elapsed
# 733.851  49.970 779.998
#    user  system elapsed
# 735.718  48.357 778.947
#    user  system elapsed
# 735.231  46.183 776.263
#    user  system elapsed
# 736.474  46.745 777.756
#    user  system elapsed
# 738.830  48.348 782.128
#    user  system elapsed
# 730.191  52.926 779.505
#    user  system elapsed
# 735.061  48.367 777.461
#    user  system elapsed
# 741.580  49.328 785.959
#    user  system elapsed
# 739.091  48.170 782.230
#    user  system elapsed
# 729.759  49.427 773.977
#    user  system elapsed
# 748.142  43.934 787.423
#    user  system elapsed
# 733.590  48.207 776.953
#    user  system elapsed
# 738.037  47.241 780.275
#    user  system elapsed
# 735.188  48.280 778.528
#    user  system elapsed
# 735.633  50.156 781.730
#    user  system elapsed
# 729.656  55.062 781.512
#    user  system elapsed
# 739.874  47.175 783.748
#    user  system elapsed
# 731.246  49.712 776.014
#    user  system elapsed
# 743.138  46.038 784.501
#    user  system elapsed
# 742.897  41.919 779.329
#    user  system elapsed
# 736.510  48.166 779.515
#    user  system elapsed
# 736.556  54.737 788.908
#    user  system elapsed
# 731.520  47.328 774.514
#    user  system elapsed
# 726.466  51.432 772.547
#    user  system elapsed
# 740.417  51.751 790.148
#    user  system elapsed
# 731.090  52.757 780.675
#    user  system elapsed
# 771.736  56.755 837.940
#    user  system elapsed
# 804.124  67.715 894.488
#    user  system elapsed
# 809.184  66.855 891.573
#    user  system elapsed
# 813.241  75.653 912.562
#    user  system elapsed
# 812.637  73.456 911.862
#    user  system elapsed
# 827.320  77.098 941.330
#    user  system elapsed
# 810.231  72.836 908.565
#    user  system elapsed
# 745.673  59.958 811.347
#    user  system elapsed
# 745.838  48.813 791.468
#    user  system elapsed
# 772.949  60.958 839.899
#    user  system elapsed
# 763.156  55.428 817.335
#    user  system elapsed
# 757.580  58.366 815.838
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL
#
# [[6]]
# NULL
#
# [[7]]
# NULL
#
# [[8]]
# NULL
#
# [[9]]
# NULL
#
# [[10]]
# NULL
#
# [[11]]
# NULL
#
# [[12]]
# NULL
#
# [[13]]
# NULL
#
# [[14]]
# NULL
#
# [[15]]
# NULL
#
# [[16]]
# NULL
#
# [[17]]
# NULL
#
# [[18]]
# NULL
#
# [[19]]
# NULL
#
# [[20]]
# NULL
#
# [[21]]
# NULL
#
# [[22]]
# NULL
#
# [[23]]
# NULL
#
# [[24]]
# NULL
#
# [[25]]
# NULL
#
# [[26]]
# NULL
#
# [[27]]
# NULL
#
# [[28]]
# NULL
#
# [[29]]
# NULL
#
# [[30]]
# NULL
#
# [[31]]
# NULL
#
# [[32]]
# NULL
#
# [[33]]
# NULL
#
# [[34]]
# NULL
#
# [[35]]
# NULL
#
# [[36]]
# NULL
#
# [[37]]
# NULL
#
# [[38]]
# NULL
#
# [[39]]
# NULL
#
# [[40]]
# NULL
#
# [[41]]
# NULL
#
# [[42]]
# NULL
#
# [[43]]
# NULL
#
# [[44]]
# NULL
#
# [[45]]
# NULL
#
# [[46]]
# NULL
#
# [[47]]
# NULL
#
# [[48]]
# NULL
#
# [[49]]
# NULL
#
# [[50]]
# NULL
#
# [[51]]
# NULL
#
# [[52]]
# NULL
#
# [[53]]
# NULL
#
# [[54]]
# NULL
#
# [[55]]
# NULL
#
# [[56]]
# NULL
#
# [[57]]
# NULL
#
# [[58]]
# NULL
#
# [[59]]
# NULL
#
# [[60]]
# NULL
#
# [[61]]
# NULL
#
# [[62]]
# NULL
#
# [[63]]
# NULL
#
# [[64]]
# NULL
#
# [[65]]
# NULL
#
# [[66]]
# NULL
#
# [[67]]
# NULL
#
# [[68]]
# NULL
#
# [[69]]
# NULL
#
# [[70]]
# NULL
#
# [[71]]
# NULL
#
# [[72]]
# NULL
#
# [[73]]
# NULL
#
# [[74]]
# NULL
#
# [[75]]
# NULL
#
# [[76]]
# NULL
#
# [[77]]
# NULL
#
# [[78]]
# NULL
#
# [[79]]
# NULL
#
# [[80]]
# NULL
#
# [[81]]
# NULL
#
# [[82]]
# NULL
#
# [[83]]
# NULL
#
# [[84]]
# NULL
#
# [[85]]
# NULL
#
# [[86]]
# NULL
#
# [[87]]
# NULL
#
# [[88]]
# NULL
#
# [[89]]
# NULL
#
# [[90]]
# NULL
#
# [[91]]
# NULL
#
# [[92]]
# NULL
#
# [[93]]
# NULL
#
# [[94]]
# NULL
#
# [[95]]
# NULL
#
# [[96]]
# NULL
#
# [[97]]
# NULL
#
# [[98]]
# NULL
#
# [[99]]
# NULL
#
# [[100]]
# NULL
