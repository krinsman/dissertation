# %%
library("phenopath")
library("reticulate")
np <- import("numpy")

# %% [markdown]
# I am not sure whether the CAVI optimization from phenopath is completely deterministic, so I'm not sure whether the following cell would have actually been necessary for complete reproducibility. Nevertheless, I should have included this in the original notebooks.

# %%
set.seed(42)

# %%
phenopath_defaults <- function(observations, covariates, ...) {
    # suppressWarnings because I am well aware that it hasn't converged
    return(suppressWarnings(phenopath(observations, covariates, model_mu=TRUE, 
                                      maxiter=50, thin=10, verbose=FALSE, ...)))
}

# %% [markdown]
# The gLV models have intercepts $\mu$, and it makes more sense conceptually that a model has them (so they can represent 'intrinsic growth rates'), so `model_mu` is being used even though it is not a default setting. Plus very preliminary investigation seemed to suggest it is likely to get better results, and one would expect that theoretically as well not just for the reasons above but also because the default `model_mu=FALSE` is actually a special case where $\mu = 0$ is assumed, so allowing extra possible values for that parameter in general can only increase the fit. (Of course one can then argue about overfitting, but that seems unlikely since this model is clearly heavily mis-specified anyway, and again the extra parameter would not only increase fit but also be amenable to biological interpretation in this context.)
#
# Regarding small number of iterations, they seem to give decent enough results in practice, all the more so given that in this context one is more interested in qualitative fit, especially correct signs and sparsity, than precise numerical values. In other words any resulting quantitative accuracy will hopefully not also correspond to substantially decreased qualitative accuracy, especially given that 50 iterations is still a decent amount. Plus from a practical perspective, in order to provide estimates for so many estimations, there needs to be a reasonably enough upper bound on the runtime for each, and that is only possible by providing a relatively small of maximum possible iterations. In practice the experimenter, who only needs to analyze the results of a single experiment, should probably not used such a low number of maximum iterations.

# %%
spearman <- function(x,y){return(cor(x,y,method='spearman'))}

# %%
size = 11
seed = 42
number_droplets = 100000
number_batches = 5
results_dirname = 'results'

base_filename = paste(results_dirname, '/', size, '_strains.seed_', 
                      seed, '.', format(number_droplets, scientific=FALSE), '_droplets.iteration_',
                      '#', '.npz', sep='')

# %%
get_results <- function(phenopath_results, true_times) {
    uncensored_results <- interaction_effects(phenopath_results)
    censored_results <- significant_interactions(phenopath_results) * uncensored_results
    pearson <- abs(cor(true_times, trajectory(phenopath_results))) # same level of support if pseudotimes are flipped
    spearman <- abs(spearman(true_times, trajectory(phenopath_results)))
    
    results <- list("uncensored_results" = uncensored_results, 
                   "censored_results" = censored_results,
                   "pearson" = pearson,
                   "spearman" = spearman)
    return(results)
}

# %%
get_results_filename <- function(base_dir, scaling, iteration_number) {
    iteration_filename = paste('iteration_', iteration_number, '.npz', sep='')
    results_dir = file.path(paste(base_dir, '/', scaling, sep=''))
    results_filename = file.path(paste(results_dir, '/', iteration_filename, sep=''))
    return(results_filename)
}

save_results <- function(results_filename, results) {
    np$savez_compressed(results_filename,
    uncensored_results = results$uncensored_results,
    censored_results = results$censored_results,
    pearson = results$pearson,
    spearman = results$spearman)
}

# %% [markdown]
# The questions that I seek to answer are at a broad level: 'How can phenopath best be applied to this problem?' and 'What settings will allow phenopath to work best?'. Admittedly though not all possible choices of settings are being considered (e.g. alternative choices of `z_init`, like the true time values or the exponentials thereof, nor centering but not scaling the data, etc.) but the idea behind that was because in practice the experimenter is only likely to be willing (or in some cases only able) to use settings which do not deviate too much from the default values, plus it is reasonable to think that default choices of e.g. `z_init` were well thought out by the developers and are likely to be useful in practice, even if not the most useful theoretically possible for this context (which would be impossible to find, at least without a lot of probably intractable theory, due to e.g. the infinite state space of options for many settings).
#
# So the specific questions reduce to: (1) does it make sense to scale the data in this context (even though the data is PCR-bias adjusted and so roughly absolute counts), (2) what makes the most sense to use as the covariates for the model, and (3) do censoring values considered "insignificant" by the phenopath model lead to increased fit (i.e. by reducing false positives)? As an additional fun question, it is also asked: does the correlation (Pearson and/or Spearman) of the computed pseudotimes with the true times of the batches have any predictive value for the performance? E.g. do the true time values have any "importance" in that sense?
#
# As for always using the log-transformed data as the values, well that is both what is recommended in the phenopath paper and in its documentation, and moreover what makes the (generative) model for phenopath most closely resemble the (integral version of) the gLV equations.
#
# create directories to store results in

# %%
all_results_dir = 'phenopath_results_cells'
if (!dir.exists(all_results_dir)) {dir.create(all_results_dir)}

binary_results_dir = file.path(paste(all_results_dir, '/', 'binary_covariates', sep=''))
if (!dir.exists(binary_results_dir)) {dir.create(binary_results_dir)}

counts_cov_results_dir = file.path(paste(all_results_dir, '/', 'count_covariates', sep=''))
if (!dir.exists(counts_cov_results_dir)) {dir.create(counts_cov_results_dir)}

for (subdirectory in list.files(path=all_results_dir, full.names=T)) {
    scaled_results_dir = file.path(paste(subdirectory, '/', 'scaled', sep=''))
    if (!dir.exists(scaled_results_dir)) {dir.create(scaled_results_dir)}
    
    unscaled_results_dir = file.path(paste(subdirectory, '/', 'unscaled', sep=''))
    if (!dir.exists(unscaled_results_dir)) {dir.create(unscaled_results_dir)}
}

# %% [markdown]
# loop through the iterations of stored results

# %%
# very bad naughty code that uses lots of global variables
# this is a self-contained notebook however and not a software library.
# I don't want to rewrite the function and the function calls to unnecessarily be
# much longer when scope rules automatically do the right thing.
lapply_input <- function(iteration_number){
    
    filename = gsub("#", iteration_number, base_filename)
    npzfile = np$load(filename)

    cell_log_counts = npzfile[["cell_log_counts"]]
    cell_init_vectors = npzfile[["cell_init_vectors"]]
    cell_counts = exp(cell_log_counts)*(cell_log_counts != 0)    
    
    merged_droplets_per_batch <- dim(cell_log_counts)[1]/number_batches
    true_times = c()
    for (i in 1:number_batches) {true_times <- append(true_times, rep(i, merged_droplets_per_batch))}
    
    start_time <- proc.time()
    binary_scaled <- phenopath_defaults(cell_log_counts, cell_init_vectors, scale_y=TRUE)
    results <- get_results(binary_scaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    binary_unscaled <- phenopath_defaults(cell_log_counts, cell_init_vectors, scale_y=FALSE)
    results <- get_results(binary_unscaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_scaled <- phenopath_defaults(cell_log_counts, cell_counts, scale_y=TRUE)
    results <- get_results(counts_scaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_unscaled <- phenopath_defaults(cell_log_counts, cell_counts, scale_y=FALSE)
    results <- get_results(counts_unscaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    # this is supposed to be an embarrassingly parallel for loop, so memory usage should not change with number of iterations
    # but system monitor shows memory usage continually increasing. Hadley Wickham seems to have said that calling `gc`
    # manually for garbage collection should never be necessary, but honestly at this point I don't trust R so...
    gc()
    
    # controversial stylistically but consistent with Python style and since most programming is done
    # in Python, from a practical perspective it's better for me to use stylistic conventions that also work in Python.
    return(NULL)
}

# %%
lapply(1:100, lapply_input)
# Out:
#    user  system elapsed
# 859.750  71.818 975.724
#     user   system  elapsed
#  866.914   84.607 1025.279
#     user   system  elapsed
#  863.229   86.401 1028.356
#    user  system elapsed
# 836.930  75.204 932.723
#    user  system elapsed
# 817.916  69.153 903.742
#    user  system elapsed
# 815.387  64.533 896.600
#    user  system elapsed
# 820.358  57.699 886.942
#    user  system elapsed
# 806.174  63.482 880.844
#    user  system elapsed
# 814.378  63.022 886.740
#    user  system elapsed
# 814.281  60.282 886.286
#    user  system elapsed
# 821.409  58.202 879.812
#    user  system elapsed
# 810.666  57.995 868.161
#    user  system elapsed
# 817.139  63.272 892.238
#    user  system elapsed
# 833.130  70.815 928.768
#    user  system elapsed
# 851.644  94.645 990.426
#     user   system  elapsed
#  895.853  117.384 1097.902
#     user   system  elapsed
#  887.210   99.634 1044.098
#     user   system  elapsed
#  873.750   78.934 1001.754
#    user  system elapsed
# 842.200  67.276 921.716
#    user  system elapsed
# 815.974  62.647 882.103
#    user  system elapsed
# 847.686  77.408 961.342
#    user  system elapsed
# 816.934  70.392 903.336
#    user  system elapsed
# 840.118  71.061 925.200
#    user  system elapsed
# 834.778  75.458 934.173
#    user  system elapsed
# 821.840  73.451 911.699
#    user  system elapsed
# 819.313  71.179 904.445
#    user  system elapsed
# 821.233  71.976 904.031
#    user  system elapsed
# 818.909  71.865 906.509
#    user  system elapsed
# 826.031  73.459 911.113
#     user   system  elapsed
#  883.100   80.086 1043.294
#     user   system  elapsed
#  889.564   83.533 1065.156
#     user   system  elapsed
#  898.218   87.068 1079.682
#     user   system  elapsed
#  918.810   88.379 1120.127
#     user   system  elapsed
#  911.717   96.255 1149.298
#    user  system elapsed
# 860.501  85.493 996.083
#    user  system elapsed
# 858.620  70.042 931.004
#    user  system elapsed
# 795.679  64.438 861.077
#    user  system elapsed
# 783.494  56.532 837.526
#    user  system elapsed
# 850.486  55.149 902.918
#    user  system elapsed
# 779.971  54.524 830.983
#    user  system elapsed
# 792.828  52.140 840.475
#    user  system elapsed
# 808.154  54.671 859.828
#    user  system elapsed
# 812.189  56.447 868.148
#    user  system elapsed
# 779.348  53.681 829.315
#    user  system elapsed
# 817.210  54.578 867.928
#    user  system elapsed
# 809.251  56.352 864.708
#    user  system elapsed
# 788.891  52.205 837.339
#    user  system elapsed
# 777.388  53.442 829.859
#    user  system elapsed
# 783.290  52.800 833.215
#    user  system elapsed
# 786.593  53.136 835.506
#    user  system elapsed
# 781.190  51.149 828.642
#    user  system elapsed
# 779.042  53.082 828.807
#    user  system elapsed
# 788.412  52.509 837.203
#    user  system elapsed
# 852.179  61.554 913.850
#    user  system elapsed
# 780.688  52.428 829.571
#    user  system elapsed
# 784.092  57.069 838.402
#    user  system elapsed
# 784.233  52.060 832.066
#    user  system elapsed
# 775.552  56.283 829.164
#    user  system elapsed
# 781.843  53.073 831.336
#    user  system elapsed
# 774.706  53.673 823.872
#    user  system elapsed
# 789.627  54.114 840.157
#    user  system elapsed
# 808.392  57.473 863.751
#    user  system elapsed
# 814.431  54.542 867.469
#    user  system elapsed
# 778.774  53.787 828.947
#    user  system elapsed
# 784.488  54.607 836.917
#    user  system elapsed
# 796.673  63.104 867.374
#    user  system elapsed
# 799.433  57.837 853.979
#    user  system elapsed
# 766.435  53.954 817.537
#    user  system elapsed
# 783.896  63.464 847.473
#    user  system elapsed
# 787.587  62.100 850.751
#    user  system elapsed
# 801.671  59.115 861.058
#    user  system elapsed
# 795.767  58.559 855.254
#    user  system elapsed
# 808.937  60.028 870.009
#    user  system elapsed
# 796.485  62.074 861.371
#    user  system elapsed
# 796.222  56.431 851.720
#    user  system elapsed
# 821.139  72.309 929.033
#    user  system elapsed
# 851.210  64.066 915.660
#    user  system elapsed
# 791.199  58.040 862.226
#    user  system elapsed
# 805.982  59.741 869.027
#    user  system elapsed
# 809.963  56.105 863.451
#    user  system elapsed
# 855.287  61.934 918.173
#    user  system elapsed
# 787.851  57.292 843.820
#    user  system elapsed
# 784.891  55.697 840.579
#    user  system elapsed
# 818.873  62.459 891.057
#    user  system elapsed
# 835.690  61.671 910.946
#    user  system elapsed
# 809.930  63.083 879.989
#    user  system elapsed
# 806.895  60.601 874.305
#    user  system elapsed
# 798.368  67.046 868.185
#    user  system elapsed
# 825.670  77.081 947.354
#    user  system elapsed
# 841.088  71.141 916.369
#    user  system elapsed
# 834.272  72.105 945.355
#    user  system elapsed
# 793.835  63.448 856.145
#    user  system elapsed
# 788.475  59.360 847.352
#    user  system elapsed
# 803.599  63.033 889.678
#    user  system elapsed
# 888.529  72.156 980.884
#    user  system elapsed
# 824.533  66.721 897.630
#    user  system elapsed
# 802.771  65.021 874.289
#    user  system elapsed
# 801.065  71.156 879.740
#    user  system elapsed
# 804.537  67.364 874.860
#    user  system elapsed
# 816.904  73.835 918.445
#    user  system elapsed
# 821.215  70.247 910.332
#    user  system elapsed
# 821.259  76.089 911.677
#    user  system elapsed
# 856.653  82.763 969.481
#    user  system elapsed
# 840.364  78.905 936.203
#    user  system elapsed
# 865.576  78.886 972.282
#    user  system elapsed
# 849.842  85.421 982.221
#    user  system elapsed
# 866.227  76.471 970.362
#    user  system elapsed
# 847.728  69.023 930.314
#    user  system elapsed
# 828.403  68.564 904.313
#    user  system elapsed
# 854.395  74.453 936.932
#    user  system elapsed
# 850.980  69.427 930.851
#     user   system  elapsed
#  878.918  107.235 1041.301
#    user  system elapsed
# 827.984  60.336 891.632
#    user  system elapsed
# 837.676  64.458 906.542
#    user  system elapsed
# 846.020  78.191 945.872
#    user  system elapsed
# 843.240  71.745 933.022
#    user  system elapsed
# 859.115  72.515 960.498
#    user  system elapsed
# 836.054  77.274 937.230
#    user  system elapsed
# 864.713  73.050 950.431
#    user  system elapsed
# 851.485  80.532 966.850
#    user  system elapsed
# 831.428  77.333 935.671
#    user  system elapsed
# 845.627  76.140 959.066
#    user  system elapsed
# 829.601  73.267 931.293
#    user  system elapsed
# 843.412  80.693 965.156
#    user  system elapsed
# 852.973  83.413 996.058
#    user  system elapsed
# 841.847  78.801 989.031
#    user  system elapsed
# 844.716  78.906 965.080
#    user  system elapsed
# 826.152  74.678 923.135
#    user  system elapsed
# 841.940  77.982 949.201
#    user  system elapsed
# 848.115  76.152 947.916
#    user  system elapsed
# 839.648  82.533 956.755
#    user  system elapsed
# 780.229  59.684 838.013
#    user  system elapsed
# 803.605  56.352 856.435
#    user  system elapsed
# 790.824  54.364 842.626
#    user  system elapsed
# 780.371  51.122 826.356
#    user  system elapsed
# 776.025  50.673 821.415
#    user  system elapsed
# 791.715  54.661 843.371
#    user  system elapsed
# 774.331  51.914 822.220
#    user  system elapsed
# 781.424  49.593 825.980
#    user  system elapsed
# 785.458  53.768 838.189
#    user  system elapsed
# 777.475  51.758 824.413
#    user  system elapsed
# 781.841  52.299 829.796
#    user  system elapsed
# 781.823  51.566 828.495
#    user  system elapsed
# 779.209  51.952 826.474
#    user  system elapsed
# 796.690  50.975 843.634
#    user  system elapsed
# 786.510  50.215 831.541
#    user  system elapsed
# 781.145  51.432 828.250
#    user  system elapsed
# 775.912  51.290 822.953
#    user  system elapsed
# 783.237  50.515 829.287
#    user  system elapsed
# 774.389  51.507 821.336
#    user  system elapsed
# 775.839  51.540 824.189
#    user  system elapsed
# 773.828  51.450 820.623
#    user  system elapsed
# 781.506  51.918 828.539
#    user  system elapsed
# 771.807  50.756 817.383
#    user  system elapsed
# 784.695  50.152 830.720
#    user  system elapsed
# 774.261  53.621 825.073
#    user  system elapsed
# 774.258  50.352 819.635
#    user  system elapsed
# 772.181  52.615 821.535
#    user  system elapsed
# 779.239  51.797 827.121
#    user  system elapsed
# 769.482  51.382 816.652
#    user  system elapsed
# 779.995  50.496 824.741
#    user  system elapsed
# 773.017  50.799 818.706
#    user  system elapsed
# 772.810  50.062 817.042
#    user  system elapsed
# 808.743  69.176 912.348
#    user  system elapsed
# 824.604  70.831 919.048
#    user  system elapsed
# 806.791  67.482 884.407
#    user  system elapsed
# 806.640  69.488 885.548
#    user  system elapsed
# 817.336  75.166 909.213
#    user  system elapsed
# 860.371  68.697 930.936
#    user  system elapsed
# 788.204  64.969 854.976
#    user  system elapsed
# 780.415  57.965 836.973
#    user  system elapsed
# 834.679  70.444 925.436
#    user  system elapsed
# 845.850  66.145 919.513
#    user  system elapsed
# 801.556  60.290 862.100
#    user  system elapsed
# 794.110  60.537 855.230
#    user  system elapsed
# 810.703  69.858 886.592
#    user  system elapsed
# 816.693  67.801 888.417
#    user  system elapsed
# 805.078  69.065 877.049
#    user  system elapsed
# 787.146  62.670 850.051
#    user  system elapsed
# 791.824  65.264 861.728
#    user  system elapsed
# 796.015  68.302 869.468
#    user  system elapsed
# 809.212  68.989 892.181
#    user  system elapsed
# 800.323  63.181 867.318
#    user  system elapsed
# 814.339  74.223 905.264
#    user  system elapsed
# 813.974  70.099 893.625
#    user  system elapsed
# 827.803  69.020 912.255
#    user  system elapsed
# 825.491  70.356 909.552
#    user  system elapsed
# 832.856  71.635 929.946
#    user  system elapsed
# 827.018  70.323 907.095
#    user  system elapsed
# 873.146  66.224 947.307
#    user  system elapsed
# 817.397  69.007 900.122
#    user  system elapsed
# 810.275  70.801 896.326
#    user  system elapsed
# 837.012  71.796 918.182
#    user  system elapsed
# 870.590  65.152 936.106
#    user  system elapsed
# 793.572  60.208 856.547
#    user  system elapsed
# 813.129  71.463 905.061
#    user  system elapsed
# 865.253  74.549 958.359
#    user  system elapsed
# 831.158  69.026 917.529
#    user  system elapsed
# 831.212  71.719 923.519
#    user  system elapsed
# 853.087  78.875 961.565
#    user  system elapsed
# 837.264  71.967 929.239
#    user  system elapsed
# 819.141  64.839 885.806
#    user  system elapsed
# 825.176  59.635 884.292
#    user  system elapsed
# 806.848  71.791 893.599
#    user  system elapsed
# 811.663  66.667 887.233
#    user  system elapsed
# 825.096  69.334 900.596
#    user  system elapsed
# 820.074  67.604 891.811
#    user  system elapsed
# 813.474  70.792 893.869
#     user   system  elapsed
#  903.285  133.474 1120.749
#    user  system elapsed
# 866.825  88.400 978.613
#    user  system elapsed
# 786.026  58.459 841.764
#    user  system elapsed
# 813.297  64.482 878.810
#    user  system elapsed
# 824.984  62.844 889.449
#    user  system elapsed
# 779.253  58.706 835.758
#    user  system elapsed
# 851.037  59.444 910.861
#    user  system elapsed
# 784.279  61.280 845.194
#    user  system elapsed
# 807.943  62.667 877.131
#    user  system elapsed
# 820.097  62.471 887.782
#    user  system elapsed
# 815.034  62.633 887.416
#    user  system elapsed
# 812.943  68.969 893.144
#    user  system elapsed
# 817.351  64.210 896.161
#    user  system elapsed
# 829.227  70.474 932.190
#    user  system elapsed
# 809.827  66.149 892.608
#    user  system elapsed
# 781.602  55.022 832.740
#    user  system elapsed
# 797.961  53.593 847.236
#    user  system elapsed
# 781.580  51.195 827.850
#    user  system elapsed
# 773.910  49.957 818.746
#    user  system elapsed
# 775.278  52.524 823.437
#    user  system elapsed
# 786.200  52.269 834.976
#    user  system elapsed
# 772.997  50.699 818.613
#    user  system elapsed
# 778.411  49.422 822.452
#    user  system elapsed
# 771.378  50.835 817.246
#    user  system elapsed
# 776.083  51.959 823.483
#    user  system elapsed
# 766.550  51.797 814.192
#    user  system elapsed
# 775.004  49.783 819.456
#    user  system elapsed
# 772.750  52.258 819.331
#    user  system elapsed
# 780.483  51.470 827.244
#    user  system elapsed
# 774.214  50.465 819.415
#    user  system elapsed
# 779.451  49.757 823.474
#    user  system elapsed
# 774.520  50.304 818.695
#    user  system elapsed
# 786.864  50.620 832.446
#    user  system elapsed
# 772.764  52.341 820.415
#    user  system elapsed
# 781.253  50.282 826.261
#    user  system elapsed
# 773.501  50.698 819.430
#    user  system elapsed
# 776.595  50.504 822.006
#    user  system elapsed
# 776.287  51.859 823.947
#    user  system elapsed
# 770.118  50.119 815.281
#    user  system elapsed
# 769.186  50.755 814.592
#    user  system elapsed
# 773.690  49.943 818.621
#    user  system elapsed
# 786.049  51.038 832.789
#    user  system elapsed
# 772.733  50.205 817.757
#    user  system elapsed
# 769.246  52.880 817.222
#    user  system elapsed
# 775.934  51.363 822.903
#    user  system elapsed
# 768.504  49.964 813.474
#    user  system elapsed
# 774.213  50.950 821.152
#    user  system elapsed
# 770.416  50.843 816.070
#    user  system elapsed
# 781.816  50.687 827.243
#    user  system elapsed
# 783.697  51.227 830.486
#    user  system elapsed
# 808.127  51.322 854.964
#    user  system elapsed
# 774.661  52.181 823.205
#    user  system elapsed
# 773.110  50.308 818.440
#    user  system elapsed
# 777.997  53.024 826.497
#    user  system elapsed
# 816.483  60.360 886.450
#    user  system elapsed
# 831.298  67.350 915.251
#    user  system elapsed
# 830.712  67.219 910.914
#    user  system elapsed
# 805.837  65.526 884.188
#    user  system elapsed
# 774.206  60.864 834.730
#    user  system elapsed
# 774.370  56.622 828.230
#    user  system elapsed
# 773.317  52.574 822.402
#    user  system elapsed
# 776.873  53.861 828.034
#    user  system elapsed
# 768.408  51.582 816.628
#    user  system elapsed
# 769.398  53.899 820.146
#    user  system elapsed
# 782.825  51.890 830.411
#    user  system elapsed
# 777.111  51.647 826.427
#    user  system elapsed
# 783.393  52.285 831.728
#    user  system elapsed
# 777.036  54.367 829.566
#    user  system elapsed
# 783.571  54.190 833.554
#    user  system elapsed
# 770.865  54.035 821.638
#    user  system elapsed
# 773.375  51.655 821.396
#    user  system elapsed
# 773.704  55.184 825.028
#    user  system elapsed
# 785.857  55.587 840.472
#    user  system elapsed
# 783.273  54.530 834.886
#    user  system elapsed
# 780.985  51.873 828.597
#    user  system elapsed
# 788.683  53.228 838.794
#    user  system elapsed
# 800.583  55.969 854.132
#    user  system elapsed
# 790.731  53.814 841.055
#    user  system elapsed
# 774.250  52.915 824.434
#    user  system elapsed
# 782.475  54.047 839.727
#    user  system elapsed
# 840.783  65.879 936.746
#    user  system elapsed
# 843.915  66.577 945.873
#    user  system elapsed
# 843.493  68.094 940.157
#    user  system elapsed
# 856.392  73.026 953.895
#    user  system elapsed
# 868.075  66.907 951.347
#     user   system  elapsed
# 1002.070   88.329 1189.772
#     user   system  elapsed
# 1051.541   92.919 1294.288
#    user  system elapsed
# 844.022  64.246 919.965
#    user  system elapsed
# 819.475  64.615 901.990
#    user  system elapsed
# 808.039  59.864 880.469
#    user  system elapsed
# 813.208  61.964 882.935
#    user  system elapsed
# 784.464  55.988 840.201
#    user  system elapsed
# 850.318  63.234 918.635
#    user  system elapsed
# 788.416  52.932 838.055
#    user  system elapsed
# 780.948  51.326 828.111
#    user  system elapsed
# 772.749  51.497 819.303
#    user  system elapsed
# 855.554  67.818 948.341
#    user  system elapsed
# 849.850  66.351 931.307
#    user  system elapsed
# 865.512  65.937 948.698
#    user  system elapsed
# 809.338  63.958 881.380
#    user  system elapsed
# 786.203  57.616 841.852
#    user  system elapsed
# 782.165  57.200 837.210
#    user  system elapsed
# 662.932  53.213 716.329
#    user  system elapsed
# 647.876  49.580 708.923
#     user   system  elapsed
#  794.368  121.055 1041.481
#    user  system elapsed
# 709.847  54.797 773.249
#    user  system elapsed
# 684.242  49.423 737.635
#    user  system elapsed
# 663.403  49.134 706.947
#    user  system elapsed
# 666.081  49.842 721.102
#    user  system elapsed
# 654.240  48.868 705.522
#    user  system elapsed
# 661.196  48.540 709.922
#    user  system elapsed
# 672.425  49.759 728.692
#    user  system elapsed
# 643.329  46.153 687.504
#    user  system elapsed
# 622.970  45.284 660.807
#    user  system elapsed
# 629.717  44.308 665.912
#    user  system elapsed
# 620.149  44.919 657.041
#    user  system elapsed
# 626.163  44.922 663.198
#    user  system elapsed
# 624.318  44.167 661.224
#    user  system elapsed
# 621.955  43.348 657.669
#    user  system elapsed
# 617.038  44.293 652.674
#    user  system elapsed
# 629.063  44.252 665.557
#    user  system elapsed
# 623.564  43.939 659.368
#    user  system elapsed
# 622.822  43.745 658.604
#    user  system elapsed
# 616.250  44.287 653.018
#    user  system elapsed
# 624.724  44.698 661.295
#    user  system elapsed
# 625.387  43.978 661.502
#    user  system elapsed
# 623.551  43.341 658.797
#    user  system elapsed
# 619.558  43.585 654.691
#    user  system elapsed
# 629.172  44.189 665.366
#    user  system elapsed
# 626.329  43.556 662.122
#    user  system elapsed
# 626.675  43.722 662.724
#    user  system elapsed
# 618.194  44.707 654.763
#    user  system elapsed
# 622.771  44.797 659.307
#    user  system elapsed
# 622.591  44.257 658.670
#    user  system elapsed
# 627.101  42.971 661.852
#    user  system elapsed
# 624.517  44.434 660.180
#    user  system elapsed
# 633.257  44.295 669.382
#    user  system elapsed
# 624.792  44.447 661.190
#    user  system elapsed
# 622.468  43.913 658.267
#    user  system elapsed
# 617.936  44.852 654.798
#    user  system elapsed
# 622.264  44.637 658.792
#    user  system elapsed
# 621.556  44.239 657.702
#    user  system elapsed
# 623.967  43.962 659.815
#    user  system elapsed
# 619.376  43.915 654.992
#    user  system elapsed
# 624.064  43.541 659.544
#    user  system elapsed
# 621.623  43.946 657.379
#    user  system elapsed
# 622.601  43.535 658.131
#    user  system elapsed
# 621.223  45.003 657.967
#    user  system elapsed
# 624.817  44.980 661.896
#    user  system elapsed
# 623.374  44.434 659.840
#    user  system elapsed
# 624.964  43.639 660.474
#    user  system elapsed
# 620.992  44.646 656.994
#    user  system elapsed
# 621.719  44.125 657.807
#    user  system elapsed
# 621.201  44.347 657.390
#    user  system elapsed
# 621.604  44.167 657.555
#    user  system elapsed
# 618.004  44.701 654.685
#    user  system elapsed
# 625.135  44.700 661.719
#    user  system elapsed
# 623.850  44.295 660.229
#    user  system elapsed
# 623.553  43.705 659.114
#    user  system elapsed
# 619.503  44.137 655.313
#    user  system elapsed
# 624.442  43.927 660.189
#    user  system elapsed
# 625.328  44.680 661.624
#    user  system elapsed
# 623.050  44.061 659.266
#    user  system elapsed
# 618.053  45.131 654.964
#    user  system elapsed
# 624.695  44.615 661.278
#    user  system elapsed
# 620.348  44.608 656.911
#    user  system elapsed
# 622.473  43.920 658.331
#    user  system elapsed
# 631.482  46.399 675.900
#    user  system elapsed
# 672.712  49.196 725.700
#    user  system elapsed
# 638.268  45.632 678.061
#    user  system elapsed
# 649.694  46.569 690.394
#    user  system elapsed
# 632.053  45.780 671.315
#    user  system elapsed
# 631.387  45.139 668.317
#    user  system elapsed
# 624.326  44.742 661.191
#    user  system elapsed
# 645.971  47.489 692.415
#    user  system elapsed
# 644.128  47.127 685.110
#    user  system elapsed
# 630.848  44.770 667.631
#    user  system elapsed
# 631.116  45.150 668.015
#    user  system elapsed
# 652.682  46.508 693.139
#    user  system elapsed
# 641.187  48.296 683.602
#    user  system elapsed
# 627.750  45.265 665.002
#    user  system elapsed
# 626.550  45.182 663.972
#    user  system elapsed
# 624.340  44.048 661.303
#    user  system elapsed
# 622.640  44.532 659.089
#    user  system elapsed
# 647.933  45.666 686.694
#    user  system elapsed
# 628.430  45.414 666.085
#    user  system elapsed
# 625.646  44.952 662.999
#    user  system elapsed
# 634.717  45.595 672.667
#    user  system elapsed
# 628.626  44.979 665.526
#    user  system elapsed
# 628.752  44.791 665.825
#    user  system elapsed
# 638.048  44.860 675.437
#    user  system elapsed
# 632.493  46.850 672.577
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL
#
# [[6]]
# NULL
#
# [[7]]
# NULL
#
# [[8]]
# NULL
#
# [[9]]
# NULL
#
# [[10]]
# NULL
#
# [[11]]
# NULL
#
# [[12]]
# NULL
#
# [[13]]
# NULL
#
# [[14]]
# NULL
#
# [[15]]
# NULL
#
# [[16]]
# NULL
#
# [[17]]
# NULL
#
# [[18]]
# NULL
#
# [[19]]
# NULL
#
# [[20]]
# NULL
#
# [[21]]
# NULL
#
# [[22]]
# NULL
#
# [[23]]
# NULL
#
# [[24]]
# NULL
#
# [[25]]
# NULL
#
# [[26]]
# NULL
#
# [[27]]
# NULL
#
# [[28]]
# NULL
#
# [[29]]
# NULL
#
# [[30]]
# NULL
#
# [[31]]
# NULL
#
# [[32]]
# NULL
#
# [[33]]
# NULL
#
# [[34]]
# NULL
#
# [[35]]
# NULL
#
# [[36]]
# NULL
#
# [[37]]
# NULL
#
# [[38]]
# NULL
#
# [[39]]
# NULL
#
# [[40]]
# NULL
#
# [[41]]
# NULL
#
# [[42]]
# NULL
#
# [[43]]
# NULL
#
# [[44]]
# NULL
#
# [[45]]
# NULL
#
# [[46]]
# NULL
#
# [[47]]
# NULL
#
# [[48]]
# NULL
#
# [[49]]
# NULL
#
# [[50]]
# NULL
#
# [[51]]
# NULL
#
# [[52]]
# NULL
#
# [[53]]
# NULL
#
# [[54]]
# NULL
#
# [[55]]
# NULL
#
# [[56]]
# NULL
#
# [[57]]
# NULL
#
# [[58]]
# NULL
#
# [[59]]
# NULL
#
# [[60]]
# NULL
#
# [[61]]
# NULL
#
# [[62]]
# NULL
#
# [[63]]
# NULL
#
# [[64]]
# NULL
#
# [[65]]
# NULL
#
# [[66]]
# NULL
#
# [[67]]
# NULL
#
# [[68]]
# NULL
#
# [[69]]
# NULL
#
# [[70]]
# NULL
#
# [[71]]
# NULL
#
# [[72]]
# NULL
#
# [[73]]
# NULL
#
# [[74]]
# NULL
#
# [[75]]
# NULL
#
# [[76]]
# NULL
#
# [[77]]
# NULL
#
# [[78]]
# NULL
#
# [[79]]
# NULL
#
# [[80]]
# NULL
#
# [[81]]
# NULL
#
# [[82]]
# NULL
#
# [[83]]
# NULL
#
# [[84]]
# NULL
#
# [[85]]
# NULL
#
# [[86]]
# NULL
#
# [[87]]
# NULL
#
# [[88]]
# NULL
#
# [[89]]
# NULL
#
# [[90]]
# NULL
#
# [[91]]
# NULL
#
# [[92]]
# NULL
#
# [[93]]
# NULL
#
# [[94]]
# NULL
#
# [[95]]
# NULL
#
# [[96]]
# NULL
#
# [[97]]
# NULL
#
# [[98]]
# NULL
#
# [[99]]
# NULL
#
# [[100]]
# NULL
