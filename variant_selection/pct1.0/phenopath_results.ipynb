# %%
library("phenopath")
library("reticulate")
np <- import("numpy")

# %%
phenopath_defaults <- function(observations, covariates, ...) {
    return(suppressWarnings(phenopath(observations, covariates, model_mu=TRUE, 
                                      maxiter=50, thin=10, verbose=FALSE, ...)))
}

# %% [markdown]
# The gLV models have intercepts $\mu$, and it makes more sense conceptually that a model has them (so they can represent 'intrinsic growth rates'), so `model_mu` is being used even though it is not a default setting. Plus very preliminary investigation seemed to suggest it is likely to get better results, and one would expect that theoretically as well not just for the reasons above but also because the default `model_mu=FALSE` is actually a special case where $\mu = 0$ is assumed, so allowing extra possible values for that parameter in general can only increase the fit. (Of course one can then argue about overfitting, but that seems unlikely since this model is clearly heavily mis-specified anyway, and again the extra parameter would not only increase fit but also be amenable to biological interpretation in this context.)
#
# Regarding small number of iterations, they seem to give decent enough results in practice, all the more so given that in this context one is more interested in qualitative fit, especially correct signs and sparsity, than precise numerical values. In other words any resulting quantitative accuracy will hopefully not also correspond to substantially decreased qualitative accuracy, especially given that 50 iterations is still a decent amount. Plus from a practical perspective, in order to provide estimates for so many estimations, there needs to be a reasonably enough upper bound on the runtime for each, and that is only possible by providing a relatively small of maximum possible iterations. In practice the experimenter, who only needs to analyze the results of a single experiment, should probably not used such a low number of maximum iterations.

# %%
spearman <- function(x,y){return(cor(x,y,method='spearman'))}

# %%
size = 11
seed = 42
number_droplets = 100000
number_batches = 5
results_dirname = 'results'

base_filename = paste(results_dirname, '/', size, '_strains.seed_', 
                      seed, '.', format(number_droplets, scientific=FALSE), '_droplets.iteration_',
                      '#', '.npz', sep='')

# %%
get_results <- function(phenopath_results, true_times) {
    uncensored_results <- interaction_effects(phenopath_results)
    censored_results <- significant_interactions(phenopath_results) * uncensored_results
    pearson <- abs(cor(true_times, trajectory(phenopath_results))) # same level of support if pseudotimes are flipped
    spearman <- abs(spearman(true_times, trajectory(phenopath_results)))
    
    results <- list("uncensored_results" = uncensored_results, 
                   "censored_results" = censored_results,
                   "pearson" = pearson,
                   "spearman" = spearman)
    return(results)
}

# %%
get_results_filename <- function(base_dir, scaling, iteration_number) {
    iteration_filename = paste('iteration_', iteration_number, '.npz', sep='')
    results_dir = file.path(paste(base_dir, '/', scaling, sep=''))
    results_filename = file.path(paste(results_dir, '/', iteration_filename, sep=''))
    return(results_filename)
}

save_results <- function(results_filename, results) {
    np$savez_compressed(results_filename,
    uncensored_results = results$uncensored_results,
    censored_results = results$censored_results,
    pearson = results$pearson,
    spearman = results$spearman)
}

# %% [markdown]
# The questions that I seek to answer are at a broad level: 'How can phenopath best be applied to this problem?' and 'What settings will allow phenopath to work best?'. Admittedly though not all possible choices of settings are being considered (e.g. alternative choices of `z_init`, like the true time values or the exponentials thereof, nor centering but not scaling the data, etc.) but the idea behind that was because in practice the experimenter is only likely to be willing (or in some cases only able) to use settings which do not deviate too much from the default values, plus it is reasonable to think that default choices of e.g. `z_init` were well thought out by the developers and are likely to be useful in practice, even if not the most useful theoretically possible for this context (which would be impossible to find, at least without a lot of probably intractable theory, due to e.g. the infinite state space of options for many settings).
#
# So the specific questions reduce to: (1) does it make sense to scale the data in this context (even though the data is PCR-bias adjusted and so roughly absolute counts), (2) what makes the most sense to use as the covariates for the model, and (3) do censoring values considered "insignificant" by the phenopath model lead to increased fit (i.e. by reducing false positives)? As an additional fun question, it is also asked: does the correlation (Pearson and/or Spearman) of the computed pseudotimes with the true times of the batches have any predictive value for the performance? E.g. do the true time values have any "importance" in that sense?
#
# As for always using the log-transformed data as the values, well that is both what is recommended in the phenopath paper and in its documentation, and moreover what makes the (generative) model for phenopath most closely resemble the (integral version of) the gLV equations.
#
# create directories to store results in

# %%
all_results_dir = 'phenopath_results'
if (!dir.exists(all_results_dir)) {dir.create(all_results_dir)}

binary_results_dir = file.path(paste(all_results_dir, '/', 'binary_covariates', sep=''))
if (!dir.exists(binary_results_dir)) {dir.create(binary_results_dir)}

counts_cov_results_dir = file.path(paste(all_results_dir, '/', 'count_covariates', sep=''))
if (!dir.exists(counts_cov_results_dir)) {dir.create(counts_cov_results_dir)}

for (subdirectory in list.files(path='phenopath_results', full.names=T)) {
    scaled_results_dir = file.path(paste(subdirectory, '/', 'scaled', sep=''))
    if (!dir.exists(scaled_results_dir)) {dir.create(scaled_results_dir)}
    
    unscaled_results_dir = file.path(paste(subdirectory, '/', 'unscaled', sep=''))
    if (!dir.exists(unscaled_results_dir)) {dir.create(unscaled_results_dir)}
}

# %% [markdown]
# loop through the iterations of stored results

# %%
for (iteration_number in 1:100) {
    
    filename = gsub("#", iteration_number, base_filename)
    npzfile = np$load(filename)

    read_log_counts = npzfile[["read_log_counts"]]
    read_init_vectors = npzfile[["read_init_vectors"]]
    read_counts = exp(read_log_counts)*(read_log_counts != 0)    
    
    merged_droplets_per_batch <- dim(read_log_counts)[1]/number_batches
    true_times = c()
    for (i in 1:number_batches) {true_times <- append(true_times, rep(i, merged_droplets_per_batch))}
    
    start_time <- proc.time()
    binary_scaled <- phenopath_defaults(read_log_counts, read_init_vectors, scale_y=TRUE)
    results <- get_results(binary_scaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    binary_unscaled <- phenopath_defaults(read_log_counts, read_init_vectors, scale_y=FALSE)
    results <- get_results(binary_unscaled, true_times)
    save_results(get_results_filename(binary_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_scaled <- phenopath_defaults(read_log_counts, read_counts, scale_y=TRUE)
    results <- get_results(counts_scaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'scaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    start_time <- proc.time()
    counts_unscaled <- phenopath_defaults(read_log_counts, read_counts, scale_y=FALSE)
    results <- get_results(counts_unscaled, true_times)
    save_results(get_results_filename(counts_cov_results_dir, 'unscaled', iteration_number), results)
    run_time <- proc.time() - start_time; print(run_time)
    
    # this is supposed to be an embarrassingly parallel for loop, so memory usage should not change with number of iterations
    # but system monitor shows memory usage continually increasing. Hadley Wickham seems to have said that calling `gc`
    # manually for garbage collection should never be necessary, but honestly at this point I don't trust R so...
    gc()    
}
# Out:
#    user  system elapsed
# 538.368  33.514 562.746
#    user  system elapsed
# 658.323  56.316 715.831
#    user  system elapsed
# 609.633  48.361 652.787
#    user  system elapsed
# 602.421  45.657 641.354
#    user  system elapsed
# 609.328  44.771 647.122
#    user  system elapsed
# 607.230  49.776 651.541
#    user  system elapsed
# 597.766  47.096 637.757
#    user  system elapsed
# 592.658  46.788 633.724
#    user  system elapsed
# 604.527  44.118 642.547
#    user  system elapsed
# 600.587  49.383 643.979
#    user  system elapsed
# 595.967  47.313 637.433
#    user  system elapsed
# 594.372  46.070 634.131
#    user  system elapsed
# 605.674  40.479 638.487
#    user  system elapsed
# 607.576  46.043 646.997
#    user  system elapsed
# 597.549  44.144 635.324
#    user  system elapsed
# 597.191  44.845 634.633
#    user  system elapsed
# 603.798  41.323 638.280
#    user  system elapsed
# 595.220  44.897 632.519
#    user  system elapsed
# 599.423  44.668 636.163
#    user  system elapsed
# 592.342  43.984 628.914
#    user  system elapsed
# 608.535  43.526 644.608
#    user  system elapsed
# 609.511  43.657 645.805
#    user  system elapsed
# 602.058  45.592 641.365
#    user  system elapsed
# 590.324  49.449 633.025
#    user  system elapsed
# 597.153  45.908 637.027
#    user  system elapsed
# 596.265  46.491 635.666
#    user  system elapsed
# 600.874  46.349 640.494
#    user  system elapsed
# 595.649  41.878 630.139
#    user  system elapsed
# 607.419  44.796 643.750
#    user  system elapsed
# 595.557  45.700 634.505
#    user  system elapsed
# 593.250  44.777 631.046
#    user  system elapsed
# 589.480  46.087 628.744
#    user  system elapsed
# 603.519  40.982 636.615
#    user  system elapsed
# 602.294  44.813 641.623
#    user  system elapsed
# 597.029  43.718 632.963
#    user  system elapsed
# 592.049  45.391 630.541
#    user  system elapsed
# 598.046  43.873 634.980
#    user  system elapsed
# 596.094  44.788 633.073
#    user  system elapsed
# 601.514  45.116 638.979
#    user  system elapsed
# 593.069  44.285 630.018
#    user  system elapsed
# 598.726  43.675 634.722
#    user  system elapsed
# 598.616  43.933 634.956
#    user  system elapsed
# 591.910  43.633 627.710
#    user  system elapsed
# 595.086  44.633 632.488
#    user  system elapsed
# 603.846  44.988 642.056
#    user  system elapsed
# 614.530  47.372 657.594
#    user  system elapsed
# 613.886  49.795 665.782
#    user  system elapsed
# 600.540  45.346 639.170
#    user  system elapsed
# 618.382  46.745 660.162
#    user  system elapsed
# 607.285  46.476 648.700
#    user  system elapsed
# 632.943  52.514 686.425
#    user  system elapsed
# 606.578  47.507 648.681
#    user  system elapsed
# 624.026  48.631 669.655
#    user  system elapsed
# 618.457  47.274 660.936
#    user  system elapsed
# 622.341  47.565 665.384
#    user  system elapsed
# 629.039  49.789 676.114
#    user  system elapsed
# 632.891  49.848 681.943
#    user  system elapsed
# 640.900  51.287 689.786
#    user  system elapsed
# 646.817  55.746 710.328
#    user  system elapsed
# 634.974  53.010 687.480
#    user  system elapsed
# 612.487  45.680 650.896
#    user  system elapsed
# 604.998  47.917 646.527
#    user  system elapsed
# 610.982  48.462 656.607
#    user  system elapsed
# 627.785  52.680 682.180
#    user  system elapsed
# 632.798  51.174 685.447
#    user  system elapsed
# 628.345  50.597 681.997
#    user  system elapsed
# 639.255  54.315 698.100
#    user  system elapsed
# 641.521  53.146 700.474
#    user  system elapsed
# 631.822  49.180 679.618
#    user  system elapsed
# 643.637  53.529 700.466
#    user  system elapsed
# 640.092  54.389 697.498
#    user  system elapsed
# 652.877  56.555 717.965
#    user  system elapsed
# 633.246  51.587 683.854
#    user  system elapsed
# 654.738  54.737 710.960
#    user  system elapsed
# 634.586  51.858 686.224
#    user  system elapsed
# 641.812  51.166 691.873
#    user  system elapsed
# 614.840  47.799 656.041
#    user  system elapsed
# 612.086  48.077 654.316
#    user  system elapsed
# 644.804  51.222 697.078
#    user  system elapsed
# 685.591  59.030 766.478
#    user  system elapsed
# 672.961  57.430 744.021
#    user  system elapsed
# 628.117  52.543 678.282
#    user  system elapsed
# 634.106  53.716 686.739
#    user  system elapsed
# 599.354  46.421 639.827
#    user  system elapsed
# 601.650  45.429 640.004
#    user  system elapsed
# 602.717  45.291 641.079
#    user  system elapsed
# 609.823  45.637 648.652
#    user  system elapsed
# 601.504  46.575 642.414
#    user  system elapsed
# 609.639  45.562 648.451
#    user  system elapsed
# 605.550  48.155 648.319
#    user  system elapsed
# 620.604  46.722 660.353
#    user  system elapsed
# 634.055  48.673 678.068
#    user  system elapsed
# 637.448  48.780 683.019
#    user  system elapsed
# 698.408  63.322 778.675
#    user  system elapsed
# 679.477  57.297 749.481
#    user  system elapsed
# 694.528  59.680 770.421
#    user  system elapsed
# 617.075  48.455 661.458
#    user  system elapsed
# 619.404  48.019 661.013
#    user  system elapsed
# 630.253  50.981 679.165
#    user  system elapsed
# 626.668  49.320 673.388
#    user  system elapsed
# 609.455  44.823 647.242
#    user  system elapsed
# 630.692  51.127 680.155
#    user  system elapsed
# 696.407  67.319 770.428
#    user  system elapsed
# 636.001  50.328 696.857
#    user  system elapsed
# 609.147  45.294 646.770
#    user  system elapsed
# 621.258  51.271 675.345
#    user  system elapsed
# 636.813  54.366 696.320
#    user  system elapsed
# 702.325  61.636 791.401
#    user  system elapsed
# 708.999  64.686 806.423
#    user  system elapsed
# 677.762  60.500 762.684
#    user  system elapsed
# 644.201  56.590 704.879
#    user  system elapsed
# 657.905  54.792 726.201
#    user  system elapsed
# 644.264  57.068 708.298
#    user  system elapsed
# 634.139  49.503 679.809
#    user  system elapsed
# 636.440  49.047 680.876
#    user  system elapsed
# 623.260  49.953 671.767
#    user  system elapsed
# 655.569  57.803 725.871
#    user  system elapsed
# 650.456  54.364 720.457
#    user  system elapsed
# 649.351  53.903 709.831
#    user  system elapsed
# 665.361  54.834 734.485
#    user  system elapsed
# 655.549  53.480 725.122
#    user  system elapsed
# 597.998  48.021 639.781
#    user  system elapsed
# 591.516  44.725 632.281
#    user  system elapsed
# 587.844  45.268 626.922
#    user  system elapsed
# 601.987  44.555 638.910
#    user  system elapsed
# 601.333  45.400 639.418
#    user  system elapsed
# 594.592  44.238 631.791
#    user  system elapsed
# 587.121  43.644 622.868
#    user  system elapsed
# 609.751  44.937 647.635
#    user  system elapsed
# 598.261  44.489 635.576
#    user  system elapsed
# 589.172  44.234 625.317
#    user  system elapsed
# 593.018  44.216 629.671
#    user  system elapsed
# 601.544  43.870 638.381
#    user  system elapsed
# 590.328  44.301 626.919
#    user  system elapsed
# 595.699  44.280 632.261
#    user  system elapsed
# 587.310  43.985 623.450
#    user  system elapsed
# 595.375  44.617 632.329
#    user  system elapsed
# 590.369  43.337 625.896
#    user  system elapsed
# 597.932  44.965 635.682
#    user  system elapsed
# 588.194  42.876 624.735
#    user  system elapsed
# 590.647  43.775 626.549
#    user  system elapsed
# 593.992  44.152 629.857
#    user  system elapsed
# 594.969  44.246 631.022
#    user  system elapsed
# 584.387  43.287 620.216
#    user  system elapsed
# 595.555  44.167 631.973
#    user  system elapsed
# 598.138  43.787 634.671
#    user  system elapsed
# 593.996  44.253 630.002
#    user  system elapsed
# 588.351  43.607 626.043
#    user  system elapsed
# 593.959  43.686 629.886
#    user  system elapsed
# 593.552  44.216 629.551
#    user  system elapsed
# 593.712  44.514 630.428
#    user  system elapsed
# 584.375  43.652 620.349
#    user  system elapsed
# 595.761  44.499 633.070
#    user  system elapsed
# 596.567  44.498 634.181
#    user  system elapsed
# 596.247  44.346 633.276
#    user  system elapsed
# 589.310  43.697 625.391
#    user  system elapsed
# 595.547  44.271 631.954
#    user  system elapsed
# 588.879  43.442 624.417
#    user  system elapsed
# 589.195  44.603 626.105
#    user  system elapsed
# 591.358  43.731 627.681
#    user  system elapsed
# 594.384  43.793 630.577
#    user  system elapsed
# 591.670  44.449 628.378
#    user  system elapsed
# 590.739  44.234 627.135
#    user  system elapsed
# 587.160  43.376 623.173
#    user  system elapsed
# 596.836  43.890 633.323
#    user  system elapsed
# 593.293  44.380 629.717
#    user  system elapsed
# 590.799  43.922 627.325
#    user  system elapsed
# 588.275  43.358 623.856
#    user  system elapsed
# 598.606  44.068 635.182
#    user  system elapsed
# 615.841  48.260 658.191
#    user  system elapsed
# 620.507  47.519 661.798
#    user  system elapsed
# 607.971  45.381 647.287
#    user  system elapsed
# 615.896  46.768 656.280
#    user  system elapsed
# 641.206  47.775 683.331
#    user  system elapsed
# 610.672  46.095 650.796
#    user  system elapsed
# 618.835  47.420 660.274
#    user  system elapsed
# 626.698  47.024 667.535
#    user  system elapsed
# 600.126  44.325 636.615
#    user  system elapsed
# 592.562  44.942 629.468
#    user  system elapsed
# 594.936  43.600 630.583
#    user  system elapsed
# 595.360  43.756 633.209
#    user  system elapsed
# 593.409  44.226 629.935
#    user  system elapsed
# 616.065  47.048 656.123
#    user  system elapsed
# 606.791  46.379 645.933
#    user  system elapsed
# 601.992  45.116 639.615
#    user  system elapsed
# 598.630  44.573 636.149
#    user  system elapsed
# 599.217  45.228 636.288
#    user  system elapsed
# 593.038  43.919 629.351
#    user  system elapsed
# 603.358  44.167 640.172
#    user  system elapsed
# 607.903  45.978 647.944
#    user  system elapsed
# 638.777  51.940 687.542
#    user  system elapsed
# 603.777  44.467 641.119
#    user  system elapsed
# 615.061  46.434 655.372
#    user  system elapsed
# 631.454  47.863 675.161
#    user  system elapsed
# 602.960  44.948 640.590
#    user  system elapsed
# 604.576  44.121 641.706
#    user  system elapsed
# 678.670  59.676 762.866
#    user  system elapsed
# 693.895  59.281 772.750
#    user  system elapsed
# 667.707  55.097 728.913
#    user  system elapsed
# 635.989  52.836 692.294
#    user  system elapsed
# 618.202  47.631 661.293
#    user  system elapsed
# 659.723  55.388 722.034
#    user  system elapsed
# 630.763  49.721 684.295
#    user  system elapsed
# 639.709  52.580 694.167
#    user  system elapsed
# 634.631  50.059 681.564
#    user  system elapsed
# 609.122  46.877 649.245
#    user  system elapsed
# 614.247  47.530 655.841
#    user  system elapsed
# 609.790  46.967 651.154
#    user  system elapsed
# 618.029  45.502 658.141
#    user  system elapsed
# 623.263  46.716 663.686
#    user  system elapsed
# 629.292  48.682 671.409
#    user  system elapsed
# 611.874  45.105 650.020
#    user  system elapsed
# 620.145  47.035 662.098
#    user  system elapsed
# 612.280  46.395 652.169
#    user  system elapsed
# 610.959  45.399 649.822
#    user  system elapsed
# 610.659  46.347 650.604
#    user  system elapsed
# 612.321  45.200 650.869
#    user  system elapsed
# 616.142  45.849 655.418
#    user  system elapsed
# 612.914  46.587 654.118
#    user  system elapsed
# 614.129  49.361 663.475
#    user  system elapsed
# 610.981  46.224 649.841
#    user  system elapsed
# 617.351  49.893 673.598
#    user  system elapsed
# 638.305  53.570 698.615
#    user  system elapsed
# 636.777  49.805 684.776
#    user  system elapsed
# 646.412  51.182 700.994
#    user  system elapsed
# 651.203  51.781 710.616
#    user  system elapsed
# 648.549  51.265 708.925
#    user  system elapsed
# 677.062  56.725 745.367
#    user  system elapsed
# 695.063  54.767 756.094
#    user  system elapsed
# 679.326  51.596 730.891
#    user  system elapsed
# 655.875  49.270 702.573
#    user  system elapsed
# 685.707  54.186 748.827
#    user  system elapsed
# 716.079  56.522 788.803
#    user  system elapsed
# 682.962  56.665 752.102
#    user  system elapsed
# 712.216  58.434 796.258
#    user  system elapsed
# 652.044  50.937 702.775
#    user  system elapsed
# 629.242  49.808 677.610
#    user  system elapsed
# 663.542  52.239 716.856
#    user  system elapsed
# 678.446  58.084 748.000
#    user  system elapsed
# 629.836  47.013 674.081
#    user  system elapsed
# 656.577  50.802 713.116
#    user  system elapsed
# 682.878  58.712 769.547
#    user  system elapsed
# 647.446  51.904 705.822
#    user  system elapsed
# 633.059  51.033 694.444
#    user  system elapsed
# 663.212  51.704 715.028
#    user  system elapsed
# 661.981  53.533 721.143
#    user  system elapsed
# 650.966  52.755 713.533
#    user  system elapsed
# 611.159  47.180 654.053
#    user  system elapsed
# 613.767  46.558 654.162
#    user  system elapsed
# 605.204  45.003 643.909
#    user  system elapsed
# 598.345  45.797 637.138
#    user  system elapsed
# 602.183  44.316 639.112
#    user  system elapsed
# 602.069  44.836 640.164
#    user  system elapsed
# 598.834  45.596 637.203
#    user  system elapsed
# 599.522  44.876 637.097
#    user  system elapsed
# 595.548  43.948 632.517
#    user  system elapsed
# 600.784  45.310 638.220
#    user  system elapsed
# 596.549  43.988 633.339
#    user  system elapsed
# 603.093  45.675 642.086
#    user  system elapsed
# 608.018  46.317 648.750
#    user  system elapsed
# 608.678  44.873 646.934
#    user  system elapsed
# 605.072  45.196 642.272
#    user  system elapsed
# 600.385  44.183 636.988
#    user  system elapsed
# 607.755  44.792 645.829
#    user  system elapsed
# 605.585  44.557 642.951
#    user  system elapsed
# 594.822  44.603 632.411
#    user  system elapsed
# 600.003  44.612 637.718
#    user  system elapsed
# 596.441  43.746 632.728
#    user  system elapsed
# 598.382  44.429 635.506
#    user  system elapsed
# 597.922  44.621 635.674
#    user  system elapsed
# 597.542  45.384 636.120
#    user  system elapsed
# 594.050  44.361 632.082
#    user  system elapsed
# 602.582  44.362 640.429
#    user  system elapsed
# 603.004  44.901 640.828
#    user  system elapsed
# 595.593  43.734 632.631
#    user  system elapsed
# 593.170  44.141 629.446
#    user  system elapsed
# 602.670  45.629 641.238
#    user  system elapsed
# 599.254  44.310 636.284
#    user  system elapsed
# 598.356  44.642 635.673
#    user  system elapsed
# 591.174  43.041 627.366
#    user  system elapsed
# 597.478  43.864 633.433
#    user  system elapsed
# 598.257  44.868 636.109
#    user  system elapsed
# 605.384  44.578 643.535
#    user  system elapsed
# 593.962  44.019 631.148
#    user  system elapsed
# 595.839  43.683 633.351
#    user  system elapsed
# 600.135  44.504 637.033
#    user  system elapsed
# 602.717  44.584 640.786
#    user  system elapsed
# 624.625  46.199 664.271
#    user  system elapsed
# 608.773  43.968 646.491
#    user  system elapsed
# 596.170  44.385 632.965
#    user  system elapsed
# 594.794  44.461 631.749
#    user  system elapsed
# 590.579  43.783 627.429
#    user  system elapsed
# 594.294  44.749 631.757
#    user  system elapsed
# 601.641  45.734 641.245
#    user  system elapsed
# 599.304  44.608 636.852
#    user  system elapsed
# 591.312  43.696 627.404
#    user  system elapsed
# 594.327  44.034 631.705
#    user  system elapsed
# 594.341  43.615 630.257
#    user  system elapsed
# 597.083  44.578 635.299
#    user  system elapsed
# 592.230  43.138 628.200
#    user  system elapsed
# 598.584  44.434 635.427
#    user  system elapsed
# 600.110  44.458 637.146
#    user  system elapsed
# 596.220  44.794 633.246
#    user  system elapsed
# 596.183  43.804 632.623
#    user  system elapsed
# 607.225  44.919 645.875
#    user  system elapsed
# 642.724  54.683 704.511
#    user  system elapsed
# 728.487  97.709 863.256
#    user  system elapsed
# 612.688  49.278 655.121
#    user  system elapsed
# 615.605  47.057 657.365
#    user  system elapsed
# 619.386  47.128 660.250
#    user  system elapsed
# 638.752  49.643 691.783
#    user  system elapsed
# 627.858  49.001 678.012
#    user  system elapsed
# 582.174  45.148 621.376
#    user  system elapsed
# 507.219  36.208 533.953
#    user  system elapsed
# 509.467  36.564 537.307
#    user  system elapsed
# 515.205  38.079 544.303
#    user  system elapsed
# 519.810  37.681 548.664
#    user  system elapsed
# 519.216  37.696 547.973
#    user  system elapsed
# 521.599  39.178 551.679
#    user  system elapsed
# 515.808  37.345 545.230
#    user  system elapsed
# 514.900  36.886 541.682
#    user  system elapsed
# 510.702  36.894 537.439
#    user  system elapsed
# 505.995  36.753 532.968
#    user  system elapsed
# 502.945  35.796 529.643
#    user  system elapsed
# 507.179  35.876 533.265
#    user  system elapsed
# 510.206  36.392 536.883
#    user  system elapsed
# 527.439  38.693 559.823
#    user  system elapsed
# 529.478  38.897 562.872
#    user  system elapsed
# 537.984  39.959 572.151
#    user  system elapsed
# 530.901  38.915 561.107
#    user  system elapsed
# 526.626  39.075 557.823
#    user  system elapsed
# 543.395  40.778 578.887
#    user  system elapsed
# 519.412  37.341 547.511
#    user  system elapsed
# 508.742  37.244 538.359
#    user  system elapsed
# 509.463  36.887 536.570
#    user  system elapsed
# 519.804  38.395 549.419
#    user  system elapsed
# 524.259  38.809 554.393
#    user  system elapsed
# 521.618  38.091 550.291
#    user  system elapsed
# 526.556  38.954 556.779
#    user  system elapsed
# 523.698  37.833 553.207
#    user  system elapsed
# 529.019  38.311 559.655
#    user  system elapsed
# 524.125  39.001 555.101
#    user  system elapsed
# 515.251  37.801 543.424
#    user  system elapsed
# 516.926  37.592 545.113
#    user  system elapsed
# 526.656  38.202 556.001
#    user  system elapsed
# 525.804  38.390 555.047
#    user  system elapsed
# 524.661  39.030 555.074
#    user  system elapsed
# 541.876  42.393 579.055
#    user  system elapsed
# 548.473  43.296 586.205
#    user  system elapsed
# 547.107  43.195 584.600
#    user  system elapsed
# 548.851  44.053 587.527
#    user  system elapsed
# 547.771  44.000 586.441
#    user  system elapsed
# 554.874  44.475 594.398
#    user  system elapsed
# 553.332  44.096 592.968
#    user  system elapsed
# 542.363  40.961 577.295
#    user  system elapsed
# 518.851  38.256 547.290
#    user  system elapsed
# 526.675  39.240 557.121
#    user  system elapsed
# 529.682  39.337 559.879
#    user  system elapsed
# 525.749  39.410 557.414
#    user  system elapsed
# 524.716  38.251 556.007
#    user  system elapsed
# 512.893  37.014 539.615
#    user  system elapsed
# 510.478  37.234 538.198
#    user  system elapsed
# 511.681  37.058 538.579
#    user  system elapsed
# 624.415  74.950 739.787
#     user   system  elapsed
#  595.342   65.164 7500.050
#    user  system elapsed
# 549.711  42.035 587.017
#    user  system elapsed
# 544.674  41.604 580.046
#    user  system elapsed
# 529.671  39.421 562.575
#    user  system elapsed
# 559.814  41.041 595.063
#    user  system elapsed
# 532.834  40.896 569.228
#    user  system elapsed
# 539.685  41.537 577.300
#    user  system elapsed
# 531.809  39.877 566.302
#    user  system elapsed
# 562.664  43.138 607.304
#    user  system elapsed
# 540.029  41.300 575.110
#    user  system elapsed
# 543.821  41.555 578.977
#    user  system elapsed
# 531.933  39.019 565.871
#    user  system elapsed
# 549.083  41.875 586.642
#    user  system elapsed
# 550.803  41.992 589.151
#    user  system elapsed
# 539.923  41.127 577.132
#    user  system elapsed
# 541.469  40.828 577.907
#    user  system elapsed
# 562.840  43.340 611.983
#    user  system elapsed
# 552.803  43.032 594.117
#    user  system elapsed
# 553.766  42.958 596.254
#    user  system elapsed
# 559.867  42.999 603.655
#    user  system elapsed
# 552.165  41.885 594.361
#    user  system elapsed
# 547.501  41.484 588.447
#    user  system elapsed
# 557.092  41.768 602.542
#    user  system elapsed
# 572.108  45.190 630.362
#    user  system elapsed
# 570.891  43.922 616.905
#    user  system elapsed
# 557.928  42.547 606.163
#    user  system elapsed
# 565.759  43.942 617.669
#    user  system elapsed
# 565.904  44.247 613.659
#    user  system elapsed
# 566.207  43.550 609.401
#    user  system elapsed
# 557.304  43.520 600.711
#    user  system elapsed
# 550.572  42.631 589.348
#    user  system elapsed
# 536.878  39.896 570.583
#    user  system elapsed
# 513.946  37.032 541.032
#    user  system elapsed
# 519.068  36.797 545.888
#    user  system elapsed
# 517.059  37.231 544.563
#    user  system elapsed
# 516.895  36.434 543.709
